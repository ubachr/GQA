# %%
from src.utils import *
# Out:
# c:\Users\ubach\.conda\envs\geospatial_ETC_DI_v4\lib\site-packages\geopandas\_compat.py:123: UserWarning: The Shapely GEOS version (3.11.2-CAPI-1.17.2) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(
# c:\Users\ubach\Projects\GQA\src\utils.py:3: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   import geopandas as gpd

# %%
# Load required libraries
import pandas as pd
import geopandas as gpd
import numpy as np
import os
import fiona
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from shapely.ops import unary_union
from unidecode import unidecode
import glob
import csv
from datetime import datetime
import dask.dataframe as dd
import dask_geopandas as dg
from dask.distributed import Client
import gc

# %%
# Path to data folders
indata_f = r'P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas'
outdata_f = os.path.join(indata_f, 'OutputData', 'batch1')
if not os.path.exists(outdata_f):
    # Create the folder if it doesn't exist
    os.makedirs(outdata_f)

# 0 PREPARE A LOG FILE FOR QC
log_file = 'log_GQA_Step1.csv'
log_path = os.path.join(outdata_f, log_file)

# Initialize Dask client
client = Client()

# Define engines
engines = {
    'fiona': {'engine': 'fiona'},
    'pyogrio': {'engine': 'pyogrio'},
    'pyogrio+arrow': {'engine': 'pyogrio', 'use_arrow': True}
          
}
# Out:
# c:\Users\ubach\.conda\envs\geospatial_ETC_DI_v4\lib\site-packages\distributed\node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 51074 instead
#   warnings.warn(

# %%
# 1 READ URBAN CENTRES
# Read shapefile
uc_file_path = os.path.join(indata_f, 'UrbanCentres', 'HDC2021_RG.shp')
# Read the GeoPackage file
uc = gpd.read_file(uc_file_path)
uc['HDENS_NAME'].fillna('aaa', inplace=True)

# %%
uc.head()
# Out:
#       HDENS_CLST  HDENS_NAME     HDENS_2011  POPL_2021 CNTR_CODE  MBRS_CODE_  \
# 0  GEOSTAT21_018   Stockholm  GEOSTAT11_018  1462910.0        SE           1
# 1  GEOSTAT21_019     Haninge  GEOSTAT11_019    94485.0        SE           1
# 2  GEOSTAT21_020  Södertälje  GEOSTAT11_020    74475.0        SE           1
# 3  GEOSTAT21_021       Tartu  GEOSTAT11_021    84168.0        EE           2
# 4  GEOSTAT21_022      Örebro  GEOSTAT11_022    92695.0        SE           1
#
#     SHAPE_AREA  SHAPE_LEN                                           geometry  \
# 0  342000000.0   162000.0  POLYGON ((4775000.000 4038000.000, 4774000.000...
# 1   36000000.0    38000.0  POLYGON ((4787000.000 4033000.000, 4786000.000...
# 2   22000000.0    24000.0  POLYGON ((4756000.000 4031000.000, 4755000.000...
# 3   24000000.0    24000.0  POLYGON ((5292000.000 4030000.000, 5290000.000...
# 4   27000000.0    26000.0  POLYGON ((4620000.000 4027000.000, 4618000.000...
#
#   cityLocalName_unicode
# 0             Stockholm
# 1               Haninge
# 2            Sodertalje
# 3                 Tartu
# 4                Orebro

# %%
# Add unicode names
uc_unicode_ls = []
for uc_raw_name in uc_names_ls:
    uc_unicode = unidecode(uc_raw_name)
    uc_unicode_ls.append(uc_unicode)
uc['cityLocalName_unicode'] = uc_unicode_ls

# %%
# 2 READ NOISE DATA
# Load agglomerations delineations
agls_file_path = os.path.join(indata_f, 'NoiseData', 'DF1_5_Agglomerations_20240429.gpkg')

# Read the GeoPackage file
agls = gpd.read_file(agls_file_path, layer = 'dbo.DF15_AgglomerationSource_Valid_LatestDelivery', 
                     **engines['pyogrio+arrow'],columns=['agglomerationId_identifier', 'agglomerationName_nameEng', 'geometry'])

# %%
# Read table to list the cities to process
intable = pd.read_csv(r'P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Deliveries\M1\Batch1_100_agglomerations.csv')
# replace input #############
##########################
cities_ls = intable.HDENS_CLST.tolist()

# %%
# Read table with HDENS Urban centres information and Agglomerations link
HDENS_AGGL_tbl = pd.read_csv(r'P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\UrbanCentres_Agglomerations_csv.csv')

# %%
HDENS_AGGL_tbl.head()
# Out:
#                HDENS_NAME     HDENS_2011  POPL_2021 CNTR_CODE  \
# 0                A Coruña  GEOSTAT11_610     282450        ES
# 1                  Aachen  GEOSTAT11_360     224750        DE
# 2                 Aalborg  GEOSTAT11_031     149041        DK
# 3  Aguadulce / La Gangosa                     55615        ES
# 4         Aix-en-Provence  GEOSTAT11_676     101708        FR
#
#   agglomerationId_identifier agglomerationName_nameEng     size  \
# 0             AG_ES_11_15030                  A Coruña    37.54
# 1                AG_DE_NW_13                    Aachen   161.00
# 2                 AG_DK_00_4                   Aalborg    66.00
# 3             AG_ES_61_04079           Roquetas de Mar    20.82
# 4                AG_FR_00_23                 Marseille  3149.22
#
#    numberOfInhabitants countryCode  Batch
# 0               247046          ES    NaN
# 1               246443          DE    NaN
# 2               138581          DK    1.0
# 3               106147          ES    NaN
# 4              1886800          FR    NaN

# %%
counter= 1
agl_error_ls = []


# Loop through test cities
for cityLocalName in cities_ls:
    print(str(cityLocalName))
    print(counter)
    start_time = datetime.now()
    print(str(start_time))

    cityLocalName_unicode = unidecode(cityLocalName)        
    uc_city = uc.query(f'cityLocalName_unicode == "{cityLocalName_unicode}"')
    if uc_city.empty:
        print ('error in agl city')
        agl_error_ls.append(cityLocalName_unicode)
    
    else:
        ctry_code = uc_city.CNTR_CODE.values.astype(str)[0]
        print(ctry_code)
        cityLocalName_unicode = unidecode(cityLocalName)
        print(f'loading aglomeration city {cityLocalName_unicode}')
        agglomerationId_identifier = HDENS_AGGL_tbl.query(f'HDENS_NAME == "{cityLocalName}"').agglomerationId_identifier.values.astype(str)
        if agglomerationId_identifier.size == 0:
            agglomerationId_identifier = 'NotAvailable'
            print ("agglomerationId_identifier")
        else:
            for i in range(len(agglomerationId_identifier)):
                print(agglomerationId_identifier[i])
                print ("agglomerationId_identifier")        
            
                agl_city = agls.query(f'agglomerationId_identifier == "{agglomerationId_identifier[i]}"')
                if agl_city.empty:
                    agglomerationId_identifier = 'NotAvailable'
                    print ("agglomerationId_identifier")
                else:
                    output_path = os.path.join(outdata_f, f'{ctry_code}_{cityLocalName_unicode}_{agglomerationId_identifier[i]}_GQA_centroids.shp')
                    if not os.path.exists(output_path):
                        # Check noise contour maps GeoPackage file
                        ncm_file_path = os.path.join(indata_f, 'NoiseData', f'Noise_20202025_export.gpkg')
                        layerName = f'dbo.DF48_agg_NoiseContours_roadsInAgglomeration_Lden_Valid_LatestDelivery_Poly_{ctry_code}'           
                        #ncm_file_path = os.path.join(indata_f, 'NoiseData', f'Noise_20202025_export_{ctry_code}.gpkg')
                        #layerName = f'dbo.DF48_agg_NoiseContours_roadsInAgglomeration_Lden_Valid_LatestDelivery_Poly_{ctry_code}'
                        #layerName = f'dbodf48_agg_noisecontours_roadsinagglomeration_lden_valid_latestdelivery_poly_{ctry_code}'
                        ncm = gpd.read_file(ncm_file_path, layer=layerName, columns=['category', 'geometry'], 
                                            engine='pyogrio', use_arrow=True, bbox= tuple(agl_city.total_bounds))
                        print ("ncm")

                        # Perform spatial overlay (intersection) 
                        ncm_agl = gpd.overlay(ncm, agl_city, how='intersection')
                        print ("ncm_agl")

                        # Aggregate the area with lower band values (quieter bands)
                        ncm_agl_city = gpd.overlay(ncm_agl, agl_city, how='union')
                        ncm_agl_city.category.fillna(0)

                        # Select a subset of columns of interest
                        ncm_dis = ncm_agl_city[['category', 'geometry']]
                        
                        # Define the list of noisy classes
                        noisy_classes = ['Lden5559', 'Lden6064', 'Lden6569', 'Lden7074', 'LdenGreaterThan75']

                        # Create a condition based on the category column
                        condition = ncm_dis['category'].isin(noisy_classes)  # Replace 'category_column' with the actual column name

                        # Specify the condition and create a new category column based on the condition
                        ncm_dis['noisy'] = 0
                        ncm_dis.loc[condition, 'noisy'] = 1
                        ncm_dis = ncm_dis[['noisy', 'geometry']]
                        ncm_dis_dg = dg.from_geopandas(ncm_dis, npartitions=10)
                        ncm_dis = ncm_dis_dg.dissolve(by='noisy').compute().reset_index()
                        print ("ncm_dis")

                        # 3 READ UA DATA        
                        # Load GeoPackage info
                        data_f = r'A:\Copernicus\UrbanAtlas\UrbanAtlas\UA2018'
                        ctry_code = uc_city.CNTR_CODE.values.astype(str)[0] 
                        city_unicodeName_upper = unidecode(cityLocalName).upper()
                        folder_path = glob.glob(os.path.join(data_f, f'{ctry_code}*{city_unicodeName_upper}*'))
                        ua_file_path =  glob.glob(os.path.join(folder_path[0], 'Data', f'{ctry_code}*{city_unicodeName_upper}*.gpkg'))
                        layers_ls = fiona.listlayers(ua_file_path[0])
                        print ("layers_ls")

                        # Read the GeoPackage file
                        ua = gpd.read_file(ua_file_path[0], layer= layers_ls[0], 
                                        columns= ['country', 'fua_name', 'fua_code','code_2018', 'class_2018', 'geometry'], engine='pyogrio', 
                                        use_arrow=True, bbox= tuple(uc_city.total_bounds))
                        print ("loaded ua in urban city")

                        # Select 'green' classes
                        uagreen = ua.query('code_2018 == "14100" or code_2018 == "31000"')
                        
                        # 4 SELECT UA INTERSECTING UC
                        # Perform spatial overlay (intersection)
                        uagreen_urbc = gpd.overlay(uagreen, uc_city, how='intersection')

                        # 5 IDENTIFY GREEN AREAS EXCLUDED (NOT COVERED BY NCM)
                        # Perform spatial overlay (intersection)
                        nqgreen = gpd.overlay(uagreen_urbc, ncm_dis, how='intersection') #noisy/quiet green
                        not_covered = uagreen_urbc.geometry.difference(uagreen_urbc.geometry.intersection(nqgreen.geometry.unary_union))
                        # Filter out empty polygons(not empty polygons)
                        green_not_covered_by_ncm = not_covered[~not_covered.is_empty]

                        # save to shapefile
                        file_path = os.path.join(outdata_f, f'{ctry_code}_{cityLocalName_unicode}_{agglomerationId_identifier[i]}_green_not_covered_by_ncm.shp')
                        green_not_covered_by_ncm.to_file(file_path, driver='ESRI Shapefile')
                        print ("green_not_covered_by_ncm")

                        # 6 IDENTIFY QUIET/NOISY AREAS
                        ## for statistics need to calculate area again
                        # Calculate the area for each geometry and create a new column 'area'
                        nqgreen['area_m2'] = nqgreen['geometry'].area
                        nqgreen['area_ha'] = round(nqgreen['area_m2']* 0.0001,2)
                        nqgreen['area_km2'] = round(nqgreen['area_ha']* 0.01,2)
                        nqgreen_area = nqgreen.groupby(['code_2018', 'noisy'])['area_m2'].sum().reset_index()
                        nqgreen_area['area_ha'] = round(nqgreen_area['area_m2']* 0.0001,2)
                        nqgreen_area['area_km2'] = round(nqgreen_area['area_ha']* 0.01,2)

                        # 7 EXPORT GREEN QUIET AREAS (GQA)
                        nqgreen = nqgreen[['country', 'fua_name', 'fua_code', 'HDENS_2011', 'code_2018', 'class_2018', 'noisy',  'area_m2', 'area_ha', 'area_km2', 'geometry']]
                        GQA = nqgreen.query('noisy == 0')
                        GNA = nqgreen.query('noisy == 1')

                        # Export to shapefile
                        file_path = os.path.join(outdata_f, f'{ctry_code}_{cityLocalName_unicode}_{agglomerationId_identifier[i]}_GQA.shp')
                        GQA.to_file(file_path, driver='ESRI Shapefile')
                        print ("GQA")

                        # 8 CREATE CENTROIDS FOR GQA POLYGONS
                        # Create a new GeoDataFrame with centroids as points
                        GQA_pts = gpd.GeoDataFrame(geometry=GQA['geometry'].centroid)
                        GQA_pts['oid'] = GQA.index
                        GQA_pts['fua_name'] = GQA.fua_name
                        GQA_pts['fua_code'] = GQA.fua_code
                        GQA_pts['HDENS_2011'] = GQA.HDENS_2011

                        # Export to shapefile
                        file_path = os.path.join(outdata_f, f'{ctry_code}_{cityLocalName_unicode}_{agglomerationId_identifier[i]}_GQA_centroids.shp')
                        GQA_pts.to_file(file_path, driver='ESRI Shapefile')

                        print ("GQA_pts")
                
                        # Calculate the duration
                        end_time = datetime.now()
                        processing_time = end_time - start_time

                        print ("str(processing_time)")
                        
                        ## write output values into log file
                        uc_km2 = round(uc_city.area.sum()/1000000,2)
                        agl_city_km2 = round(agl_city.area.sum()/1000000,2)
                        ncm_agl_city_km2 = round(ncm_agl_city.area.sum()/1000000,2)
                        ua_km2 = round(ua.area.sum()/1000000,2)
                        uagreen_km2 = round(uagreen.area.sum()/1000000,2)
                        uagreen_urbc_km2 = round(uagreen_urbc.area.sum()/1000000,2)
                        nqgreen_m2 = round(nqgreen.area.sum(),2)
                        green_not_covered_by_ncm_m2 = round(green_not_covered_by_ncm.area.sum(),2)
                        GQA_m2 = round(GQA.area.sum(),2)
                        GNA_m2 = round(GNA.area.sum(),2)
                        processing_duration = str(processing_time)

                        log_entry = create_log_entry(cityLocalName, agglomerationId_identifier, uc_km2, agl_city_km2, 
                                                ncm_agl_city_km2,ua_km2, uagreen_km2, uagreen_urbc_km2, nqgreen_m2, 
                                                green_not_covered_by_ncm_m2, GQA_m2, GNA_m2, processing_time)
                        write_log(log_path, log_entry)
                        # Clean up intermediate variables to free memory
                        del agl_city, ncm, ncm_agl, ncm_agl_city, ncm_dis, ua, uagreen, uagreen_urbc, nqgreen, green_not_covered_by_ncm, GQA, GNA, GQA_pts
    counter= counter+1

print(agl_error_ls)
# Out:
# Aalborg
# 1
# 2024-07-15 09:43:08.335212
# DK
# loading aglomeration city Aalborg
# AG_DK_00_4
# agglomerationId_identifier
# Aarhus
# 2
# 2024-07-15 09:43:08.356207
# error in agl city
# AggloLux
# 3
# 2024-07-15 09:43:08.361198
# error in agl city
# Agglomeration Amsterdam-Haarlem
# 4
# 2024-07-15 09:43:08.365198
# error in agl city
# Agglomeration Rotterdam-Dordrecht
# 5
# 2024-07-15 09:43:08.371196
# error in agl city
# Agglomeration Utrecht
# 6
# 2024-07-15 09:43:08.382199
# error in agl city
# Agglomeration Zwolle
# 7
# 2024-07-15 09:43:08.392197
# error in agl city
# AggloSud
# 8
# 2024-07-15 09:43:08.398198
# error in agl city
# AMADORA
# 9
# 2024-07-15 09:43:08.402198
# error in agl city
# Antwerp
# 10
# 2024-07-15 09:43:08.405199
# error in agl city
# Basel
# 11
# 2024-07-15 09:43:08.410198
# CH-DE
# loading aglomeration city Basel
# AG_CH_00_5
# agglomerationId_identifier
# ---------------------------------------------------------------------------
# DataLayerError                            Traceback (most recent call last)
# Cell In[152], line 44
#      40 layerName = f'dbo.DF48_agg_NoiseContours_roadsInAgglomeration_Lden_Valid_LatestDelivery_Poly_{ctry_code}'
#      41 #ncm_file_path = os.path.join(indata_f, 'NoiseData', f'Noise_20202025_export_{ctry_code}.gpkg')
#      42 #layerName = f'dbo.DF48_agg_NoiseContours_roadsInAgglomeration_Lden_Valid_LatestDelivery_Poly_{ctry_code}'
#      43 #layerName = f'dbodf48_agg_noisecontours_roadsinagglomeration_lden_valid_latestdelivery_poly_{ctry_code}'
# ---> 44 ncm = gpd.read_file(ncm_file_path, layer=layerName, columns=['category', 'geometry'],
#      45                     engine='pyogrio', use_arrow=True, bbox= tuple(agl_city.total_bounds))
#      46 print ("ncm")
#      48 # Perform spatial overlay (intersection)
#
# File c:\Users\ubach\.conda\envs\geospatial_ETC_DI_v4\lib\site-packages\geopandas\io\file.py:263, in _read_file(filename, bbox, mask, rows, engine, **kwargs)
#     259     return _read_file_fiona(
#     260         path_or_bytes, from_bytes, bbox=bbox, mask=mask, rows=rows, **kwargs
#     261     )
#     262 elif engine == "pyogrio":
# --> 263     return _read_file_pyogrio(
#     264         path_or_bytes, bbox=bbox, mask=mask, rows=rows, **kwargs
#     265     )
#     266 else:
#     267     raise ValueError(f"unknown engine '{engine}'")
#
# File c:\Users\ubach\.conda\envs\geospatial_ETC_DI_v4\lib\site-packages\geopandas\io\file.py:408, in _read_file_pyogrio(path_or_bytes, bbox, mask, rows, **kwargs)
#     405     kwargs["read_geometry"] = False
#     407 # TODO: if bbox is not None, check its CRS vs the CRS of the file
# --> 408 return pyogrio.read_dataframe(path_or_bytes, bbox=bbox, **kwargs)
#
# File c:\Users\ubach\.conda\envs\geospatial_ETC_DI_v4\lib\site-packages\pyogrio\geopandas.py:261, in read_dataframe(path_or_buffer, layer, encoding, columns, read_geometry, force_2d, skip_features, max_features, where, bbox, mask, fids, sql, sql_dialect, fid_as_index, use_arrow, on_invalid, arrow_to_pandas_kwargs, **kwargs)
#     256 if not use_arrow:
#     257     # For arrow, datetimes are read as is.
#     258     # For numpy IO, datetimes are read as string values to preserve timezone info
#     259     # as numpy does not directly support timezones.
#     260     kwargs["datetime_as_string"] = True
# --> 261 result = read_func(
#     262     path_or_buffer,
#     263     layer=layer,
#     264     encoding=encoding,
#     265     columns=columns,
#     266     read_geometry=read_geometry,
#     267     force_2d=gdal_force_2d,
#     268     skip_features=skip_features,
#     269     max_features=max_features,
#     270     where=where,
#     271     bbox=bbox,
#     272     mask=mask,
#     273     fids=fids,
#     274     sql=sql,
#     275     sql_dialect=sql_dialect,
#     276     return_fids=fid_as_index,
#     277     **kwargs,
#     278 )
#     280 if use_arrow:
#     281     meta, table = result
#
# File c:\Users\ubach\.conda\envs\geospatial_ETC_DI_v4\lib\site-packages\pyogrio\raw.py:287, in read_arrow(path_or_buffer, layer, encoding, columns, read_geometry, force_2d, skip_features, max_features, where, bbox, mask, fids, sql, sql_dialect, return_fids, **kwargs)
#     284     gdal_skip_features = skip_features
#     285     skip_features = 0
# --> 287 with open_arrow(
#     288     path_or_buffer,
#     289     layer=layer,
#     290     encoding=encoding,
#     291     columns=columns,
#     292     read_geometry=read_geometry,
#     293     force_2d=force_2d,
#     294     where=where,
#     295     bbox=bbox,
#     296     mask=mask,
#     297     fids=fids,
#     298     sql=sql,
#     299     sql_dialect=sql_dialect,
#     300     return_fids=return_fids,
#     301     skip_features=gdal_skip_features,
#     302     batch_size=batch_size,
#     303     use_pyarrow=True,
#     304     **kwargs,
#     305 ) as source:
#     306     meta, reader = source
#     308     if max_features is not None:
#
# File c:\Users\ubach\.conda\envs\geospatial_ETC_DI_v4\lib\contextlib.py:119, in _GeneratorContextManager.__enter__(self)
#     117 del self.args, self.kwds, self.func
#     118 try:
# --> 119     return next(self.gen)
#     120 except StopIteration:
#     121     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\ubach\.conda\envs\geospatial_ETC_DI_v4\lib\site-packages\pyogrio\_io.pyx:1495, in ogr_open_arrow()
#
# File c:\Users\ubach\.conda\envs\geospatial_ETC_DI_v4\lib\site-packages\pyogrio\_io.pyx:267, in pyogrio._io.get_ogr_layer()
#
# DataLayerError: Layer 'dbo.DF48_agg_NoiseContours_roadsInAgglomeration_Lden_Valid_LatestDelivery_Poly_CH-DE' could not be opened

# %%
CNTR_CODE
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[151], line 1
# ----> 1 CNTR_CODE
#
# NameError: name 'CNTR_CODE' is not defined

# %%
nqgreen
# Out:
#     code_2018     HDENS_CLST HDENS_NAME     HDENS_2011  POPL_2021 CNTR_CODE  \
# 0       14100  GEOSTAT21_031    Aalborg  GEOSTAT11_031   149041.0        DK
# 1       14100  GEOSTAT21_031    Aalborg  GEOSTAT11_031   149041.0        DK
# 2       14100  GEOSTAT21_031    Aalborg  GEOSTAT11_031   149041.0        DK
# 3       14100  GEOSTAT21_031    Aalborg  GEOSTAT11_031   149041.0        DK
# 4       14100  GEOSTAT21_031    Aalborg  GEOSTAT11_031   149041.0        DK
# ..        ...            ...        ...            ...        ...       ...
# 230     14100  GEOSTAT21_031    Aalborg  GEOSTAT11_031   149041.0        DK
# 231     14100  GEOSTAT21_031    Aalborg  GEOSTAT11_031   149041.0        DK
# 232     14100  GEOSTAT21_031    Aalborg  GEOSTAT11_031   149041.0        DK
# 233     14100  GEOSTAT21_031    Aalborg  GEOSTAT11_031   149041.0        DK
# 234     14100  GEOSTAT21_031    Aalborg  GEOSTAT11_031   149041.0        DK
#
#      MBRS_CODE_  SHAPE_AREA  SHAPE_LEN cityLocalName_unicode  noisy  \
# 0             1  48000000.0    34000.0               Aalborg      1
# 1             1  48000000.0    34000.0               Aalborg      1
# 2             1  48000000.0    34000.0               Aalborg      1
# 3             1  48000000.0    34000.0               Aalborg      1
# 4             1  48000000.0    34000.0               Aalborg      1
# ..          ...         ...        ...                   ...    ...
# 230           1  48000000.0    34000.0               Aalborg      0
# 231           1  48000000.0    34000.0               Aalborg      0
# 232           1  48000000.0    34000.0               Aalborg      0
# 233           1  48000000.0    34000.0               Aalborg      0
# 234           1  48000000.0    34000.0               Aalborg      0
#
#                                               geometry       area_m2  area_ha  \
# 0    POLYGON ((4314825.103 3772662.917, 4314839.580...  13615.396081     1.36
# 1    POLYGON ((4320012.522 3768572.875, 4320078.561...  17879.839167     1.79
# 2    POLYGON ((4313432.265 3768417.155, 4313404.075...   9323.289365     0.93
# 3    POLYGON ((4314000.000 3772486.379, 4314000.000...    879.274017     0.09
# 4    POLYGON ((4315304.802 3772479.787, 4315304.696...  10616.202135     1.06
# ..                                                 ...           ...      ...
# 230  POLYGON ((4320592.038 3768837.488, 4320601.592...   9471.949732     0.95
# 231  POLYGON ((4320428.214 3768777.119, 4320428.189...   2301.686242     0.23
# 232  POLYGON ((4320757.196 3768986.065, 4320749.557...  18966.463687     1.90
# 233  POLYGON ((4320428.507 3769185.324, 4320426.847...   1091.826572     0.11
# 234  MULTIPOLYGON (((4320737.803 3769447.954, 43207...   7362.020147     0.74
#
#      area_km2
# 0        0.01
# 1        0.02
# 2        0.01
# 3        0.00
# 4        0.01
# ..        ...
# 230      0.01
# 231      0.00
# 232      0.02
# 233      0.00
# 234      0.01
#
# [235 rows x 15 columns]

# %%
agglomerationId_identifier
# Out:
# array(['AG_DK_00_4'], dtype='<U10')

# %%
uc_names_ls = uc.HDENS_NAME.to_list()

# %%
def is_name_in_list(name):
    return name.lower() in [n.lower() for n in names_list]

# %%
uc_names_ls
# Out:
# ['Stockholm',
#  'Haninge',
#  'Södertälje',
#  'Tartu',
#  'Örebro',
#  'Stavanger',
#  'Norrköping',
#  'Linköping',
#  'Kristiansand',
#  'Jönköping / Huskvarna',
#  'Göteborg',
#  'Borås',
#  'Rīga',
#  'Aalborg',
#  'Växjö',
#  'Liepāja',
#  'Daugavpils',
#  'Panevėžys',
#  'Klaipėda',
#  'Århus',
#  'Helsingborg',
#  'København',
#  'Lund',
#  'Kaunas',
#  'Vilnius',
#  'Malmö',
#  'Odense',
#  'Gdynia',
#  'Flensburg',
#  'Suwałki',
#  'Galway',
#  'Gdańsk',
#  'Słupsk',
#  'Dublin',
#  'Elbląg',
#  'Blanchardstown',
#  'Ełk',
#  'Kiel',
#  'Koszalin',
#  'Olsztyn',
#  'Lütten Klein',
#  'Greifswald, Hansestadt',
#  'Rostock',
#  'Limerick',
#  'Neumünster',
#  'Lübeck',
#  'Białystok',
#  'Grudziądz',
#  'Łomża',
#  'Hamburg',
#  'Bremerhaven',
#  'Szczecin',
#  'Neu Wulmstorf / Neugraben-Fischbek / Hausbruch',
#  'Harburg',
#  'Kasztelanka',
#  'Bydgoszcz',
#  'Piła',
#  'Cork',
#  'Toruń',
#  'Groningen',
#  'Leeuwarden',
#  'Lüneburg',
#  'Oldenburg (Oldenburg)',
#  'Gröpelingen / Vegesack',
#  'Bremen',
#  'Inowrocław',
#  'Delmenhorst',
#  'Assen',
#  'Włocławek',
#  'Płock',
#  'Legionowo',
#  'Kobyłka-Kobylak / Wołomin',
#  'Gorzów Wielkopolski',
#  'Warszawa',
#  'Oulu / Uleåborg',
#  'Umeå',
#  'Trondheim',
#  'Jyväskylä',
#  'Tampere / Tammerfors',
#  'Lahti',
#  'Helsinki',
#  'Turku / Åbo',
#  'Narva',
#  'Bergen',
#  'Tallinn',
#  'Uppsala',
#  'Oslo',
#  'Västerås',
#  'Drammen',
#  'Täby',
#  'Hannover',
#  'Almelo',
#  'Wolfsburg',
#  'Deventer',
#  'Leiden',
#  'Hilversum',
#  'Hengelo',
#  'Osnabrück',
#  'Soest / Baarn',
#  'Apeldoorn',
#  'Amersfoort',
#  'Braunschweig',
#  'Enschede',
#  'Alphen aan den Rijn',
#  'Den Haag',
#  'Utrecht',
#  'Zoetermeer',
#  'Łódź',
#  'Magdeburg',
#  'Gouda',
#  'Hildesheim',
#  'Pijnacker / Berkel en Rodenrijs',
#  'Nieuwegein / IJsselstein',
#  'Ede',
#  'Veenendaal',
#  'Rotterdam',
#  'Zielona Góra',
#  'Arnhem',
#  'Bielefeld',
#  'Kalisz',
#  'Pabianice',
#  'Ridderkerk / Alblasserdam',
#  'Münster',
#  'Spijkenisse',
#  'Dordrecht',
#  'Radom',
#  'Nijmegen',
#  'Lublin',
#  'Gütersloh',
#  'Ostrów Wielkopolski',
#  'Düsseldorf',
#  'Wuppertal',
#  'Dunkerque',
#  'Mönchengladbach',
#  'Neuss',
#  'Görlitz',
#  'Gent',
#  'Lüdenscheid',
#  'Calais',
#  'Benrath',
#  'Solingen',
#  'Remscheid',
#  'Częstochowa',
#  'Mechelen',
#  'Dresden',
#  'Leverkusen',
#  'Sittard-Geleen',
#  'Köln',
#  'Vilvoorde / Machelen',
#  'Kortrijk',
#  'Bruxelles / Brussel',
#  'Boulogne-sur-mer',
#  'Leuven',
#  'Erfurt',
#  'Wałbrzych',
#  'Heerlen',
#  'Lille',
#  'Jena',
#  'Opole',
#  'Maastricht',
#  'Porz',
#  'Siegen',
#  'Gera',
#  'Chemnitz',
#  'Liberec',
#  'Aachen',
#  'Düren',
#  'Bonn',
#  'Liège',
#  'Ústí nad Labem',
#  'Górnośląski Związek Metropolitalny',
#  'Rzeszów',
#  'Verviers / Dison',
#  'Lens',
#  'Gliwice',
#  'La Louvière',
#  'Gießen',
#  'Mysłowice',
#  'Quaregnon / Frameries',
#  'Douai',
#  'Charleroi',
#  'Namur',
#  'Valenciennes',
#  'Fulda',
#  'Most',
#  'Chełm',
#  'Bocholt',
#  'Oss',
#  'Cottbus',
#  "'s-Hertogenbosch",
#  'Głogów',
#  'Piotrków Trybunalski',
#  'Paderborn',
#  'Hamm',
#  'Breda',
#  'Marl',
#  'Tilburg',
#  'Bergen op Zoom',
#  'Roosendaal',
#  'Ruhrgebiet',
#  'Lünen',
#  'Göttingen',
#  'Eindhoven',
#  'Helmond',
#  'Unna, Massen, Assein, Wickede',
#  'Lubin',
#  'Halle an der Saale',
#  'Moers / Rheinhausen',
#  'Duisburg',
#  'Oostende',
#  'Kapellen / Ekeren',
#  'Venlo',
#  'Hagen',
#  'Brugge',
#  'Leipzig',
#  'Krefeld',
#  'Iserlohn',
#  'Antwerpen',
#  'Legnica',
#  'Kielce',
#  'Wrocław',
#  'Kassel',
#  'aaa',
#  'Scharwoude / Heerhugowaard',
#  'Siedlce',
#  'Alkmaar',
#  'Hoorn',
#  'Poznań',
#  'Berlin',
#  'Beverwijk/Heemskerk',
#  'Purmerend',
#  'Amsterdam',
#  'Lelystad',
#  'Zwolle',
#  'Haarlem',
#  'Almere',
#  'Potsdam',
#  'Haarlemmermeer',
#  'Frankfurt (Oder)',
#  'Wiesbaden',
#  'Havířov',
#  'Hofheim am Taunus, Kriftel',
#  'Hrabuvka',
#  'Schweinfurt',
#  'Mainz',
#  'Rüsselsheim am Main',
#  'Aschaffenburg',
#  'Bayreuth',
#  'Le Havre',
#  'Bamberg',
#  'Darmstadt',
#  'Rouen',
#  'Olomouc',
#  'Trier',
#  'Würzburg',
#  'Plzeň',
#  'Luxembourg',
#  'Caen',
#  'Erlangen',
#  'Žilina',
#  'Esslingen am Neckar',
#  'Vaihingen / Möhringen',
#  'Sindelfingen',
#  'Göppingen',
#  'Strasbourg',
#  'Trnava',
#  'Miskolc',
#  'Nitra',
#  'Nyíregyháza',
#  'Iaşi',
#  'Lorient',
#  'Landshut',
#  'Satu Mare',
#  'Tübingen',
#  'Reutlingen',
#  'Baia Mare',
#  'Wien',
#  'Troyes',
#  'Le Mans',
#  'Bratislava',
#  'Ulm/Neu-Ulm',
#  'Linz',
#  'Vannes',
#  'Augsburg',
#  'Wels',
#  'Orléans',
#  'München',
#  'Piatra Neamţ',
#  'Debrecen',
#  'Colmar',
#  'Bistrita',
#  'Vaslui',
#  'Freiburg im Breisgau',
#  'Dunakeszi / Fót',
#  'Angers',
#  'Budapest',
#  'Saint-Nazaire',
#  'Gyõr',
#  'Tatabánya',
#  'Bacău',
#  'Rosenheim',
#  'Sopron',
#  'Rákosliget',
#  'Nantes',
#  'Salzburg',
#  'Mulhouse',
#  'Tours',
#  'Érd',
#  'Kempten (Allgäu)',
#  'Oradea',
#  'Szigethalom / Szigetszentmiklós',
#  'Belfort',
#  'Konstanz',
#  'Basel',
#  'Cluj-Napoca',
#  'Székesfehérvár',
#  'Târgu Mureş',
#  'Winterthur',
#  'Gebenstorf / Turgi / Obersiggenthal / Baden / Wettingen',
#  'Creil',
#  'Mannheim/Ludwigshafen',
#  'Fürth',
#  'Kaiserslautern',
#  'Martin',
#  'Reims',
#  'Heidelberg',
#  'Brno',
#  'Brest',
#  'Paris',
#  'Mantes en Yvelines',
#  'Košice',
#  'Saarbrücken',
#  'Poissy',
#  'Metz',
#  'Meaux',
#  'Heilbronn',
#  'Banská Bystrica',
#  'Lagny-sur-Marne / Montévrain',
#  'Les Clayes-sous-Bois',
#  'Maurepas / Montigny-le-Bretonneux',
#  'Regensburg',
#  'České Budějovice',
#  'Karlsruhe',
#  'Botoşani',
#  'Ludwigsburg',
#  'Quimper',
#  'Pforzheim',
#  'Stuttgart',
#  'Melun',
#  'Ingolstadt',
#  'Chartres',
#  'Nancy',
#  'Rennes',
#  'Tarnów',
#  'Chomutov / Jirkov',
#  'Kraków',
#  'Arras',
#  'Tychy',
#  'Koblenz',
#  'Hradec Králové',
#  'Jastrzębie-Zdrój',
#  'Cherbourg',
#  'Praha',
#  'Frankfurt am Main',
#  'Kladno',
#  'Pardubice',
#  'Bielsko-Biała',
#  'Bad Soden am Taunus / Kelkheim',
#  'Amiens',
#  'Ostrava',
#  'Hanau',
#  'Poruba',
#  'Nowy Sącz',
#  'Braşov',
#  'Thun',
#  'Arad',
#  'La Rochelle',
#  'Szeged',
#  'Sibiu',
#  'Klagenfurt',
#  'Maribor',
#  'Lausanne',
#  'Vevey / La Tour-de-Peilz / Montreux',
#  'Bolzano',
#  'Buzău',
#  'Pécs',
#  'Timişoara',
#  'Genève',
#  'Limoges',
#  'Ljubljana',
#  'Ploieşti',
#  'Udine',
#  'Trento',
#  'Râmnicu Vâlcea',
#  'Târgovişte',
#  'Clermont-Ferrand',
#  'Lugano',
#  'Pordenone',
#  'Zagreb',
#  'Annecy',
#  'Lyon',
#  'Piteşti',
#  'Osijek',
#  'Târgu Jiu',
#  'Constanţa',
#  'Lecco',
#  'Varese',
#  'Como',
#  'Saint-Priest / Mions',
#  'Trieste',
#  'Bucureşti',
#  'Bergamo',
#  'Shumen',
#  'Modena',
#  'Oviedo',
#  'Santiago de Compostela',
#  'Bologna',
#  'Lugo',
#  'Genova',
#  'Pleven',
#  'Ravenna',
#  'Santander',
#  'Savona',
#  'Veliko Tarnovo',
#  'Zadar',
#  'Forlì',
#  'Bilbao',
#  'Pontevedra',
#  'Bayonne',
#  'La Spezia',
#  'Rimini',
#  'Avignon',
#  'Irun',
#  'Toulouse',
#  'San Sebastián/Donostia',
#  'Burgas',
#  'Nimes',
#  'Sliven',
#  'Vigo',
#  'Pesaro',
#  'Ourense',
#  'Ponferrada',
#  'Prato',
#  'Pau',
#  'Montpellier',
#  'León',
#  'Firenze',
#  'Nice',
#  'Split',
#  'Pisa',
#  'Ancona',
#  'Vitoria/Gasteiz',
#  'Aix-en-Provence',
#  'Antibes',
#  'Stara Zagora',
#  'Cannes',
#  'Sofia',
#  'Béziers',
#  'Livorno',
#  'Martigues / Port-de-Bouc',
#  'Pamplona/Iruña',
#  'Marseille',
#  'Fréjus',
#  'Arezzo',
#  'Burgos',
#  'Braga',
#  'Plovdiv',
#  'Logroño',
#  'Toulon',
#  'Pazardzhik',
#  'La Seyne-sur-Mer / Sanary-sur-Mer',
#  'Póvoa de Varzim',
#  'Perugia',
#  'Haskovo',
#  'Palencia',
#  'Milano',
#  'Treviso',
#  'Gallarate',
#  'Chambery',
#  'Busto Arsizio',
#  'Brescia',
#  'Călărași',
#  'Saint-Etienne',
#  'Vicenza',
#  'Mestre',
#  'Novara',
#  'Padova',
#  'Venezia',
#  'Verona',
#  'Rijeka',
#  'Bordeaux',
#  'Slatina',
#  'Drobeta-Turnu Severin',
#  'Vigevano',
#  'Grenoble',
#  'Craiova',
#  'Pavia',
#  'Torino',
#  'Cremona',
#  'Dobrich',
#  'Ferrol',
#  'Ruse',
#  'Valence',
#  'Piacenza',
#  'A Coruña',
#  'Asti',
#  'Alessandria',
#  'Ferrara',
#  'Parma',
#  'Avilés',
#  'Carpi',
#  'Varna',
#  'Gijón',
#  "Reggio nell'Emilia",
#  'Bregenz',
#  'Zürich',
#  'Dijon',
#  'St. Gallen',
#  'Szombathely',
#  'Aarau / Buchs / Suhr / Oberentfelden',
#  'Kecskemét',
#  'Besançon',
#  'Innsbruck',
#  'Graz',
#  'Cham / Zug',
#  'Biel/Bienne',
#  'Luzern',
#  'Focşani',
#  'Poitiers',
#  'Bern',
#  'Galaţi',
#  'Fribourg',
#  'Tulcea',
#  'Brăila',
#  'Coimbra',
#  'Ajaccio',
#  'Igualada',
#  'Granollers',
#  'Terrassa',
#  'Sabadell',
#  'Mollet del Vallès',
#  'Mataró',
#  'Sant Cugat del Vallès/Rubí',
#  'Premià de Mar / Premià de Dalt / Vilassar / Cabrils',
#  'Barcelona',
#  'Ostia',
#  'Sant Boi de Llobregat',
#  'Viladecans',
#  'El Prat de Llobregat',
#  'Collado Villalba',
#  'Foggia',
#  'Castelldefels',
#  'Vilanova i la Geltrú',
#  'Reus',
#  'Anzio / Nettuno',
#  'Majadahonda',
#  'Almada',
#  'Barreiro',
#  'Amora',
#  'Castellón de la Plana/Castelló de la Plana',
#  'Larisa',
#  'Setúbal',
#  'Badajoz',
#  'Mérida',
#  'Ioannina',
#  'Volos',
#  "El Port de Sagunt / Canet d'En Berenguer",
#  'Valencia',
#  'Ciudad Real',
#  'Palma de Mallorca',
#  'Albacete',
#  'Cosenza',
#  'Gandia',
#  'Chalkida',
#  'Eivissa',
#  'Alcoi/Alcoy',
#  'Cagliari',
#  'Athina',
#  'Elda',
#  'Linares',
#  'Benidorm',
#  'Córdoba',
#  'Pátra',
#  'Alicante/Alacant',
#  'Elche/Elx',
#  'Huelva',
#  'Jaén',
#  'Sevilla',
#  'Tomares',
#  'Alcalá de Guadaíra',
#  'Murcia',
#  'Dos Hermanas',
#  'Alcantarilla',
#  'Torrevieja',
#  'Lorca',
#  'Messina',
#  'Reggio di Calabria',
#  'Cartagena',
#  'Palermo',
#  'Sanlúcar de Barrameda',
#  'Granada',
#  'Bagheria',
#  'Churriana de la Vega / Armilla',
#  'Lefkosia',
#  'Jerez de la Frontera',
#  'Trapani',
#  'Puerto de Santa María, El',
#  'Larnaka',
#  'Cádiz',
#  'San Fernando',
#  'Málaga',
#  'Kalamata',
#  'Chiclana de la Frontera',
#  'Acireale',
#  'Torremolinos',
#  'Catania',
#  'Marbella',
#  'Fuengirola',
#  'Almería',
#  'Thessaloniki',
#  'Guadalajara',
#  'Tarragona',
#  'Latina',
#  'Barletta',
#  'Madrid',
#  'Cerignola',
#  'Andria',
#  'Pozuelo de Alarcón',
#  'Molfetta',
#  'Alcalá de Henares',
#  'Torrejón de Ardoz',
#  'Bari',
#  'Coslada',
#  'Santa Monica',
#  'Fuenlabrada',
#  'Arganda del Rey',
#  'Parla',
#  'Pinto',
#  'Caserta',
#  'Valdemoro',
#  'Napoli',
#  'Talavera de la Reina',
#  'Katerini',
#  'Acerra',
#  'Altamura',
#  'Aranjuez',
#  'Pozzuoli / Bacoli',
#  'San Giuseppe Vesuviano',
#  'Brindisi',
#  'Matera',
#  'Toledo',
#  'Cáceres',
#  'Salerno',
#  'Sassari',
#  'Taranto',
#  'Battipaglia',
#  'Lisboa',
#  'Lecce',
#  'Porto',
#  'Perpignan',
#  'Arcozelo / Espinho',
#  'Grosseto',
#  'Zamora',
#  'Valladolid',
#  'Bastia',
#  'Huesca',
#  'Terni',
#  'Pescara',
#  'Zaragoza',
#  'Girona',
#  'Xanthi',
#  'Salamanca',
#  'Manresa',
#  'Lleida',
#  'Roma',
#  'Fonte Nuova / Colleverde / Setteville / Case Rosse',
#  'Serres',
#  'Tivoli / Villanova',
#  'Aguadulce / La Gangosa',
#  'Lemesos',
#  'Algeciras',
#  'Línea de la Concepción, La',
#  'Siracusa',
#  'Gela',
#  'Ceuta',
#  'Ragusa',
#  'Funchal',
#  'Chania',
#  'Irakleio',
#  'Melilla',
#  'Valletta',
#  'Santa Cruz de Tenerife',
#  'Puerto de la Cruz',
#  'Arrecife',
#  'Las Palmas',
#  'Telde',
#  'Santa Lucía de Tirajana']

# %%
# Out:
# Stockholm
# Stockholm
# Haninge
# Haninge
# Södertälje
# Sodertalje
# Tartu
# Tartu
# Örebro
# Orebro
# Stavanger
# Stavanger
# Norrköping
# Norrkoping
# Linköping
# Linkoping
# Kristiansand
# Kristiansand
# Jönköping / Huskvarna
# Jonkoping / Huskvarna
# Göteborg
# Goteborg
# Borås
# Boras
# Rīga
# Riga
# Aalborg
# Aalborg
# Växjö
# Vaxjo
# Liepāja
# Liepaja
# Daugavpils
# Daugavpils
# Panevėžys
# Panevezys
# Klaipėda
# Klaipeda
# Århus
# Arhus
# Helsingborg
# Helsingborg
# København
# Kobenhavn
# Lund
# Lund
# Kaunas
# Kaunas
# Vilnius
# Vilnius
# Malmö
# Malmo
# Odense
# Odense
# Gdynia
# Gdynia
# Flensburg
# Flensburg
# Suwałki
# Suwalki
# Galway
# Galway
# Gdańsk
# Gdansk
# Słupsk
# Slupsk
# Dublin
# Dublin
# Elbląg
# Elblag
# Blanchardstown
# Blanchardstown
# Ełk
# Elk
# Kiel
# Kiel
# Koszalin
# Koszalin
# Olsztyn
# Olsztyn
# Lütten Klein
# Lutten Klein
# Greifswald, Hansestadt
# Greifswald, Hansestadt
# Rostock
# Rostock
# Limerick
# Limerick
# Neumünster
# Neumunster
# Lübeck
# Lubeck
# Białystok
# Bialystok
# Grudziądz
# Grudziadz
# Łomża
# Lomza
# Hamburg
# Hamburg
# Bremerhaven
# Bremerhaven
# Szczecin
# Szczecin
# Neu Wulmstorf / Neugraben-Fischbek / Hausbruch
# Neu Wulmstorf / Neugraben-Fischbek / Hausbruch
# Harburg
# Harburg
# Kasztelanka
# Kasztelanka
# Bydgoszcz
# Bydgoszcz
# Piła
# Pila
# Cork
# Cork
# Toruń
# Torun
# Groningen
# Groningen
# Leeuwarden
# Leeuwarden
# Lüneburg
# Luneburg
# Oldenburg (Oldenburg)
# Oldenburg (Oldenburg)
# Gröpelingen / Vegesack
# Gropelingen / Vegesack
# Bremen
# Bremen
# Inowrocław
# Inowroclaw
# Delmenhorst
# Delmenhorst
# Assen
# Assen
# Włocławek
# Wloclawek
# Płock
# Plock
# Legionowo
# Legionowo
# Kobyłka-Kobylak / Wołomin
# Kobylka-Kobylak / Wolomin
# Gorzów Wielkopolski
# Gorzow Wielkopolski
# Warszawa
# Warszawa
# Oulu / Uleåborg
# Oulu / Uleaborg
# Umeå
# Umea
# Trondheim
# Trondheim
# Jyväskylä
# Jyvaskyla
# Tampere / Tammerfors
# Tampere / Tammerfors
# Lahti
# Lahti
# Helsinki
# Helsinki
# Turku / Åbo
# Turku / Abo
# Narva
# Terni
# Terni
# Pescara
# Pescara
# Zaragoza
# Zaragoza
# Girona
# Girona
# Xanthi
# Xanthi
# Salamanca
# Salamanca
# Manresa
# Manresa
# Lleida
# Lleida
# Roma
# Roma
# Fonte Nuova / Colleverde / Setteville / Case Rosse
# Fonte Nuova / Colleverde / Setteville / Case Rosse
# Serres
# Serres
# Tivoli / Villanova
# Tivoli / Villanova
# Aguadulce / La Gangosa
# Aguadulce / La Gangosa
# Lemesos
# Lemesos
# Algeciras
# Algeciras
# Línea de la Concepción, La
# Linea de la Concepcion, La
# Siracusa
# Siracusa
# Gela
# Gela
# Ceuta
# Ceuta
# Ragusa
# Ragusa
# Funchal
# Funchal
# Chania
# Chania
# Irakleio
# Irakleio
# Melilla
# Melilla
# Valletta
# Valletta
# Santa Cruz de Tenerife
# Santa Cruz de Tenerife
# Puerto de la Cruz
# Puerto de la Cruz
# Arrecife
# Arrecife
# Las Palmas
# Las Palmas
# Telde
# Telde
# Santa Lucía de Tirajana
# Santa Lucia de Tirajana

# %%
uc_unicode_ls
# Out:
# ['Stockholm',
#  'Haninge',
#  'Sodertalje',
#  'Tartu',
#  'Orebro',
#  'Stavanger',
#  'Norrkoping',
#  'Linkoping',
#  'Kristiansand',
#  'Jonkoping / Huskvarna',
#  'Goteborg',
#  'Boras',
#  'Riga',
#  'Aalborg',
#  'Vaxjo',
#  'Liepaja',
#  'Daugavpils',
#  'Panevezys',
#  'Klaipeda',
#  'Arhus',
#  'Helsingborg',
#  'Kobenhavn',
#  'Lund',
#  'Kaunas',
#  'Vilnius',
#  'Malmo',
#  'Odense',
#  'Gdynia',
#  'Flensburg',
#  'Suwalki',
#  'Galway',
#  'Gdansk',
#  'Slupsk',
#  'Dublin',
#  'Elblag',
#  'Blanchardstown',
#  'Elk',
#  'Kiel',
#  'Koszalin',
#  'Olsztyn',
#  'Lutten Klein',
#  'Greifswald, Hansestadt',
#  'Rostock',
#  'Limerick',
#  'Neumunster',
#  'Lubeck',
#  'Bialystok',
#  'Grudziadz',
#  'Lomza',
#  'Hamburg',
#  'Bremerhaven',
#  'Szczecin',
#  'Neu Wulmstorf / Neugraben-Fischbek / Hausbruch',
#  'Harburg',
#  'Kasztelanka',
#  'Bydgoszcz',
#  'Pila',
#  'Cork',
#  'Torun',
#  'Groningen',
#  'Leeuwarden',
#  'Luneburg',
#  'Oldenburg (Oldenburg)',
#  'Gropelingen / Vegesack',
#  'Bremen',
#  'Inowroclaw',
#  'Delmenhorst',
#  'Assen',
#  'Wloclawek',
#  'Plock',
#  'Legionowo',
#  'Kobylka-Kobylak / Wolomin',
#  'Gorzow Wielkopolski',
#  'Warszawa',
#  'Oulu / Uleaborg',
#  'Umea',
#  'Trondheim',
#  'Jyvaskyla',
#  'Tampere / Tammerfors',
#  'Lahti',
#  'Helsinki',
#  'Turku / Abo',
#  'Narva',
#  'Bergen',
#  'Tallinn',
#  'Uppsala',
#  'Oslo',
#  'Vasteras',
#  'Drammen',
#  'Taby',
#  'Hannover',
#  'Almelo',
#  'Wolfsburg',
#  'Deventer',
#  'Leiden',
#  'Hilversum',
#  'Hengelo',
#  'Osnabruck',
#  'Soest / Baarn',
#  'Apeldoorn',
#  'Amersfoort',
#  'Braunschweig',
#  'Enschede',
#  'Alphen aan den Rijn',
#  'Den Haag',
#  'Utrecht',
#  'Zoetermeer',
#  'Lodz',
#  'Magdeburg',
#  'Gouda',
#  'Hildesheim',
#  'Pijnacker / Berkel en Rodenrijs',
#  'Nieuwegein / IJsselstein',
#  'Ede',
#  'Veenendaal',
#  'Rotterdam',
#  'Zielona Gora',
#  'Arnhem',
#  'Bielefeld',
#  'Kalisz',
#  'Pabianice',
#  'Ridderkerk / Alblasserdam',
#  'Munster',
#  'Spijkenisse',
#  'Dordrecht',
#  'Radom',
#  'Nijmegen',
#  'Lublin',
#  'Gutersloh',
#  'Ostrow Wielkopolski',
#  'Dusseldorf',
#  'Wuppertal',
#  'Dunkerque',
#  'Monchengladbach',
#  'Neuss',
#  'Gorlitz',
#  'Gent',
#  'Ludenscheid',
#  'Calais',
#  'Benrath',
#  'Solingen',
#  'Remscheid',
#  'Czestochowa',
#  'Mechelen',
#  'Dresden',
#  'Leverkusen',
#  'Sittard-Geleen',
#  'Koln',
#  'Vilvoorde / Machelen',
#  'Kortrijk',
#  'Bruxelles / Brussel',
#  'Boulogne-sur-mer',
#  'Leuven',
#  'Erfurt',
#  'Walbrzych',
#  'Heerlen',
#  'Lille',
#  'Jena',
#  'Opole',
#  'Maastricht',
#  'Porz',
#  'Siegen',
#  'Gera',
#  'Chemnitz',
#  'Liberec',
#  'Aachen',
#  'Duren',
#  'Bonn',
#  'Liege',
#  'Usti nad Labem',
#  'Gornoslaski Zwiazek Metropolitalny',
#  'Rzeszow',
#  'Verviers / Dison',
#  'Lens',
#  'Gliwice',
#  'La Louviere',
#  'Giessen',
#  'Myslowice',
#  'Quaregnon / Frameries',
#  'Douai',
#  'Charleroi',
#  'Namur',
#  'Valenciennes',
#  'Fulda',
#  'Most',
#  'Chelm',
#  'Bocholt',
#  'Oss',
#  'Cottbus',
#  "'s-Hertogenbosch",
#  'Glogow',
#  'Piotrkow Trybunalski',
#  'Paderborn',
#  'Hamm',
#  'Breda',
#  'Marl',
#  'Tilburg',
#  'Bergen op Zoom',
#  'Roosendaal',
#  'Ruhrgebiet',
#  'Lunen',
#  'Gottingen',
#  'Eindhoven',
#  'Helmond',
#  'Unna, Massen, Assein, Wickede',
#  'Lubin',
#  'Halle an der Saale',
#  'Moers / Rheinhausen',
#  'Duisburg',
#  'Oostende',
#  'Kapellen / Ekeren',
#  'Venlo',
#  'Hagen',
#  'Brugge',
#  'Leipzig',
#  'Krefeld',
#  'Iserlohn',
#  'Antwerpen',
#  'Legnica',
#  'Kielce',
#  'Wroclaw',
#  'Kassel',
#  'aaa',
#  'Scharwoude / Heerhugowaard',
#  'Siedlce',
#  'Alkmaar',
#  'Hoorn',
#  'Poznan',
#  'Berlin',
#  'Beverwijk/Heemskerk',
#  'Purmerend',
#  'Amsterdam',
#  'Lelystad',
#  'Zwolle',
#  'Haarlem',
#  'Almere',
#  'Potsdam',
#  'Haarlemmermeer',
#  'Frankfurt (Oder)',
#  'Wiesbaden',
#  'Havirov',
#  'Hofheim am Taunus, Kriftel',
#  'Hrabuvka',
#  'Schweinfurt',
#  'Mainz',
#  'Russelsheim am Main',
#  'Aschaffenburg',
#  'Bayreuth',
#  'Le Havre',
#  'Bamberg',
#  'Darmstadt',
#  'Rouen',
#  'Olomouc',
#  'Trier',
#  'Wurzburg',
#  'Plzen',
#  'Luxembourg',
#  'Caen',
#  'Erlangen',
#  'Zilina',
#  'Esslingen am Neckar',
#  'Vaihingen / Mohringen',
#  'Sindelfingen',
#  'Goppingen',
#  'Strasbourg',
#  'Trnava',
#  'Miskolc',
#  'Nitra',
#  'Nyiregyhaza',
#  'Iasi',
#  'Lorient',
#  'Landshut',
#  'Satu Mare',
#  'Tubingen',
#  'Reutlingen',
#  'Baia Mare',
#  'Wien',
#  'Troyes',
#  'Le Mans',
#  'Bratislava',
#  'Ulm/Neu-Ulm',
#  'Linz',
#  'Vannes',
#  'Augsburg',
#  'Wels',
#  'Orleans',
#  'Munchen',
#  'Piatra Neamt',
#  'Debrecen',
#  'Colmar',
#  'Bistrita',
#  'Vaslui',
#  'Freiburg im Breisgau',
#  'Dunakeszi / Fot',
#  'Angers',
#  'Budapest',
#  'Saint-Nazaire',
#  'Gyor',
#  'Tatabanya',
#  'Bacau',
#  'Rosenheim',
#  'Sopron',
#  'Rakosliget',
#  'Nantes',
#  'Salzburg',
#  'Mulhouse',
#  'Tours',
#  'Erd',
#  'Kempten (Allgau)',
#  'Oradea',
#  'Szigethalom / Szigetszentmiklos',
#  'Belfort',
#  'Konstanz',
#  'Basel',
#  'Cluj-Napoca',
#  'Szekesfehervar',
#  'Targu Mures',
#  'Winterthur',
#  'Gebenstorf / Turgi / Obersiggenthal / Baden / Wettingen',
#  'Creil',
#  'Mannheim/Ludwigshafen',
#  'Furth',
#  'Kaiserslautern',
#  'Martin',
#  'Reims',
#  'Heidelberg',
#  'Brno',
#  'Brest',
#  'Paris',
#  'Mantes en Yvelines',
#  'Kosice',
#  'Saarbrucken',
#  'Poissy',
#  'Metz',
#  'Meaux',
#  'Heilbronn',
#  'Banska Bystrica',
#  'Lagny-sur-Marne / Montevrain',
#  'Les Clayes-sous-Bois',
#  'Maurepas / Montigny-le-Bretonneux',
#  'Regensburg',
#  'Ceske Budejovice',
#  'Karlsruhe',
#  'Botosani',
#  'Ludwigsburg',
#  'Quimper',
#  'Pforzheim',
#  'Stuttgart',
#  'Melun',
#  'Ingolstadt',
#  'Chartres',
#  'Nancy',
#  'Rennes',
#  'Tarnow',
#  'Chomutov / Jirkov',
#  'Krakow',
#  'Arras',
#  'Tychy',
#  'Koblenz',
#  'Hradec Kralove',
#  'Jastrzebie-Zdroj',
#  'Cherbourg',
#  'Praha',
#  'Frankfurt am Main',
#  'Kladno',
#  'Pardubice',
#  'Bielsko-Biala',
#  'Bad Soden am Taunus / Kelkheim',
#  'Amiens',
#  'Ostrava',
#  'Hanau',
#  'Poruba',
#  'Nowy Sacz',
#  'Brasov',
#  'Thun',
#  'Arad',
#  'La Rochelle',
#  'Szeged',
#  'Sibiu',
#  'Klagenfurt',
#  'Maribor',
#  'Lausanne',
#  'Vevey / La Tour-de-Peilz / Montreux',
#  'Bolzano',
#  'Buzau',
#  'Pecs',
#  'Timisoara',
#  'Geneve',
#  'Limoges',
#  'Ljubljana',
#  'Ploiesti',
#  'Udine',
#  'Trento',
#  'Ramnicu Valcea',
#  'Targoviste',
#  'Clermont-Ferrand',
#  'Lugano',
#  'Pordenone',
#  'Zagreb',
#  'Annecy',
#  'Lyon',
#  'Pitesti',
#  'Osijek',
#  'Targu Jiu',
#  'Constanta',
#  'Lecco',
#  'Varese',
#  'Como',
#  'Saint-Priest / Mions',
#  'Trieste',
#  'Bucuresti',
#  'Bergamo',
#  'Shumen',
#  'Modena',
#  'Oviedo',
#  'Santiago de Compostela',
#  'Bologna',
#  'Lugo',
#  'Genova',
#  'Pleven',
#  'Ravenna',
#  'Santander',
#  'Savona',
#  'Veliko Tarnovo',
#  'Zadar',
#  'Forli',
#  'Bilbao',
#  'Pontevedra',
#  'Bayonne',
#  'La Spezia',
#  'Rimini',
#  'Avignon',
#  'Irun',
#  'Toulouse',
#  'San Sebastian/Donostia',
#  'Burgas',
#  'Nimes',
#  'Sliven',
#  'Vigo',
#  'Pesaro',
#  'Ourense',
#  'Ponferrada',
#  'Prato',
#  'Pau',
#  'Montpellier',
#  'Leon',
#  'Firenze',
#  'Nice',
#  'Split',
#  'Pisa',
#  'Ancona',
#  'Vitoria/Gasteiz',
#  'Aix-en-Provence',
#  'Antibes',
#  'Stara Zagora',
#  'Cannes',
#  'Sofia',
#  'Beziers',
#  'Livorno',
#  'Martigues / Port-de-Bouc',
#  'Pamplona/Iruna',
#  'Marseille',
#  'Frejus',
#  'Arezzo',
#  'Burgos',
#  'Braga',
#  'Plovdiv',
#  'Logrono',
#  'Toulon',
#  'Pazardzhik',
#  'La Seyne-sur-Mer / Sanary-sur-Mer',
#  'Povoa de Varzim',
#  'Perugia',
#  'Haskovo',
#  'Palencia',
#  'Milano',
#  'Treviso',
#  'Gallarate',
#  'Chambery',
#  'Busto Arsizio',
#  'Brescia',
#  'Calarasi',
#  'Saint-Etienne',
#  'Vicenza',
#  'Mestre',
#  'Novara',
#  'Padova',
#  'Venezia',
#  'Verona',
#  'Rijeka',
#  'Bordeaux',
#  'Slatina',
#  'Drobeta-Turnu Severin',
#  'Vigevano',
#  'Grenoble',
#  'Craiova',
#  'Pavia',
#  'Torino',
#  'Cremona',
#  'Dobrich',
#  'Ferrol',
#  'Ruse',
#  'Valence',
#  'Piacenza',
#  'A Coruna',
#  'Asti',
#  'Alessandria',
#  'Ferrara',
#  'Parma',
#  'Aviles',
#  'Carpi',
#  'Varna',
#  'Gijon',
#  "Reggio nell'Emilia",
#  'Bregenz',
#  'Zurich',
#  'Dijon',
#  'St. Gallen',
#  'Szombathely',
#  'Aarau / Buchs / Suhr / Oberentfelden',
#  'Kecskemet',
#  'Besancon',
#  'Innsbruck',
#  'Graz',
#  'Cham / Zug',
#  'Biel/Bienne',
#  'Luzern',
#  'Focsani',
#  'Poitiers',
#  'Bern',
#  'Galati',
#  'Fribourg',
#  'Tulcea',
#  'Braila',
#  'Coimbra',
#  'Ajaccio',
#  'Igualada',
#  'Granollers',
#  'Terrassa',
#  'Sabadell',
#  'Mollet del Valles',
#  'Mataro',
#  'Sant Cugat del Valles/Rubi',
#  'Premia de Mar / Premia de Dalt / Vilassar / Cabrils',
#  'Barcelona',
#  'Ostia',
#  'Sant Boi de Llobregat',
#  'Viladecans',
#  'El Prat de Llobregat',
#  'Collado Villalba',
#  'Foggia',
#  'Castelldefels',
#  'Vilanova i la Geltru',
#  'Reus',
#  'Anzio / Nettuno',
#  'Majadahonda',
#  'Almada',
#  'Barreiro',
#  'Amora',
#  'Castellon de la Plana/Castello de la Plana',
#  'Larisa',
#  'Setubal',
#  'Badajoz',
#  'Merida',
#  'Ioannina',
#  'Volos',
#  "El Port de Sagunt / Canet d'En Berenguer",
#  'Valencia',
#  'Ciudad Real',
#  'Palma de Mallorca',
#  'Albacete',
#  'Cosenza',
#  'Gandia',
#  'Chalkida',
#  'Eivissa',
#  'Alcoi/Alcoy',
#  'Cagliari',
#  'Athina',
#  'Elda',
#  'Linares',
#  'Benidorm',
#  'Cordoba',
#  'Patra',
#  'Alicante/Alacant',
#  'Elche/Elx',
#  'Huelva',
#  'Jaen',
#  'Sevilla',
#  'Tomares',
#  'Alcala de Guadaira',
#  'Murcia',
#  'Dos Hermanas',
#  'Alcantarilla',
#  'Torrevieja',
#  'Lorca',
#  'Messina',
#  'Reggio di Calabria',
#  'Cartagena',
#  'Palermo',
#  'Sanlucar de Barrameda',
#  'Granada',
#  'Bagheria',
#  'Churriana de la Vega / Armilla',
#  'Lefkosia',
#  'Jerez de la Frontera',
#  'Trapani',
#  'Puerto de Santa Maria, El',
#  'Larnaka',
#  'Cadiz',
#  'San Fernando',
#  'Malaga',
#  'Kalamata',
#  'Chiclana de la Frontera',
#  'Acireale',
#  'Torremolinos',
#  'Catania',
#  'Marbella',
#  'Fuengirola',
#  'Almeria',
#  'Thessaloniki',
#  'Guadalajara',
#  'Tarragona',
#  'Latina',
#  'Barletta',
#  'Madrid',
#  'Cerignola',
#  'Andria',
#  'Pozuelo de Alarcon',
#  'Molfetta',
#  'Alcala de Henares',
#  'Torrejon de Ardoz',
#  'Bari',
#  'Coslada',
#  'Santa Monica',
#  'Fuenlabrada',
#  'Arganda del Rey',
#  'Parla',
#  'Pinto',
#  'Caserta',
#  'Valdemoro',
#  'Napoli',
#  'Talavera de la Reina',
#  'Katerini',
#  'Acerra',
#  'Altamura',
#  'Aranjuez',
#  'Pozzuoli / Bacoli',
#  'San Giuseppe Vesuviano',
#  'Brindisi',
#  'Matera',
#  'Toledo',
#  'Caceres',
#  'Salerno',
#  'Sassari',
#  'Taranto',
#  'Battipaglia',
#  'Lisboa',
#  'Lecce',
#  'Porto',
#  'Perpignan',
#  'Arcozelo / Espinho',
#  'Grosseto',
#  'Zamora',
#  'Valladolid',
#  'Bastia',
#  'Huesca',
#  'Terni',
#  'Pescara',
#  'Zaragoza',
#  'Girona',
#  'Xanthi',
#  'Salamanca',
#  'Manresa',
#  'Lleida',
#  'Roma',
#  'Fonte Nuova / Colleverde / Setteville / Case Rosse',
#  'Serres',
#  'Tivoli / Villanova',
#  'Aguadulce / La Gangosa',
#  'Lemesos',
#  'Algeciras',
#  'Linea de la Concepcion, La',
#  'Siracusa',
#  'Gela',
#  'Ceuta',
#  'Ragusa',
#  'Funchal',
#  'Chania',
#  'Irakleio',
#  'Melilla',
#  'Valletta',
#  'Santa Cruz de Tenerife',
#  'Puerto de la Cruz',
#  'Arrecife',
#  'Las Palmas',
#  'Telde',
#  'Santa Lucia de Tirajana']

# %%
# Sample data creation
data = {
    'name': ['Café', 'naïve', 'résumé', 'Alice', 'Bob', 'Charlie'],
    'geometry': [None, None, None, None, None, None]  # Placeholder geometries
}
gdf = gpd.GeoDataFrame(data)

# Define the list of names to check
names_list = ['Cafe', 'naive', 'resume', 'Alice', 'Bob']

# Define the function to unidecode the name and check if it is in the list
def is_unidecoded_name_in_list(name):
    unidecoded_name = unidecode(name)
    return unidecoded_name in names_list

# Apply the function to create a new column
gdf['is_name_in_list'] = gdf['name'].apply(is_unidecoded_name_in_list)

# Optionally, inspect the result
print(gdf[['name', 'is_name_in_list']])

# %%
def is_unidecoded_name_in_list(name):
    unidecoded_name = unidecode(name)
    return unidecoded_name in uc_names_ls

# %%
uc.HDENS_NAME.apply(is_unidecoded_name_in_list)
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 692     True
# 693     True
# 694     True
# 695     True
# 696    False
# Name: HDENS_NAME, Length: 697, dtype: bool

# %%
counter= 1
agl_error_ls = []
# Loop through test cities
for cityLocalName in cities_ls:
    print(str(cityLocalName))
    print(counter)
    start_time = datetime.now()
    #print(str(start_time))

    cityLocalName_unicode = unidecode(cityLocalName)        
    uc_city = uc.query(f'cityLocalName_unicode == "{cityLocalName_unicode}"')
    if uc_city.empty:
        print ('error in agl city')
        agl_error_ls.append(cityLocalName_unicode)
    else:
        ctry_code = uc_city.CNTR_CODE.values.astype(str)[0]
        print(ctry_code)
    counter = counter+ 1
# Out:
# Aalborg
# 1
# DK
# Aarhus
# 2
# error in agl city
# AggloLux
# 3
# error in agl city
# Agglomeration Amsterdam-Haarlem
# 4
# error in agl city
# Agglomeration Rotterdam-Dordrecht
# 5
# error in agl city
# Agglomeration Utrecht
# 6
# error in agl city
# Agglomeration Zwolle
# 7
# error in agl city
# AggloSud
# 8
# error in agl city
# AMADORA
# 9
# error in agl city
# Antwerp
# 10
# error in agl city
# Basel
# 11
# CH-DE
# Bergen
# 12
# NO
# Berlin
# 13
# DE
# Bern
# 14
# CH
# Bilbao
# 15
# ES
# Bonn
# 16
# DE
# Bordeaux
# 17
# FR
# Bremen
# 18
# DE
# Brest
# 19
# FR
# Brno
# 20
# CZ
# Brussels-Capital
# 21
# error in agl city
# Caen
# 22
# FR
# City of Rijeka
# 23
# error in agl city
# City of Split
# 24
# error in agl city
# City of Zagreb
# 25
# error in agl city
# Clermont-Ferrand
# 26
# FR
# Cologne
# 27
# error in agl city
# Copenhagen
# 28
# error in agl city
# Cork
# 29
# IE
# Cracow
# 30
# error in agl city
# Darmstadt
# 31
# DE
# Dublin
# 32
# IE
# Espoo
# 33
# error in agl city
# Fredrikstad/Sarpsborg
# 34
# error in agl city
# GDAŃSK
# 35
# error in agl city
# Geneva
# 36
# error in agl city
# Ghent
# 37
# error in agl city
# Gothenburg
# 38
# error in agl city
# Graz
# 39
# AT
# Hamburg
# 40
# DE
# Helsingborg
# 41
# SE
# Helsinki
# 42
# FI
# Innsbruck
# 43
# AT
# Kaunas
# 44
# LT
# Kuopio
# 45
# error in agl city
# Larnaca
# 46
# error in agl city
# Lausanne
# 47
# CH
# León
# 48
# ES
# Leuven
# 49
# BE
# Liberec
# 50
# CZ
# Liege
# 51
# BE
# Limassol
# 52
# error in agl city
# Limerick
# 53
# IE
# Linkoping
# 54
# SE
# Linz
# 55
# AT
# LISBOA
# 56
# error in agl city
# Lund
# 57
# SE
# Lyon
# 58
# FR
# Madrid
# 59
# ES
# Malmo
# 60
# SE
# Malta Noise Agglomeration
# 61
# error in agl city
# Marseille
# 62
# FR
# MATOSINHOS
# 63
# error in agl city
# Nacka
# 64
# error in agl city
# Nice
# 65
# FR
# Nicosia
# 66
# error in agl city
# Norrkoping
# 67
# SE
# Odense
# 68
# DK
# ODIVELAS
# 69
# error in agl city
# OEIRAS
# 70
# error in agl city
# Olomouc
# 71
# CZ
# Oslo
# 72
# NO
# Ostrava
# 73
# CZ
# Oulu
# 74
# error in agl city
# Pafos
# 75
# error in agl city
# Pilsen
# 76
# error in agl city
# PORTO
# 77
# error in agl city
# Prague
# 78
# error in agl city
# Reims
# 79
# FR
# Riga
# 80
# LV
# Salzburg
# 81
# AT
# Stavanger/Sandnes
# 82
# error in agl city
# Stockholm
# 83
# SE
# Tallinn
# 84
# EE
# Tampere
# 85
# error in agl city
# Tartu city
# 86
# error in agl city
# Trondheim
# 87
# NO
# Turku
# 88
# error in agl city
# Uppsala
# 89
# SE
# Usti nad Labem - Teplice
# 90
# error in agl city
# València
# 91
# ES
# Vigo
# 92
# ES
# Vitoria-Gasteiz
# 93
# error in agl city
# Warsaw
# 94
# error in agl city
# Wien
# 95
# AT
# Włocławek
# 96
# PL
# Wroclaw
# 97
# PL
# ZABRZE
# 98
# error in agl city
# Zielona Gora
# 99
# PL
# Zurich
# 100
# CH

# %%
counter= 1
agl_error_ls = []
# Loop through test cities
for cityLocalName in cities_ls:
    print(str(cityLocalName))
    print(counter)
    start_time = datetime.now()
    #print(str(start_time))

    cityLocalName_unicode = unidecode(cityLocalName)        
    uc_city = uc.query(f'cityLocalName_unicode == "{cityLocalName_unicode}"')
    if uc_city.empty:
        print ('error in agl city')
        agl_error_ls.append(cityLocalName_unicode)
    else:
        ctry_code = uc_city.CNTR_CODE.values.astype(str)[0]
        print(ctry_code)
    counter = counter+ 1

# %%
len(agl_error_ls)
# Out:
# 45

# %%
cityLocalName_unicode
# Out:
# 'Aarhus'

# %%
uc.query(f'cityLocalName_unicode == "{cityLocalName_unicode}"')
# Out:
# Empty GeoDataFrame
# Columns: [HDENS_CLST, HDENS_NAME, HDENS_2011, POPL_2021, CNTR_CODE, MBRS_CODE_, SHAPE_AREA, SHAPE_LEN, geometry, cityLocalName_unicode]
# Index: []

# %%
cityLocalName_unicode
# Out:
# 'Aarhus'

# %%
uc.query(f'HDENS_NAME == "{cityLocalName_unicode}"')
# Out:
# Empty GeoDataFrame
# Columns: [HDENS_CLST, HDENS_NAME, HDENS_2011, POPL_2021, CNTR_CODE, MBRS_CODE_, SHAPE_AREA, SHAPE_LEN, geometry]
# Index: []

# %%
uc.query(f'HDENS_NAME == "{cityLocalName_unicode}"')
# Out:
#        HDENS_CLST HDENS_NAME     HDENS_2011  POPL_2021 CNTR_CODE  MBRS_CODE_  \
# 13  GEOSTAT21_031    Aalborg  GEOSTAT11_031   149041.0        DK           1
#
#     SHAPE_AREA  SHAPE_LEN                                           geometry
# 13  48000000.0    34000.0  POLYGON ((4320000.000 3767000.000, 4318000.000...

# %%
uc_city
# Out:
# Empty GeoDataFrame
# Columns: [HDENS_CLST, HDENS_NAME, HDENS_2011, POPL_2021, CNTR_CODE, MBRS_CODE_, SHAPE_AREA, SHAPE_LEN, geometry]
# Index: []

# %%
uc.query('CNTR_CODE=="DK"')[1:2].HDENS_NAME.values.astype(str)[0]
# Out:
# 'Århus'

# %%
from unidecode import unidecode

# %%
unidecode(uc.query('CNTR_CODE=="DK"')[1:2].HDENS_NAME.values.astype(str)[0])
# Out:
# 'Arhus'

# %%
uc.head()
# Out:
#       HDENS_CLST  HDENS_NAME     HDENS_2011  POPL_2021 CNTR_CODE  MBRS_CODE_  \
# 0  GEOSTAT21_018   Stockholm  GEOSTAT11_018  1462910.0        SE           1
# 1  GEOSTAT21_019     Haninge  GEOSTAT11_019    94485.0        SE           1
# 2  GEOSTAT21_020  Södertälje  GEOSTAT11_020    74475.0        SE           1
# 3  GEOSTAT21_021       Tartu  GEOSTAT11_021    84168.0        EE           2
# 4  GEOSTAT21_022      Örebro  GEOSTAT11_022    92695.0        SE           1
#
#     SHAPE_AREA  SHAPE_LEN                                           geometry  \
# 0  342000000.0   162000.0  POLYGON ((4775000.000 4038000.000, 4774000.000...
# 1   36000000.0    38000.0  POLYGON ((4787000.000 4033000.000, 4786000.000...
# 2   22000000.0    24000.0  POLYGON ((4756000.000 4031000.000, 4755000.000...
# 3   24000000.0    24000.0  POLYGON ((5292000.000 4030000.000, 5290000.000...
# 4   27000000.0    26000.0  POLYGON ((4620000.000 4027000.000, 4618000.000...
#
#   cityLocalName_unicode
# 0             Stockholm
# 1               Haninge
# 2            Sodertalje
# 3                 Tartu
# 4                Orebro

# %%
uc.query('CNTR_CODE=="DK"')
# Out:
#        HDENS_CLST HDENS_NAME     HDENS_2011  POPL_2021 CNTR_CODE  MBRS_CODE_  \
# 13  GEOSTAT21_031    Aalborg  GEOSTAT11_031   149041.0        DK           1
# 19  GEOSTAT21_047      Århus  GEOSTAT11_047   245448.0        DK           1
# 21  GEOSTAT21_903  København           None  1360930.0        DK           1
# 26  GEOSTAT21_060     Odense  GEOSTAT11_060   135431.0        DK           1
#
#      SHAPE_AREA  SHAPE_LEN                                           geometry  \
# 13   48000000.0    34000.0  POLYGON ((4320000.000 3767000.000, 4318000.000...
# 19   72000000.0    58000.0  POLYGON ((4334000.000 3666000.000, 4334000.000...
# 21  299000000.0   130000.0  POLYGON ((4463000.000 3607000.000, 4463000.000...
# 26   48000000.0    42000.0  POLYGON ((4347000.000 3584000.000, 4346000.000...
#
#    cityLocalName_unicode
# 13               Aalborg
# 19                 Arhus
# 21             Kobenhavn
# 26                Odense

# %%
uc.query(f'cityLocalName_unicode=="Aarhus"')
# Out:
# Empty GeoDataFrame
# Columns: [HDENS_CLST, HDENS_NAME, HDENS_2011, POPL_2021, CNTR_CODE, MBRS_CODE_, SHAPE_AREA, SHAPE_LEN, geometry, cityLocalName_unicode]
# Index: []

# %%
uc.query(f'cityLocalName_unicode=="{cityLocalName_unicode}"')
# Out:
# Empty GeoDataFrame
# Columns: [HDENS_CLST, HDENS_NAME, HDENS_2011, POPL_2021, CNTR_CODE, MBRS_CODE_, SHAPE_AREA, SHAPE_LEN, geometry, cityLocalName_unicode]
# Index: []

# %%
cityLocalName_unicode
# Out:
# 'Aarhus'

# %%
uc.query('CNTR_CODE=="DK"')

# %%
uc['cityLocalName_unicode'] = uc_unicode_ls

# %%
ctry_code = uc_city.CNTR_CODE.values.astype(str)[0]

# %%
cities_ls[0]
# Out:
# 'Aarhus'

# %%
cityLocalName
# Out:
# 'Aarhus'

# %%
uc.query(f'HDENS_NAME == "Aalborg"')
# Out:
#        HDENS_CLST HDENS_NAME     HDENS_2011  POPL_2021 CNTR_CODE  MBRS_CODE_  \
# 13  GEOSTAT21_031    Aalborg  GEOSTAT11_031   149041.0        DK           1
#
#     SHAPE_AREA  SHAPE_LEN                                           geometry
# 13  48000000.0    34000.0  POLYGON ((4320000.000 3767000.000, 4318000.000...

# %%
uc.query(f'HDENS_NAME == "Aalborg"').CNTR_CODE.values.astype(str)
# Out:
# array(['DK'], dtype='<U2')

# %%
counter= 1
agl_error_ls = []

# Loop through test cities
for cityLocalName in cities_ls:
    print(str(cityLocalName))
    print(counter)
    start_time = datetime.now()
    print(str(start_time))

    cityLocalName_unicode = unidecode(cityLocalName)        
    uc_city = uc.query(f'cityLocalName_unicode == "{cityLocalName_unicode}"')
    if uc_city.empty:
        print ('error in agl city')
        agl_error_ls.append(cityLocalName_unicode)
    
    else:
        ctry_code = uc_city.CNTR_CODE.values.astype(str)[0]
        cityLocalName_unicode = unidecode(cityLocalName)

        output_path = os.path.join(outdata_f, f'{ctry_code}_{cityLocalName_unicode}_GQA_centroids.shp')
        if not os.path.exists(output_path):
            print(f'loading aglomeration city {cityLocalName_unicode}')
            agglomerationId_identifier = HDENS_AGGL_tbl.query(f'HDENS_NAME == "{cityLocalName}"').agglomerationId_identifier.values.astype(str)
            agl_city = agls.query(f'agglomerationId_identifier == "{agglomerationId_identifier}"')
# Out:
# Aalborg
# 1
# 2024-07-14 12:34:24.681303
# loading aglomeration city Aalborg
# Aarhus
# 1
# 2024-07-14 12:34:24.696298
# error in agl city
# AggloLux
# 1
# 2024-07-14 12:34:24.699294
# error in agl city
# Agglomeration Amsterdam-Haarlem
# 1
# 2024-07-14 12:34:24.702292
# error in agl city
# Agglomeration Rotterdam-Dordrecht
# 1
# 2024-07-14 12:34:24.705297
# error in agl city
# Agglomeration Utrecht
# 1
# 2024-07-14 12:34:24.709293
# error in agl city
# Agglomeration Zwolle
# 1
# 2024-07-14 12:34:24.711293
# error in agl city
# AggloSud
# 1
# 2024-07-14 12:34:24.714294
# error in agl city
# AMADORA
# 1
# 2024-07-14 12:34:24.717293
# error in agl city
# Antwerp
# 1
# 2024-07-14 12:34:24.722293
# error in agl city
# Basel
# 1
# 2024-07-14 12:34:24.730293
# loading aglomeration city Basel
# Bergen
# 1
# 2024-07-14 12:34:24.744307
# loading aglomeration city Bergen
# Berlin
# 1
# 2024-07-14 12:34:24.760298
# loading aglomeration city Berlin
# Bern
# 1
# 2024-07-14 12:34:24.772299
# loading aglomeration city Bern
# Bilbao
# 1
# 2024-07-14 12:34:24.785311
# loading aglomeration city Bilbao
# Bonn
# 1
# 2024-07-14 12:34:24.799306
# loading aglomeration city Bonn
# Bordeaux
# 1
# 2024-07-14 12:34:24.810295
# loading aglomeration city Bordeaux
# Bremen
# 1
# 2024-07-14 12:34:24.820299
# loading aglomeration city Bremen
# Brest
# 1
# 2024-07-14 12:34:24.829296
# loading aglomeration city Brest
# Brno
# 1
# 2024-07-14 12:34:24.839298
# loading aglomeration city Brno
# Brussels-Capital
# 1
# 2024-07-14 12:34:24.849294
# error in agl city
# Caen
# 1
# 2024-07-14 12:34:24.852293
# loading aglomeration city Caen
# City of Rijeka
# 1
# 2024-07-14 12:34:24.863295
# error in agl city
# City of Split
# 1
# 2024-07-14 12:34:24.866294
# error in agl city
# City of Zagreb
# 1
# 2024-07-14 12:34:24.869296
# error in agl city
# Clermont-Ferrand
# 1
# 2024-07-14 12:34:24.872293
# loading aglomeration city Clermont-Ferrand
# Cologne
# 1
# 2024-07-14 12:34:24.886299
# error in agl city
# Copenhagen
# 1
# 2024-07-14 12:34:24.889297
# error in agl city
# Cork
# 1
# 2024-07-14 12:34:24.892299
# loading aglomeration city Cork
# Cracow
# 1
# 2024-07-14 12:34:25.526316
# error in agl city
# Darmstadt
# 1
# 2024-07-14 12:34:25.539312
# loading aglomeration city Darmstadt
# Dublin
# 1
# 2024-07-14 12:34:25.566312
# loading aglomeration city Dublin
# Espoo
# 1
# 2024-07-14 12:34:25.587323
# error in agl city
# Fredrikstad/Sarpsborg
# 1
# 2024-07-14 12:34:25.589317
# error in agl city
# GDAŃSK
# 1
# 2024-07-14 12:34:25.593321
# error in agl city
# Geneva
# 1
# 2024-07-14 12:34:25.595319
# error in agl city
# Ghent
# 1
# 2024-07-14 12:34:25.598313
# error in agl city
# Gothenburg
# 1
# 2024-07-14 12:34:25.602317
# error in agl city
# Graz
# 1
# 2024-07-14 12:34:25.607321
# loading aglomeration city Graz
# Hamburg
# 1
# 2024-07-14 12:34:25.711316
# loading aglomeration city Hamburg
# Helsingborg
# 1
# 2024-07-14 12:34:25.734329
# loading aglomeration city Helsingborg
# Helsinki
# 1
# 2024-07-14 12:34:25.754323
# loading aglomeration city Helsinki
# Innsbruck
# 1
# 2024-07-14 12:34:25.768324
# loading aglomeration city Innsbruck
# Kaunas
# 1
# 2024-07-14 12:34:25.782319
# loading aglomeration city Kaunas
# Kuopio
# 1
# 2024-07-14 12:34:25.797323
# error in agl city
# Larnaca
# 1
# 2024-07-14 12:34:25.800321
# error in agl city
# Lausanne
# 1
# 2024-07-14 12:34:25.802321
# loading aglomeration city Lausanne
# León
# 1
# 2024-07-14 12:34:25.815323
# loading aglomeration city Leon
# Leuven
# 1
# 2024-07-14 12:34:25.829318
# loading aglomeration city Leuven
# Liberec
# 1
# 2024-07-14 12:34:25.842327
# loading aglomeration city Liberec
# Liege
# 1
# 2024-07-14 12:34:25.936323
# loading aglomeration city Liege
# Limassol
# 1
# 2024-07-14 12:34:25.956423
# error in agl city
# Limerick
# 1
# 2024-07-14 12:34:25.959337
# loading aglomeration city Limerick
# Linkoping
# 1
# 2024-07-14 12:34:25.971324
# loading aglomeration city Linkoping
# Linz
# 1
# 2024-07-14 12:34:25.983324
# loading aglomeration city Linz
# LISBOA
# 1
# 2024-07-14 12:34:25.999326
# error in agl city
# Lund
# 1
# 2024-07-14 12:34:26.002322
# loading aglomeration city Lund
# Lyon
# 1
# 2024-07-14 12:34:26.038324
# loading aglomeration city Lyon
# Madrid
# 1
# 2024-07-14 12:34:26.056325
# loading aglomeration city Madrid
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[139], line 25
#      23 print(f'loading aglomeration city {cityLocalName_unicode}')
#      24 agglomerationId_identifier = HDENS_AGGL_tbl.query(f'HDENS_NAME == "{cityLocalName}"').agglomerationId_identifier.values.astype(str)
# ---> 25 agl_city = agls.query(f'agglomerationId_identifier == "{agglomerationId_identifier}"')
#
# File c:\Users\ubach\.conda\envs\geospatial_ETC_DI_v4\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\ubach\.conda\envs\geospatial_ETC_DI_v4\lib\site-packages\pandas\core\frame.py:4474, in DataFrame.query(self, expr, inplace, **kwargs)
#    4472 kwargs["level"] = kwargs.pop("level", 0) + 2
#    4473 kwargs["target"] = None
# -> 4474 res = self.eval(expr, **kwargs)
#    4476 try:
#    4477     result = self.loc[res]
#
# File c:\Users\ubach\.conda\envs\geospatial_ETC_DI_v4\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\ubach\.conda\envs\geospatial_ETC_DI_v4\lib\site-packages\pandas\core\frame.py:4612, in DataFrame.eval(self, expr, inplace, **kwargs)
#    4609     kwargs["target"] = self
#    4610 kwargs["resolvers"] = tuple(kwargs.get("resolvers", ())) + resolvers
# -> 4612 return _eval(expr, inplace=inplace, **kwargs)
#
# File c:\Users\ubach\.conda\envs\geospatial_ETC_DI_v4\lib\site-packages\pandas\core\computation\eval.py:328, in eval(expr, parser, engine, truediv, local_dict, global_dict, resolvers, level, target, inplace)
#     325 multi_line = len(exprs) > 1
#     327 if multi_line and target is None:
# --> 328     raise ValueError(
#     329         "multi-line expressions are only valid in the "
#     330         "context of data, use DataFrame.eval"
#     331     )
#     332 engine = _check_engine(engine)
#     333 _check_parser(parser)
#
# ValueError: multi-line expressions are only valid in the context of data, use DataFrame.eval

# %%
for i in range(len(agglomerationId_identifier)):
    print(agglomerationId_identifier[i])
# Out:
# AG_ES_30_28006
# AG_ES_30_28058
# AG_ES_30_28065
# AG_ES_30_28074
# AG_ES_30_28079
