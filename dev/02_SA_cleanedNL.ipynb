# %%
#----------------------------------------------------------------------------------
#Author: Veerle Martens
#Date: may 2012
#Adapted by: Raquel Ubach (UAB) - Dec 2023/Jul 2024
#
#Purpose: Create service areas around each building block and find out the area of
#         green urban area that can be reached.
#---------------------------------------------------------------------------------

#create error handler
class CustomError(Exception):
    def __init__(self,value):
        self.value = value
    def __str__(self):
        return repr(self.value)

import sys, arcpy, time, traceback, os.path
import pandas as pd

def unique_values(table , field):
    with arcpy.da.SearchCursor(table, [field]) as cursor:
        return sorted({row[0] for row in cursor})

def convert(list):
    return tuple(list)

def create_service_area_layer(group_id, network_dataset, locations, fc_SA):
    print ("Creating network layer for batch {}".format(group_id))
    salyr = arcpy.na.MakeServiceAreaAnalysisLayer(
        network_data_source= network_dataset,
        layer_name="{}_SA_400m".format(group_id),
        travel_mode="Walk",
        travel_direction="FROM_FACILITIES",
        cutoffs=[400],
        time_of_day=None,
        time_zone="LOCAL_TIME_AT_LOCATIONS",
        output_type="POLYGONS",
        polygon_detail="HIGH",
        geometry_at_overlaps="OVERLAP",
        geometry_at_cutoffs="DISKS",
        polygon_trim_distance="10 Meters",
        exclude_sources_from_polygon_generation=None,
        accumulate_attributes=None,
        ignore_invalid_locations="SKIP"
    )
    arcpy.na.AddLocations(
        in_network_analysis_layer=salyr,
        sub_layer="Facilities",        
        in_table=locations,
        field_mappings="Name # #;CurbApproach # 0;Attr_Minutes # 0;Attr_Meters # 0;Attr_pedestrian_minutes # 0;Breaks_Minutes # #;Breaks_Meters # #;Breaks_pedestrian_minutes # #",
        search_tolerance="5000 Meters",
        sort_field=None,
        search_criteria="nw SHAPE;Network_ND_Junctions NONE",
        match_type="MATCH_TO_CLOSEST",
        append="APPEND",
        snap_to_position_along_network="NO_SNAP",
        snap_offset="5 Meters",
        exclude_restricted_elements="EXCLUDE",
        search_query=None,
        allow_auto_relocate="ALLOW"
    )
    print("Solving network analysis")
    arcpy.na.Solve(
        in_network_analysis_layer=salyr,
        ignore_invalids="SKIP",
        terminate_on_solve_error="CONTINUE",
        simplification_tolerance=None,
        overrides=""
    )
    arcpy.CopyFeatures_management("{}_SA_400m\Polygons".format(uc_code), fc_SA)
    arcpy.Delete_management(salyr) 

# Path to data folders
indata_f = r'P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas'
networks_f = os.path.join(indata_f, 'Network data Regio')
step1_f = os.path.join(indata_f, 'OutputData', 'step1_GQA')
step2_f = os.path.join(indata_f, 'OutputData', 'step2_GQA_Final')
step3_f = os.path.join(indata_f, 'OutputData', 'step3_SA')
if not os.path.exists(step3_f):
    os.makedirs(step3_f)
uc_file_path = os.path.join(indata_f, 'UrbanCentres', 'HDC2021_RG_InputUpdateB2B3B4Copy.shp')

# input parameters
pedestrian_path = networks_f
outPath = step3_f 
CODE_Fld = "code_2018"
UATL_ID_Fld = "FID"

    
# TRANSLATOR TABLE
# Crosswalk table containing the different codes from input sources
codes_path = r'P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\Codes.csv'
codes = pd.read_csv(codes_path)

#Environment settings
arcpy.env.overwriteOutput = True
arcpy.env.addOutputsToMap = False

try:
    arcpy.CheckOutExtension("Network")
    print("Network Analyst extension has been checked out.")
except arcpy.ExecuteError:
    print("Failed to check out the Network Analyst extension.")
    
# Run process for ctry
ctry = 'PL'
sql_query = "Batch >0"

# Define the path and name for the geodatabase
#gdb_path = os.path.join(indata_f, 'Processing')
gdb_path = os.path.join(indata_f, 'OutputData', 'oct_run', 'step2_SA_final')

#gdb_name = f"SA_output_2510_{ctry}.gdb"
gdb_name = f"SA_1610.gdb"
outGDB = os.path.join(gdb_path, gdb_name)
# Check if the geodatabase exists
if not arcpy.Exists(outGDB):
    # Create the geodatabase if it does not exist
    arcpy.CreateFileGDB_management(gdb_path, gdb_name)

with arcpy.da.SearchCursor(uc_file_path, ["SHAPE@", "HDENS_CLST", "CNTR_CODE"], where_clause=sql_query) as uc_cursor:
    for uc_row in uc_cursor:
        geom = uc_row[0]  # Geometry object
        ctr_cd = uc_row[2]
        uc_code = uc_row[1]
        print(uc_code)
        print(codes.query(f'HDENS_CLST == "{uc_code}"').HDENS_NAME.values.astype(str)[0].strip())
        inGQA = os.path.join(step2_f, '{}_finalGQA.shp'.format(uc_code))
        fc_SA = os.path.join(outPath, "{}_SA.shp".format(uc_code))
        ####fc_SA = os.path.join(gdb_path, gdb_name, "{}_SA".format(uc_code))
        if ctr_cd.startswith("CH-"):
            ctr_cd = "CH"
        
        outDiss = os.path.join(outPath, 'Dissolved', "{}_SAd.shp".format(uc_code))
        ##if os.path.exists(inGQA) and not arcpy.Exists(fc_SA) and ctr_cd!="NO" and ctr_cd!="CH":
        if os.path.exists(inGQA) and not arcpy.Exists(outDiss) and ctr_cd==ctry:
            print ("start: " + time.strftime("%H:%M:%S", time.localtime()))
            pedestrianNWpath = pedestrian_path + r"\NW_" + ctr_cd + ".gdb\\" + ctr_cd + r"\Network_ND"
            if not arcpy.Exists(pedestrianNWpath):
                raise CustomError("Featureclass " + pedestrianNWpath + " NOT FOUND")

            arcpy.env.extent = geom.extent # Extent object of the geometry
            print("Extent set to match uc: {}".format(arcpy.env.extent))
            
            try:          

                if arcpy.Exists("{}_UATLlayer".format(uc_code)):
                    arcpy.Delete_management("{}_UATLlayer".format(uc_code))
                uatlLyr = arcpy.MakeFeatureLayer_management(inGQA, "{}_UATLlayer".format(uc_code))

                ## Count number of GUA Blocks
                cnt = arcpy.GetCount_management(uatlLyr)
                print ("nb record(s) in " + os.path.basename(inGQA) + " subset selection [" + CODE_Fld + "] IN (14100,30000,31000) : " +  cnt.getOutput(0))

                ## Create and Select points from GUA borders used to create SA
                print ("Create points from GUA borders used to create SA")

                #fc_GUA_pt_50m = outPath + "\\GUA_pt_50m.shp" ## modified to output folder
                fc_GUA_pt_50m = outGDB +"\\{}_GUA_pt_50m".format(uc_code)

                if arcpy.Exists(fc_GUA_pt_50m):
                    arcpy.Delete_management(fc_GUA_pt_50m)
                print ("GeneratePointsAlongLines Distance 50m from selected GUA in " + os.path.basename(inGQA) + " to " + os.path.basename(fc_GUA_pt_50m))
                arcpy.GeneratePointsAlongLines_management(uatlLyr, fc_GUA_pt_50m, 'DISTANCE', Distance='50 meters', Include_End_Points='END_POINTS')

                cnt = arcpy.GetCount_management(fc_GUA_pt_50m)
                nbrec = cnt.getOutput(0)
                print ("nb generated points : " + nbrec)

                if arcpy.Exists('{}_GUA_PT_50m_lyr'.format(uc_code)):
                    arcpy.Delete_management('{}_GUA_PT_50m_lyr'.format(uc_code))
                arcpy.MakeFeatureLayer_management(fc_GUA_pt_50m, '{}_GUA_PT_50m_lyr'.format(uc_code)) 

                fc_GUA_pt_50m_nw_25m = outGDB +"\\{}_GUA_pt_50m_nw_25m".format(uc_code)    
                if arcpy.Exists(fc_GUA_pt_50m_nw_25m):
                    arcpy.Delete_management(fc_GUA_pt_50m_nw_25m)
                nw_Path = pedestrian_path + r"\NW_" + ctr_cd + ".gdb" + "\\" + ctr_cd + "\\nw"
                print ("SelectLayerByLocation points in " + os.path.basename(fc_GUA_pt_50m) + " WITHIN_A_DISTANCE of 25 meters from " + os.path.basename(nw_Path)+ " to " + os.path.basename(fc_GUA_pt_50m_nw_25m))
                Selection = arcpy.SelectLayerByLocation_management('{}_GUA_PT_50m_lyr'.format(uc_code), 'WITHIN_A_DISTANCE', nw_Path, "25 meters", "NEW_SELECTION")
                # save selection in a diferent feature class
                arcpy.CopyFeatures_management(Selection, fc_GUA_pt_50m_nw_25m) 
                # Adding FID field to the point feature class if it doesn't already exist
                if 'FID' not in [f.name for f in arcpy.ListFields(fc_GUA_pt_50m_nw_25m)]:
                    arcpy.AddField_management(fc_GUA_pt_50m_nw_25m, 'FID', 'LONG')

                UATL_Ids_GUAs_nw_25m = unique_values(fc_GUA_pt_50m_nw_25m, "ORIG_FID")
                print("Nb of GQA near network " + str(len(UATL_Ids_GUAs_nw_25m)))
                ids_ls_GQA = unique_values(uatlLyr, "FID")
                print("Total nb of GQA " +str(len(ids_ls_GQA)))

                # GQA without access to network (less than 25m)
                ids_noaccess = [item for item in ids_ls_GQA if item not in UATL_Ids_GUAs_nw_25m]
                
                # List to hold centroid points and their corresponding FIDs
                centroid_points = []
                fields_ls = ["FID", "SHAPE@", "Area"] # List of fields to include
                # Create a search cursor to iterate through the polygon shapefile GQA
                with arcpy.da.SearchCursor(uatlLyr, fields_ls) as cursor:
                    for row in cursor:
                        if row[0] in ids_noaccess:
                            # Get the FID and the geometry of the polygon
                            fid = row[0]
                            polygon = row[1]
                            area = row[2]
                            # Compute the centroid of the polygon
                            centroid = polygon.centroid
                            # Append the FID and centroid to the list
                            centroid_points.append((fid, centroid, area))

                # Start an edit session for the geodatabase
                with arcpy.da.Editor(outGDB) as edit:
                    # Create an insert cursor for the point feature class
                    with arcpy.da.InsertCursor(fc_GUA_pt_50m_nw_25m, fields_ls) as cursor:
                        for fid, point, area in centroid_points:
                            # Insert the centroid point and the FID
                            cursor.insertRow([fid, point, area])
                print("Centroids and FIDs computed and appended successfully.")

                # Add FID value to all records
                field_to_check = 'FID'
                alternative_field = 'ORIG_FID'
                #expression = f"!{field_to_check}! if !{field_to_check}! is not None else !{alternative_field}!"
                expression ="!FID! if !FID! is not None else !ORIG_FID!"
                # Execute CalculateField
                arcpy.CalculateField_management(fc_GUA_pt_50m_nw_25m, field_to_check, expression, "PYTHON3")

                cnt = arcpy.GetCount_management(fc_GUA_pt_50m_nw_25m)
                nbrec = cnt.getOutput(0)
                print ("nb points in " + os.path.basename(fc_GUA_pt_50m_nw_25m) + " : " + nbrec)
        
                if arcpy.Exists("{}GUA_points_layer".format(uc_code)):
                    arcpy.Delete_management("{}GUA_points_layer".format(uc_code))
                GUA_pt_lyr = arcpy.MakeFeatureLayer_management(fc_GUA_pt_50m_nw_25m, "{}GUA_points_layer".format(uc_code))
                print("{}GUA_points_layer".format(uc_code))
                

                # Create service area layer
                ###create_service_area_layer(GUA_pt_lyr, "{}_SA_400m".format(uc_code), pedestrianNWpath, uc_code, nbMeters)
                group_id = uc_code
                network_dataset = pedestrianNWpath
                locations = GUA_pt_lyr
                if not os.path.exists(fc_SA):
                    create_service_area_layer(group_id, network_dataset, locations, fc_SA)

                #join GQA FID
                arcpy.management.JoinField(
                    in_data=fc_SA,
                    in_field="FacilityID",
                    join_table=fc_GUA_pt_50m_nw_25m,
                    join_field="OBJECTID",
                    fields="FID",
                    fm_option="NOT_USE_FM",
                    field_mapping=None,
                    index_join_fields="NO_INDEXES"
                )
                # Dissolve by QGA id
                outDiss = os.path.join(outPath, 'Dissolved', "{}_SAd.shp".format(uc_code))
                if not os.path.exists(outDiss):
                    arcpy.analysis.PairwiseDissolve(
                        in_features=fc_SA,
                        out_feature_class=outDiss,
                        dissolve_field="FID_1",
                        statistics_fields=None,
                        multi_part="MULTI_PART",
                        concatenation_separator=""
                    )


                print ("end: " + time.strftime("%H:%M:%S", time.localtime()))
                
            except CustomError as ce:
                arcpy.AddError(ce.value)
                print (ce.value)
            except arcpy.ExecuteError:
                msgs = arcpy.GetMessages(2)
                arcpy.AddError(msgs)
                print (msgs)
            except:
                tb = sys.exc_info()[2]
                tbinfo = traceback.format_tb(tb)[0]
                pymsg = "PYTHON ERRORS:\nTraceback info:\n" + tbinfo + "\nError Info:\n" + str(sys.exc_info()[1])
                msgs = "ArcPy ERRORS:\n" + arcpy.GetMessages(2) + "\n"
                arcpy.AddError(pymsg)
                print (msgs)
                arcpy.AddError(msgs)
                print (pymsg)
# Out:
# Network Analyst extension has been checked out.
# GEOSTAT21_018
# Stockholm
# GEOSTAT21_021
# Tartu
# GEOSTAT21_022
# Örebro
# GEOSTAT21_023
# Stavanger
# GEOSTAT21_024
# Norrköping
# GEOSTAT21_025
# Linköping
# GEOSTAT21_914
# Jönköping / Huskvarna
# GEOSTAT21_029
# Göteborg
# GEOSTAT21_026
# Borås
# GEOSTAT21_028
# Rīga
# GEOSTAT21_031
# Aalborg
# GEOSTAT21_047
# Århus
# GEOSTAT21_048
# Helsingborg
# GEOSTAT21_903
# København
# GEOSTAT21_049
# Lund
# GEOSTAT21_051
# Kaunas
# GEOSTAT21_054
# Malmö
# GEOSTAT21_060
# Odense
# GEOSTAT21_065
# Gdynia
# GEOSTAT21_068
# Gdańsk
# GEOSTAT21_904
# Dublin
# GEOSTAT21_070
# Elbląg
# GEOSTAT21_086
# Kiel
# GEOSTAT21_090
# Olsztyn
# GEOSTAT21_093
# Lütten Klein
# GEOSTAT21_094
# Rostock
# GEOSTAT21_095
# Limerick
# GEOSTAT21_108
# Lübeck
# GEOSTAT21_109
# Białystok
# GEOSTAT21_119
# Hamburg
# GEOSTAT21_118
# Bremerhaven
# GEOSTAT21_120
# Szczecin
# GEOSTAT21_919
# Neu Wulmstorf / Neugraben-Fischbek / Hausbruch
# GEOSTAT21_121
# Harburg
# GEOSTAT21_122
# Kasztelanka
# GEOSTAT21_128
# Bydgoszcz
# GEOSTAT21_132
# Cork
# GEOSTAT21_131
# Toruń
# GEOSTAT21_137
# Groningen
# GEOSTAT21_141
# Oldenburg (Oldenburg)
# GEOSTAT21_140
# Gröpelingen / Vegesack
# GEOSTAT21_145
# Bremen
# GEOSTAT21_150
# Włocławek
# GEOSTAT21_154
# Płock
# GEOSTAT21_161
# Gorzów Wielkopolski
# GEOSTAT21_171
# Warszawa
# GEOSTAT21_002
# Oulu / Uleåborg
# GEOSTAT21_003
# Umeå
# GEOSTAT21_004
# Trondheim
# GEOSTAT21_005
# Jyväskylä
# GEOSTAT21_006
# Tampere / Tammerfors
# GEOSTAT21_911
# Lahti
# GEOSTAT21_901
# Helsinki
# GEOSTAT21_007
# Turku / Åbo
# GEOSTAT21_011
# Bergen
# GEOSTAT21_012
# Tallinn
# GEOSTAT21_013
# Uppsala
# GEOSTAT21_902
# Oslo
# GEOSTAT21_016
# Västerås
# GEOSTAT21_912
# Drammen
# GEOSTAT21_200
# Hannover
# GEOSTAT21_205
# Leiden
# GEOSTAT21_196
# Hilversum
# GEOSTAT21_199
# Hengelo
# GEOSTAT21_201
# Osnabrück
# GEOSTAT21_203
# Apeldoorn
# GEOSTAT21_211
# Braunschweig
# GEOSTAT21_208
# Enschede
# GEOSTAT21_206
# Alphen aan den Rijn
# GEOSTAT21_221
# Den Haag
# GEOSTAT21_905
# Utrecht
# GEOSTAT21_216
# Zoetermeer
# GEOSTAT21_229
# Łódź
# GEOSTAT21_225
# Magdeburg
# GEOSTAT21_220
# Gouda
# GEOSTAT21_223
# Hildesheim
# GEOSTAT21_224
# Nieuwegein / IJsselstein
# GEOSTAT21_240
# Rotterdam
# GEOSTAT21_233
# Zielona Góra
# GEOSTAT21_239
# Arnhem
# GEOSTAT21_237
# Bielefeld
# GEOSTAT21_243
# Münster
# GEOSTAT21_242
# Spijkenisse
# GEOSTAT21_248
# Dordrecht
# GEOSTAT21_249
# Radom
# GEOSTAT21_256
# Nijmegen
# GEOSTAT21_255
# Lublin
# GEOSTAT21_327
# Düsseldorf
# GEOSTAT21_925
# Wuppertal
# GEOSTAT21_316
# Dunkerque
# GEOSTAT21_331
# Mönchengladbach
# GEOSTAT21_332
# Gent
# GEOSTAT21_334
# Solingen
# GEOSTAT21_328
# Remscheid
# GEOSTAT21_335
# Częstochowa
# GEOSTAT21_339
# Dresden
# GEOSTAT21_346
# Köln
# GEOSTAT21_349
# Bruxelles / Brussel
# GEOSTAT21_344
# Leuven
# GEOSTAT21_347
# Heerlen
# GEOSTAT21_348
# Opole
# GEOSTAT21_354
# Porz
# GEOSTAT21_359
# Chemnitz
# GEOSTAT21_358
# Liberec
# GEOSTAT21_360
# Aachen
# GEOSTAT21_363
# Bonn
# GEOSTAT21_364
# Liège
# GEOSTAT21_362
# Ústí nad Labem
# GEOSTAT21_376
# Górnośląski Związek Metropolitalny
# GEOSTAT21_366
# Rzeszów
# GEOSTAT21_367
# Lens
# GEOSTAT21_379
# Charleroi
# GEOSTAT21_265
# s-Hertogenbosch
# GEOSTAT21_274
# Breda
# GEOSTAT21_299
# Ruhrgebiet
# GEOSTAT21_289
# Göttingen
# GEOSTAT21_292
# Eindhoven
# GEOSTAT21_288
# Helmond
# GEOSTAT21_295
# Halle an der Saale
# GEOSTAT21_297
# Moers / Rheinhausen
# GEOSTAT21_302
# Duisburg
# GEOSTAT21_305
# Hagen
# GEOSTAT21_304
# Brugge
# GEOSTAT21_312
# Leipzig
# GEOSTAT21_307
# Krefeld
# GEOSTAT21_317
# Antwerpen
# GEOSTAT21_308
# Kielce
# GEOSTAT21_318
# Wrocław
# GEOSTAT21_320
# Kassel
# GEOSTAT21_922
# Scharwoude / Heerhugowaard
# GEOSTAT21_168
# Alkmaar
# GEOSTAT21_178
# Poznań
# GEOSTAT21_186
# Berlin
# GEOSTAT21_173
# Beverwijk/Heemskerk
# GEOSTAT21_190
# Amsterdam
# GEOSTAT21_177
# Zwolle
# GEOSTAT21_181
# Haarlem
# GEOSTAT21_184
# Almere
# GEOSTAT21_188
# Potsdam
# GEOSTAT21_405
# Wiesbaden
# GEOSTAT21_403
# Havířov
# GEOSTAT21_404
# Hrabuvka
# GEOSTAT21_408
# Mainz
# GEOSTAT21_413
# Darmstadt
# GEOSTAT21_418
# Rouen
# GEOSTAT21_414
# Olomouc
# GEOSTAT21_417
# Würzburg
# GEOSTAT21_416
# Plzeň
# GEOSTAT21_419
# Luxembourg
# GEOSTAT21_420
# Caen
# GEOSTAT21_421
# Erlangen
# GEOSTAT21_457
# Vaihingen / Möhringen
# GEOSTAT21_473
# Reutlingen
# GEOSTAT21_481
# Wien
# GEOSTAT21_476
# Ulm/Neu-Ulm
# GEOSTAT21_479
# Linz
# GEOSTAT21_907
# Augsburg
# GEOSTAT21_487
# München
# GEOSTAT21_488
# Freiburg im Breisgau
# GEOSTAT21_489
# Angers
# GEOSTAT21_496
# Nantes
# GEOSTAT21_495
# Salzburg
# GEOSTAT21_499
# Tours
# GEOSTAT21_510
# Basel
# GEOSTAT21_941
# Gebenstorf / Turgi / Obersiggenthal / Baden / Wettingen
# GEOSTAT21_425
# Mannheim/Ludwigshafen
# GEOSTAT21_429
# Fürth
# GEOSTAT21_427
# Reims
# GEOSTAT21_428
# Heidelberg
# GEOSTAT21_430
# Brno
# GEOSTAT21_431
# Brest
# GEOSTAT21_906
# Paris
# GEOSTAT21_432
# Mantes en Yvelines
# GEOSTAT21_435
# Saarbrücken
# GEOSTAT21_437
# Poissy
# GEOSTAT21_441
# Heilbronn
# GEOSTAT21_440
# Les Clayes-sous-Bois
# GEOSTAT21_443
# Maurepas / Montigny-le-Bretonneux
# GEOSTAT21_445
# Regensburg
# GEOSTAT21_447
# Karlsruhe
# GEOSTAT21_448
# Pforzheim
# GEOSTAT21_454
# Stuttgart
# GEOSTAT21_455
# Ingolstadt
# GEOSTAT21_459
# Rennes
# GEOSTAT21_377
# Tarnów
# GEOSTAT21_385
# Kraków
# GEOSTAT21_382
# Arras
# GEOSTAT21_384
# Tychy
# GEOSTAT21_387
# Koblenz
# GEOSTAT21_402
# Praha
# GEOSTAT21_401
# Frankfurt am Main
# GEOSTAT21_394
# Bielsko-Biała
# start: 19:01:26
# Extent set to match uc: 4965000 3004000 4973000 3009000 NaN NaN NaN NaN
# nb record(s) in GEOSTAT21_394_finalGQA.shp subset selection [code_2018] IN (14100,30000,31000) : 63
# Create points from GUA borders used to create SA
# ERROR 000464: Cannot get exclusive schema lock.  Either being edited or in use by another application or service.
# Failed to execute (Delete).
#
# GEOSTAT21_397
# Ostrava
# GEOSTAT21_400
# Hanau
# GEOSTAT21_398
# Poruba
# GEOSTAT21_542
# Lausanne
# GEOSTAT21_549
# Genève
# GEOSTAT21_550
# Limoges
# GEOSTAT21_558
# Clermont-Ferrand
# GEOSTAT21_557
# Lugano
# GEOSTAT21_561
# Zagreb
# GEOSTAT21_569
# Lyon
# GEOSTAT21_945
# Saint-Priest / Mions
# GEOSTAT21_624
# Oviedo
# GEOSTAT21_650
# Bilbao
# GEOSTAT21_652
# San Sebastián/Donostia
# GEOSTAT21_657
# Vigo
# GEOSTAT21_665
# León
# GEOSTAT21_672
# Nice
# GEOSTAT21_669
# Split
# GEOSTAT21_674
# Vitoria/Gasteiz
# GEOSTAT21_676
# Aix-en-Provence
# GEOSTAT21_682
# Martigues / Port-de-Bouc
# GEOSTAT21_687
# Pamplona/Iruña
# GEOSTAT21_689
# Marseille
# GEOSTAT21_694
# Logroño
# GEOSTAT21_580
# Saint-Etienne
# GEOSTAT21_588
# Rijeka
# GEOSTAT21_595
# Bordeaux
# GEOSTAT21_597
# Grenoble
# GEOSTAT21_620
# Gijón
# GEOSTAT21_521
# Zürich
# GEOSTAT21_514
# St. Gallen
# GEOSTAT21_519
# Besançon
# GEOSTAT21_520
# Innsbruck
# GEOSTAT21_522
# Graz
# GEOSTAT21_943
# Cham / Zug
# GEOSTAT21_523
# Biel/Bienne
# GEOSTAT21_528
# Bern
# GEOSTAT21_531
# Fribourg
# GEOSTAT21_800
# Castellón de la Plana/Castelló de la Plana
# GEOSTAT21_809
# Valencia
# GEOSTAT21_843
# Lefkosia
# GEOSTAT21_773
# Madrid
# GEOSTAT21_768
# Torrejón de Ardoz
# GEOSTAT21_774
# Fuenlabrada
# GEOSTAT21_706
# Porto
# GEOSTAT21_712
# Valladolid
# GEOSTAT21_856
# Lemesos
# GEOSTAT21_867
# Valletta

# %%
import glob
indata_f = r'P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas'
step2_f = os.path.join(indata_f, 'OutputData', 'step3_SA')

SA_ls = glob.glob(os.path.join(step2_f, '*.shp'))

# %%
len(SA_ls)
# Out:
# 234

# %%
# Print the list of shapefiles
for sa_name in SA_ls[40:66]:
    uc_code = os.path.basename(sa_name)[:-7]

# %%
uc_code='GEOSTAT21_297'
fc_SA = os.path.join(outPath, "{}_SA.shp".format(uc_code))
outDiss = os.path.join(outPath, 'Dissolved', "{}_SAd.shp".format(uc_code))
if not os.path.exists(outDiss):
    arcpy.analysis.PairwiseDissolve(
        in_features=fc_SA,
        out_feature_class=outDiss,
        dissolve_field="ORIG_FID",
        statistics_fields=None,
        multi_part="MULTI_PART",
        concatenation_separator=""
    )

# %%
fc_GUA_pt_50m_nw_25m = outGDB +"\\{}_GUA_pt_50m_nw_25m".format(uc_code)

arcpy.management.JoinField(
    in_data=fc_SA,
    in_field="FacilityID",
    join_table=fc_GUA_pt_50m_nw_25m,
    join_field="OBJECTID",
    fields="FID",
    fm_option="NOT_USE_FM",
    field_mapping=None,
    index_join_fields="NO_INDEXES"
)
# Dissolve by QGA id
outDiss = os.path.join(outPath, 'Dissolved', "{}_SAd.shp".format(uc_code))
if not os.path.exists(outDiss):
    arcpy.analysis.PairwiseDissolve(
        in_features=fc_SA,
        out_feature_class=outDiss,
        dissolve_field="FID_1",
        statistics_fields=None,
        multi_part="MULTI_PART",
        concatenation_separator=""
    )

# %%
# Out:
# 'P:\\Environment and Health\\Noise\\ServiceContract\\2024_ServiceContract\\QuietAreas\\Processing\\SA_output_2510_DE_DIS.gdb\\GEOSTAT21_354_GUA_pt_50m_nw_25m'

# %%
arcpy.MakeFeatureLayer_management(fc_GUA_pt_50m_nw_25m
,'locations'
)
# Out:
# <Result 'locations'>

# %%
fields = arcpy.ListFields('locations')

# %%
for field in fields:
    print(f"Name: {field.name}")
    #print(f"Type: {field.type}")
# Out:
# Name: OBJECTID
# Name: Shape
# Name: ORIG_FID
# Name: Id
# Name: ORIG_FID_1
# Name: Area
# Name: FID

# %%
arcpy.MakeFeatureLayer_management(fc_SA,'fc_SA')
fieldsSA = arcpy.ListFields('fc_SA')
for field in fieldsSA:
    print(f"Name: {field.name}")
# Out:
# Name: FID
# Name: Shape
# Name: FacilityID
# Name: Name
# Name: FromBreak
# Name: ToBreak
# Name: Shape_Leng
# Name: Shape_Area

# %%
arcpy.JoinField_management('fc_SA', 'FacilityID', 'locations', 'FID', 'FID')
# Out:
# <Result 'fc_SA'>

# %%
arcpy.MakeFeatureLayer_management(fc_SA,'fc_SA')
fieldsSA = arcpy.ListFields('fc_SA')
for field in fieldsSA:
    print(f"Name: {field.name}")
# Out:
# Name: FID
# Name: Shape
# Name: FacilityID
# Name: Name
# Name: FromBreak
# Name: ToBreak
# Name: Shape_Leng
# Name: Shape_Area
# Name: FID_1

# %%
arcpy.CopyFeatures_management('fc_SA', os.path.join(outPath, "{}_SA_merged.shp".format(uc_code)))
# Out:
# <Result 'P:\\Environment and Health\\Noise\\ServiceContract\\2024_ServiceContract\\QuietAreas\\OutputData\\step3_SA\\GEOSTAT21_354_SA_merged.shp'>

# %%
outPath
# Out:
# 'P:\\Environment and Health\\Noise\\ServiceContract\\2024_ServiceContract\\QuietAreas\\OutputData\\step3_SA'

# %%
uc_code = 'GEOSTAT21_354'
#out_feature_class =os.path.join(outPath, "{}_SA_Diss22.shp".format(uc_code))
out_feature_class =outGDB +"\\{}_Diss".format(uc_code)
#arcpy.Dissolve_management('fc_SA', out_feature_class, 'FID_1')
arcpy.management.Dissolve('fc_SA', out_feature_class, 'FID_1')
# Out:
# <Result 'P:\\Environment and Health\\Noise\\ServiceContract\\2024_ServiceContract\\QuietAreas\\Processing\\SA_output_2510_DE_DIS.gdb\\GEOSTAT21_354_Diss'>

# %%
uc_code
# Out:
# 'GEOSTAT21_867'

# %%
fc_SA = os.path.join(outPath, "GEOSTAT21_297_SA.shp")
uc_code = 'GEOSTAT21_297'
arcpy.CopyFeatures_management("{}_SA_400m\Polygons".format(uc_code), fc_SA)
# Out:
# <Result 'P:\\Environment and Health\\Noise\\ServiceContract\\2024_ServiceContract\\QuietAreas\\OutputData\\step3_SA\\GEOSTAT21_297_SA.shp'>

# %%
#----------------------------------------------------------------------------------
#Author: Veerle Martens
#Date: may 2012
#Adapted by: Raquel Ubach (UAB) - Dec 2023/Jul 2024
#
#Purpose: Create service areas around each building block and find out the area of
#         green urban area that can be reached.
#---------------------------------------------------------------------------------

#create error handler
class CustomError(Exception):
    def __init__(self,value):
        self.value = value
    def __str__(self):
        return repr(self.value)

import sys, arcpy, time, traceback, os.path
import pandas as pd

def unique_values(table , field):
    with arcpy.da.SearchCursor(table, [field]) as cursor:
        return sorted({row[0] for row in cursor})

def convert(list):
    return tuple(list)

def create_service_area_layer(group_id, network_dataset, locations, fc_SA):
    print ("Creating network layer for batch {}".format(group_id))
    salyr = arcpy.na.MakeServiceAreaAnalysisLayer(
        network_data_source= network_dataset,
        layer_name="{}_SA_400m".format(group_id),
        travel_mode="Walk",
        travel_direction="FROM_FACILITIES",
        cutoffs=[400],
        time_of_day=None,
        time_zone="LOCAL_TIME_AT_LOCATIONS",
        output_type="POLYGONS",
        polygon_detail="HIGH",
        geometry_at_overlaps="OVERLAP",
        geometry_at_cutoffs="DISKS",
        polygon_trim_distance="10 Meters",
        exclude_sources_from_polygon_generation=None,
        accumulate_attributes=None,
        ignore_invalid_locations="SKIP"
    )
    arcpy.na.AddLocations(
        in_network_analysis_layer=salyr,
        sub_layer="Facilities",        
        in_table=locations,
        field_mappings="Name # #;CurbApproach # 0;Attr_Minutes # 0;Attr_Meters # 0;Attr_pedestrian_minutes # 0;Breaks_Minutes # #;Breaks_Meters # #;Breaks_pedestrian_minutes # #",
        search_tolerance="5000 Meters",
        sort_field=None,
        search_criteria="nw SHAPE;Network_ND_Junctions NONE",
        match_type="MATCH_TO_CLOSEST",
        append="APPEND",
        snap_to_position_along_network="NO_SNAP",
        snap_offset="5 Meters",
        exclude_restricted_elements="EXCLUDE",
        search_query=None,
        allow_auto_relocate="ALLOW"
    )
    print("Solving network analysis")
    arcpy.na.Solve(
        in_network_analysis_layer=salyr,
        ignore_invalids="SKIP",
        terminate_on_solve_error="CONTINUE",
        simplification_tolerance=None,
        overrides=""
    )
    arcpy.CopyFeatures_management("{}_SA_400m\Polygons".format(uc_code), fc_SA)
    arcpy.Delete_management(salyr) 

# Path to data folders
indata_f = r'P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas'
networks_f = os.path.join(indata_f, 'Network data Regio')
step1_f = os.path.join(indata_f, 'OutputData', 'step1_GQA')
step2_f = os.path.join(indata_f, 'OutputData', 'step2_GQA_Final')
step3_f = os.path.join(indata_f, 'OutputData', 'step3_SA')
if not os.path.exists(step3_f):
    os.makedirs(step3_f)
uc_file_path = os.path.join(indata_f, 'UrbanCentres', 'HDC2021_RG_InputUpdateB2B3B4Copy.shp')

# input parameters
pedestrian_path = networks_f
outPath = step3_f 
CODE_Fld = "code_2018"
UATL_ID_Fld = "FID"

    
# TRANSLATOR TABLE
# Crosswalk table containing the different codes from input sources
codes_path = r'P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\Codes.csv'
codes = pd.read_csv(codes_path)

#Environment settings
arcpy.env.overwriteOutput = True
arcpy.env.addOutputsToMap = False

try:
    arcpy.CheckOutExtension("Network")
    print("Network Analyst extension has been checked out.")
except arcpy.ExecuteError:
    print("Failed to check out the Network Analyst extension.")
    
# Run process for ctry
ctry = 'FR'
sql_query = "Batch >0"

# Define the path and name for the geodatabase
#gdb_path = os.path.join(indata_f, 'Processing')
gdb_path = os.path.join(indata_f, 'OutputData', 'oct_run', 'step2_SA_final_AT')

#gdb_name = f"SA_output_2510_{ctry}.gdb"
gdb_name = f"SA_1610.gdb"
outGDB = os.path.join(gdb_path, gdb_name)
# Check if the geodatabase exists
if not arcpy.Exists(outGDB):
    # Create the geodatabase if it does not exist
    arcpy.CreateFileGDB_management(gdb_path, gdb_name)

with arcpy.da.SearchCursor(uc_file_path, ["SHAPE@", "HDENS_CLST", "CNTR_CODE"], where_clause=sql_query) as uc_cursor:
    for uc_row in uc_cursor:
        geom = uc_row[0]  # Geometry object
        ctr_cd = uc_row[2]
        uc_code = uc_row[1]
        print(uc_code)
        print(codes.query(f'HDENS_CLST == "{uc_code}"').HDENS_NAME.values.astype(str)[0].strip())
        inGQA = os.path.join(step2_f, '{}_finalGQA.shp'.format(uc_code))
        fc_SA = os.path.join(outPath, "{}_SA.shp".format(uc_code))
        ####fc_SA = os.path.join(gdb_path, gdb_name, "{}_SA".format(uc_code))
        if ctr_cd.startswith("CH-"):
            ctr_cd = "CH"
        
        outDiss = os.path.join(outPath, 'Dissolved', "{}_SAd.shp".format(uc_code))
        ##if os.path.exists(inGQA) and not arcpy.Exists(fc_SA) and ctr_cd!="NO" and ctr_cd!="CH":
        if os.path.exists(inGQA) and not arcpy.Exists(outDiss) and ctr_cd== ctry:
            print ("start: " + time.strftime("%H:%M:%S", time.localtime()))
            pedestrianNWpath = pedestrian_path + r"\NW_" + ctr_cd + ".gdb\\" + ctr_cd + r"\Network_ND"
            if not arcpy.Exists(pedestrianNWpath):
                raise CustomError("Featureclass " + pedestrianNWpath + " NOT FOUND")

            arcpy.env.extent = geom.extent # Extent object of the geometry
            print("Extent set to match uc: {}".format(arcpy.env.extent))
            
            try:          

                if arcpy.Exists("{}_UATLlayer".format(uc_code)):
                    arcpy.Delete_management("{}_UATLlayer".format(uc_code))
                uatlLyr = arcpy.MakeFeatureLayer_management(inGQA, "{}_UATLlayer".format(uc_code))

                ## Count number of GUA Blocks
                cnt = arcpy.GetCount_management(uatlLyr)
                print ("nb record(s) in " + os.path.basename(inGQA) + " subset selection [" + CODE_Fld + "] IN (14100,30000,31000) : " +  cnt.getOutput(0))

                ## Create and Select points from GUA borders used to create SA
                print ("Create points from GUA borders used to create SA")

                #fc_GUA_pt_50m = outPath + "\\GUA_pt_50m.shp" ## modified to output folder
                fc_GUA_pt_50m = outGDB +"\\{}_GUA_pt_50m".format(uc_code)

                if arcpy.Exists(fc_GUA_pt_50m):
                    arcpy.Delete_management(fc_GUA_pt_50m)
                print ("GeneratePointsAlongLines Distance 50m from selected GUA in " + os.path.basename(inGQA) + " to " + os.path.basename(fc_GUA_pt_50m))
                arcpy.GeneratePointsAlongLines_management(uatlLyr, fc_GUA_pt_50m, 'DISTANCE', Distance='50 meters', Include_End_Points='END_POINTS')

                cnt = arcpy.GetCount_management(fc_GUA_pt_50m)
                nbrec = cnt.getOutput(0)
                print ("nb generated points : " + nbrec)

                if arcpy.Exists('{}_GUA_PT_50m_lyr'.format(uc_code)):
                    arcpy.Delete_management('{}_GUA_PT_50m_lyr'.format(uc_code))
                arcpy.MakeFeatureLayer_management(fc_GUA_pt_50m, '{}_GUA_PT_50m_lyr'.format(uc_code)) 

                fc_GUA_pt_50m_nw_25m = outGDB +"\\{}_GUA_pt_50m_nw_25m".format(uc_code)    
                if arcpy.Exists(fc_GUA_pt_50m_nw_25m):
                    arcpy.Delete_management(fc_GUA_pt_50m_nw_25m)
                nw_Path = pedestrian_path + r"\NW_" + ctr_cd + ".gdb" + "\\" + ctr_cd + "\\nw"
                print ("SelectLayerByLocation points in " + os.path.basename(fc_GUA_pt_50m) + " WITHIN_A_DISTANCE of 25 meters from " + os.path.basename(nw_Path)+ " to " + os.path.basename(fc_GUA_pt_50m_nw_25m))
                Selection = arcpy.SelectLayerByLocation_management('{}_GUA_PT_50m_lyr'.format(uc_code), 'WITHIN_A_DISTANCE', nw_Path, "25 meters", "NEW_SELECTION")
                # save selection in a diferent feature class
                arcpy.CopyFeatures_management(Selection, fc_GUA_pt_50m_nw_25m) 
                # Adding FID field to the point feature class if it doesn't already exist
                if 'FID' not in [f.name for f in arcpy.ListFields(fc_GUA_pt_50m_nw_25m)]:
                    arcpy.AddField_management(fc_GUA_pt_50m_nw_25m, 'FID', 'LONG')

                UATL_Ids_GUAs_nw_25m = unique_values(fc_GUA_pt_50m_nw_25m, "ORIG_FID")
                print("Nb of GQA near network " + str(len(UATL_Ids_GUAs_nw_25m)))
                ids_ls_GQA = unique_values(uatlLyr, "FID")
                print("Total nb of GQA " +str(len(ids_ls_GQA)))

                # GQA without access to network (less than 25m)
                ids_noaccess = [item for item in ids_ls_GQA if item not in UATL_Ids_GUAs_nw_25m]
                
                # List to hold centroid points and their corresponding FIDs
                centroid_points = []
                fields_ls = ["FID", "SHAPE@", "Area"] # List of fields to include
                # Create a search cursor to iterate through the polygon shapefile GQA
                with arcpy.da.SearchCursor(uatlLyr, fields_ls) as cursor:
                    for row in cursor:
                        if row[0] in ids_noaccess:
                            # Get the FID and the geometry of the polygon
                            fid = row[0]
                            polygon = row[1]
                            area = row[2]
                            # Compute the centroid of the polygon
                            centroid = polygon.centroid
                            # Append the FID and centroid to the list
                            centroid_points.append((fid, centroid, area))

                # Start an edit session for the geodatabase
                with arcpy.da.Editor(outGDB) as edit:
                    # Create an insert cursor for the point feature class
                    with arcpy.da.InsertCursor(fc_GUA_pt_50m_nw_25m, fields_ls) as cursor:
                        for fid, point, area in centroid_points:
                            # Insert the centroid point and the FID
                            cursor.insertRow([fid, point, area])
                print("Centroids and FIDs computed and appended successfully.")

                # Add FID value to all records
                field_to_check = 'FID'
                alternative_field = 'ORIG_FID'
                #expression = f"!{field_to_check}! if !{field_to_check}! is not None else !{alternative_field}!"
                expression ="!FID! if !FID! is not None else !ORIG_FID!"
                # Execute CalculateField
                arcpy.CalculateField_management(fc_GUA_pt_50m_nw_25m, field_to_check, expression, "PYTHON3")

                cnt = arcpy.GetCount_management(fc_GUA_pt_50m_nw_25m)
                nbrec = cnt.getOutput(0)
                print ("nb points in " + os.path.basename(fc_GUA_pt_50m_nw_25m) + " : " + nbrec)
        
                if arcpy.Exists("{}GUA_points_layer".format(uc_code)):
                    arcpy.Delete_management("{}GUA_points_layer".format(uc_code))
                GUA_pt_lyr = arcpy.MakeFeatureLayer_management(fc_GUA_pt_50m_nw_25m, "{}GUA_points_layer".format(uc_code))
                print("{}GUA_points_layer".format(uc_code))
                

                # Create service area layer
                ###create_service_area_layer(GUA_pt_lyr, "{}_SA_400m".format(uc_code), pedestrianNWpath, uc_code, nbMeters)
                group_id = uc_code
                network_dataset = pedestrianNWpath
                locations = GUA_pt_lyr
                if os.path.exists(fc_SA):
                        #create_service_area_layer(group_id, network_dataset, locations, fc_SA)

                    #join GQA FID
                    arcpy.management.JoinField(
                        in_data=fc_SA,
                        in_field="FacilityID",
                        join_table=fc_GUA_pt_50m_nw_25m,
                        join_field="OBJECTID",
                        fields="FID",
                        fm_option="NOT_USE_FM",
                        field_mapping=None,
                        index_join_fields="NO_INDEXES"
                    )
                    # Dissolve by QGA id
                    outDiss = os.path.join(outPath, 'Dissolved', "{}_SAd.shp".format(uc_code))
                    if not os.path.exists(outDiss):
                        arcpy.analysis.PairwiseDissolve(
                            in_features=fc_SA,
                            out_feature_class=outDiss,
                            dissolve_field="FID_1",
                            statistics_fields=None,
                            multi_part="MULTI_PART",
                            concatenation_separator=""
                        )


                print ("end: " + time.strftime("%H:%M:%S", time.localtime()))
                
            except CustomError as ce:
                arcpy.AddError(ce.value)
                print (ce.value)
            except arcpy.ExecuteError:
                msgs = arcpy.GetMessages(2)
                arcpy.AddError(msgs)
                print (msgs)
            except:
                tb = sys.exc_info()[2]
                tbinfo = traceback.format_tb(tb)[0]
                pymsg = "PYTHON ERRORS:\nTraceback info:\n" + tbinfo + "\nError Info:\n" + str(sys.exc_info()[1])
                msgs = "ArcPy ERRORS:\n" + arcpy.GetMessages(2) + "\n"
                arcpy.AddError(pymsg)
                print (msgs)
                arcpy.AddError(msgs)
                print (pymsg)
# Out:
# Network Analyst extension has been checked out.
# GEOSTAT21_018
# Stockholm
# GEOSTAT21_021
# Tartu
# GEOSTAT21_022
# Örebro
# GEOSTAT21_023
# Stavanger
# GEOSTAT21_024
# Norrköping
# GEOSTAT21_025
# Linköping
# GEOSTAT21_914
# Jönköping / Huskvarna
# GEOSTAT21_029
# Göteborg
# GEOSTAT21_026
# Borås
# GEOSTAT21_028
# Rīga
# GEOSTAT21_031
# Aalborg
# GEOSTAT21_047
# Århus
# GEOSTAT21_048
# Helsingborg
# GEOSTAT21_903
# København
# GEOSTAT21_049
# Lund
# GEOSTAT21_051
# Kaunas
# GEOSTAT21_054
# Malmö
# GEOSTAT21_060
# Odense
# GEOSTAT21_065
# Gdynia
# GEOSTAT21_068
# Gdańsk
# GEOSTAT21_904
# Dublin
# GEOSTAT21_070
# Elbląg
# GEOSTAT21_086
# Kiel
# GEOSTAT21_090
# Olsztyn
# GEOSTAT21_093
# Lütten Klein
# GEOSTAT21_094
# Rostock
# GEOSTAT21_095
# Limerick
# GEOSTAT21_108
# Lübeck
# GEOSTAT21_109
# Białystok
# GEOSTAT21_119
# Hamburg
# GEOSTAT21_118
# Bremerhaven
# GEOSTAT21_120
# Szczecin
# GEOSTAT21_919
# Neu Wulmstorf / Neugraben-Fischbek / Hausbruch
# GEOSTAT21_121
# Harburg
# GEOSTAT21_122
# Kasztelanka
# GEOSTAT21_128
# Bydgoszcz
# GEOSTAT21_132
# Cork
# GEOSTAT21_131
# Toruń
# GEOSTAT21_137
# Groningen
# GEOSTAT21_141
# Oldenburg (Oldenburg)
# GEOSTAT21_140
# Gröpelingen / Vegesack
# GEOSTAT21_145
# Bremen
# GEOSTAT21_150
# Włocławek
# GEOSTAT21_154
# Płock
# GEOSTAT21_161
# Gorzów Wielkopolski
# GEOSTAT21_171
# Warszawa
# GEOSTAT21_002
# Oulu / Uleåborg
# GEOSTAT21_003
# Umeå
# GEOSTAT21_004
# Trondheim
# GEOSTAT21_005
# Jyväskylä
# GEOSTAT21_006
# Tampere / Tammerfors
# GEOSTAT21_911
# Lahti
# GEOSTAT21_901
# Helsinki
# GEOSTAT21_007
# Turku / Åbo
# GEOSTAT21_011
# Bergen
# GEOSTAT21_012
# Tallinn
# GEOSTAT21_013
# Uppsala
# GEOSTAT21_902
# Oslo
# GEOSTAT21_016
# Västerås
# GEOSTAT21_912
# Drammen
# GEOSTAT21_200
# Hannover
# GEOSTAT21_205
# Leiden
# GEOSTAT21_196
# Hilversum
# GEOSTAT21_199
# Hengelo
# GEOSTAT21_201
# Osnabrück
# GEOSTAT21_203
# Apeldoorn
# GEOSTAT21_211
# Braunschweig
# GEOSTAT21_208
# Enschede
# GEOSTAT21_206
# Alphen aan den Rijn
# GEOSTAT21_221
# Den Haag
# GEOSTAT21_905
# Utrecht
# GEOSTAT21_216
# Zoetermeer
# GEOSTAT21_229
# Łódź
# GEOSTAT21_225
# Magdeburg
# GEOSTAT21_220
# Gouda
# GEOSTAT21_223
# Hildesheim
# GEOSTAT21_224
# Nieuwegein / IJsselstein
# GEOSTAT21_240
# Rotterdam
# GEOSTAT21_233
# Zielona Góra
# GEOSTAT21_239
# Arnhem
# GEOSTAT21_237
# Bielefeld
# GEOSTAT21_243
# Münster
# GEOSTAT21_242
# Spijkenisse
# GEOSTAT21_248
# Dordrecht
# GEOSTAT21_249
# Radom
# GEOSTAT21_256
# Nijmegen
# GEOSTAT21_255
# Lublin
# GEOSTAT21_327
# Düsseldorf
# GEOSTAT21_925
# Wuppertal
# GEOSTAT21_316
# Dunkerque
# GEOSTAT21_331
# Mönchengladbach
# GEOSTAT21_332
# Gent
# GEOSTAT21_334
# Solingen
# GEOSTAT21_328
# Remscheid
# GEOSTAT21_335
# Częstochowa
# GEOSTAT21_339
# Dresden
# GEOSTAT21_346
# Köln
# GEOSTAT21_349
# Bruxelles / Brussel
# GEOSTAT21_344
# Leuven
# GEOSTAT21_347
# Heerlen
# GEOSTAT21_348
# Opole
# GEOSTAT21_354
# Porz
# GEOSTAT21_359
# Chemnitz
# GEOSTAT21_358
# Liberec
# GEOSTAT21_360
# Aachen
# GEOSTAT21_363
# Bonn
# GEOSTAT21_364
# Liège
# GEOSTAT21_362
# Ústí nad Labem
# GEOSTAT21_376
# Górnośląski Związek Metropolitalny
# GEOSTAT21_366
# Rzeszów
# GEOSTAT21_367
# Lens
# GEOSTAT21_379
# Charleroi
# GEOSTAT21_265
# s-Hertogenbosch
# GEOSTAT21_274
# Breda
# GEOSTAT21_299
# Ruhrgebiet
# GEOSTAT21_289
# Göttingen
# GEOSTAT21_292
# Eindhoven
# GEOSTAT21_288
# Helmond
# GEOSTAT21_295
# Halle an der Saale
# GEOSTAT21_297
# Moers / Rheinhausen
# GEOSTAT21_302
# Duisburg
# GEOSTAT21_305
# Hagen
# GEOSTAT21_304
# Brugge
# GEOSTAT21_312
# Leipzig
# GEOSTAT21_307
# Krefeld
# GEOSTAT21_317
# Antwerpen
# GEOSTAT21_308
# Kielce
# GEOSTAT21_318
# Wrocław
# GEOSTAT21_320
# Kassel
# GEOSTAT21_922
# Scharwoude / Heerhugowaard
# GEOSTAT21_168
# Alkmaar
# GEOSTAT21_178
# Poznań
# GEOSTAT21_186
# Berlin
# GEOSTAT21_173
# Beverwijk/Heemskerk
# GEOSTAT21_190
# Amsterdam
# GEOSTAT21_177
# Zwolle
# GEOSTAT21_181
# Haarlem
# GEOSTAT21_184
# Almere
# GEOSTAT21_188
# Potsdam
# GEOSTAT21_405
# Wiesbaden
# GEOSTAT21_403
# Havířov
# GEOSTAT21_404
# Hrabuvka
# GEOSTAT21_408
# Mainz
# GEOSTAT21_413
# Darmstadt
# GEOSTAT21_418
# Rouen
# GEOSTAT21_414
# Olomouc
# GEOSTAT21_417
# Würzburg
# GEOSTAT21_416
# Plzeň
# GEOSTAT21_419
# Luxembourg
# GEOSTAT21_420
# Caen
# GEOSTAT21_421
# Erlangen
# GEOSTAT21_457
# Vaihingen / Möhringen
# GEOSTAT21_473
# Reutlingen
# GEOSTAT21_481
# Wien
# GEOSTAT21_476
# Ulm/Neu-Ulm
# GEOSTAT21_479
# Linz
# GEOSTAT21_907
# Augsburg
# GEOSTAT21_487
# München
# GEOSTAT21_488
# Freiburg im Breisgau
# GEOSTAT21_489
# Angers
# GEOSTAT21_496
# Nantes
# GEOSTAT21_495
# Salzburg
# GEOSTAT21_499
# Tours
# GEOSTAT21_510
# Basel
# GEOSTAT21_941
# Gebenstorf / Turgi / Obersiggenthal / Baden / Wettingen
# GEOSTAT21_425
# Mannheim/Ludwigshafen
# GEOSTAT21_429
# Fürth
# GEOSTAT21_427
# Reims
# start: 15:44:50
# Extent set to match uc: 3883000 2917000 3890000 2926000 NaN NaN NaN NaN
# nb record(s) in GEOSTAT21_427_finalGQA.shp subset selection [code_2018] IN (14100,30000,31000) : 124
# Create points from GUA borders used to create SA
# GeneratePointsAlongLines Distance 50m from selected GUA in GEOSTAT21_427_finalGQA.shp to GEOSTAT21_427_GUA_pt_50m
# nb generated points : 1020
# SelectLayerByLocation points in GEOSTAT21_427_GUA_pt_50m WITHIN_A_DISTANCE of 25 meters from nw to GEOSTAT21_427_GUA_pt_50m_nw_25m
# Nb of GQA near network 109
# Total nb of GQA 124
# Centroids and FIDs computed and appended successfully.
# nb points in GEOSTAT21_427_GUA_pt_50m_nw_25m : 658
# GEOSTAT21_427GUA_points_layer
# end: 15:45:43
# GEOSTAT21_428
# Heidelberg
# GEOSTAT21_430
# Brno
# GEOSTAT21_431
# Brest
# start: 15:45:43
# Extent set to match uc: 3251000 2912000 3259000 2918000 NaN NaN NaN NaN
# nb record(s) in GEOSTAT21_431_finalGQA.shp subset selection [code_2018] IN (14100,30000,31000) : 150
# Create points from GUA borders used to create SA
# GeneratePointsAlongLines Distance 50m from selected GUA in GEOSTAT21_431_finalGQA.shp to GEOSTAT21_431_GUA_pt_50m
# nb generated points : 1951
# SelectLayerByLocation points in GEOSTAT21_431_GUA_pt_50m WITHIN_A_DISTANCE of 25 meters from nw to GEOSTAT21_431_GUA_pt_50m_nw_25m
# Nb of GQA near network 137
# Total nb of GQA 150
# Centroids and FIDs computed and appended successfully.
# nb points in GEOSTAT21_431_GUA_pt_50m_nw_25m : 947
# GEOSTAT21_431GUA_points_layer
# end: 15:46:31
# GEOSTAT21_906
# Paris
# GEOSTAT21_432
# Mantes en Yvelines
# GEOSTAT21_435
# Saarbrücken
# GEOSTAT21_437
# Poissy
# GEOSTAT21_441
# Heilbronn
# GEOSTAT21_440
# Les Clayes-sous-Bois
# GEOSTAT21_443
# Maurepas / Montigny-le-Bretonneux
# GEOSTAT21_445
# Regensburg
# GEOSTAT21_447
# Karlsruhe
# GEOSTAT21_448
# Pforzheim
# GEOSTAT21_454
# Stuttgart
# GEOSTAT21_455
# Ingolstadt
# GEOSTAT21_459
# Rennes
# GEOSTAT21_377
# Tarnów
# GEOSTAT21_385
# Kraków
# GEOSTAT21_382
# Arras
# start: 15:46:33
# Extent set to match uc: 3804000 3042000 3810000 3048000 NaN NaN NaN NaN
# nb record(s) in GEOSTAT21_382_finalGQA.shp subset selection [code_2018] IN (14100,30000,31000) : 25
# Create points from GUA borders used to create SA
# GeneratePointsAlongLines Distance 50m from selected GUA in GEOSTAT21_382_finalGQA.shp to GEOSTAT21_382_GUA_pt_50m
# nb generated points : 506
# SelectLayerByLocation points in GEOSTAT21_382_GUA_pt_50m WITHIN_A_DISTANCE of 25 meters from nw to GEOSTAT21_382_GUA_pt_50m_nw_25m
# Nb of GQA near network 17
# Total nb of GQA 25
# Centroids and FIDs computed and appended successfully.
# nb points in GEOSTAT21_382_GUA_pt_50m_nw_25m : 185
# GEOSTAT21_382GUA_points_layer
# end: 15:47:06
# GEOSTAT21_384
# Tychy
# GEOSTAT21_387
# Koblenz
# GEOSTAT21_402
# Praha
# GEOSTAT21_401
# Frankfurt am Main
# GEOSTAT21_394
# Bielsko-Biała
# GEOSTAT21_397
# Ostrava
# GEOSTAT21_400
# Hanau
# GEOSTAT21_398
# Poruba
# GEOSTAT21_542
# Lausanne
# GEOSTAT21_549
# Genève
# GEOSTAT21_550
# Limoges
# start: 15:47:08
# Extent set to match uc: 3639000 2561000 3647000 2567000 NaN NaN NaN NaN
# nb record(s) in GEOSTAT21_550_finalGQA.shp subset selection [code_2018] IN (14100,30000,31000) : 48
# Create points from GUA borders used to create SA
# GeneratePointsAlongLines Distance 50m from selected GUA in GEOSTAT21_550_finalGQA.shp to GEOSTAT21_550_GUA_pt_50m
# nb generated points : 731
# SelectLayerByLocation points in GEOSTAT21_550_GUA_pt_50m WITHIN_A_DISTANCE of 25 meters from nw to GEOSTAT21_550_GUA_pt_50m_nw_25m
# Nb of GQA near network 29
# Total nb of GQA 48
# Centroids and FIDs computed and appended successfully.
# nb points in GEOSTAT21_550_GUA_pt_50m_nw_25m : 166
# GEOSTAT21_550GUA_points_layer
# end: 15:47:43
# GEOSTAT21_558
# Clermont-Ferrand
# start: 15:47:43
# Extent set to match uc: 3780000 2540000 3787000 2550000 NaN NaN NaN NaN
# nb record(s) in GEOSTAT21_558_finalGQA.shp subset selection [code_2018] IN (14100,30000,31000) : 208
# Create points from GUA borders used to create SA
# GeneratePointsAlongLines Distance 50m from selected GUA in GEOSTAT21_558_finalGQA.shp to GEOSTAT21_558_GUA_pt_50m
# nb generated points : 2723
# SelectLayerByLocation points in GEOSTAT21_558_GUA_pt_50m WITHIN_A_DISTANCE of 25 meters from nw to GEOSTAT21_558_GUA_pt_50m_nw_25m
# Nb of GQA near network 180
# Total nb of GQA 208
# Centroids and FIDs computed and appended successfully.
# nb points in GEOSTAT21_558_GUA_pt_50m_nw_25m : 1363
# GEOSTAT21_558GUA_points_layer
# end: 15:48:29
# GEOSTAT21_557
# Lugano
# GEOSTAT21_561
# Zagreb
# GEOSTAT21_569
# Lyon
# start: 15:48:29
# Extent set to match uc: 3909000 2519000 3934000 2538000 NaN NaN NaN NaN
# nb record(s) in GEOSTAT21_569_finalGQA.shp subset selection [code_2018] IN (14100,30000,31000) : 893
# Create points from GUA borders used to create SA
# GeneratePointsAlongLines Distance 50m from selected GUA in GEOSTAT21_569_finalGQA.shp to GEOSTAT21_569_GUA_pt_50m
# nb generated points : 8741
# SelectLayerByLocation points in GEOSTAT21_569_GUA_pt_50m WITHIN_A_DISTANCE of 25 meters from nw to GEOSTAT21_569_GUA_pt_50m_nw_25m
# Nb of GQA near network 704
# Total nb of GQA 893
# Centroids and FIDs computed and appended successfully.
# nb points in GEOSTAT21_569_GUA_pt_50m_nw_25m : 4651
# GEOSTAT21_569GUA_points_layer
# end: 15:49:45
# GEOSTAT21_945
# Saint-Priest / Mions
# GEOSTAT21_624
# Oviedo
# GEOSTAT21_650
# Bilbao
# GEOSTAT21_652
# San Sebastián/Donostia
# GEOSTAT21_657
# Vigo
# GEOSTAT21_665
# León
# GEOSTAT21_672
# Nice
# start: 15:49:46
# Extent set to match uc: 4088000 2284000 4105000 2298000 NaN NaN NaN NaN
# nb record(s) in GEOSTAT21_672_finalGQA.shp subset selection [code_2018] IN (14100,30000,31000) : 318
# Create points from GUA borders used to create SA
# GeneratePointsAlongLines Distance 50m from selected GUA in GEOSTAT21_672_finalGQA.shp to GEOSTAT21_672_GUA_pt_50m
# nb generated points : 6051
# SelectLayerByLocation points in GEOSTAT21_672_GUA_pt_50m WITHIN_A_DISTANCE of 25 meters from nw to GEOSTAT21_672_GUA_pt_50m_nw_25m
# Nb of GQA near network 281
# Total nb of GQA 318
# Centroids and FIDs computed and appended successfully.
# nb points in GEOSTAT21_672_GUA_pt_50m_nw_25m : 2789
# GEOSTAT21_672GUA_points_layer
# end: 15:50:44
# GEOSTAT21_669
# Split
# GEOSTAT21_674
# Vitoria/Gasteiz
# GEOSTAT21_676
# Aix-en-Provence
# GEOSTAT21_682
# Martigues / Port-de-Bouc
# GEOSTAT21_687
# Pamplona/Iruña
# GEOSTAT21_689
# Marseille
# start: 15:50:44
# Extent set to match uc: 3939000 2247000.00000001 3955000 2266000 NaN NaN NaN NaN
# nb record(s) in GEOSTAT21_689_finalGQA.shp subset selection [code_2018] IN (14100,30000,31000) : 550
# Create points from GUA borders used to create SA
# GeneratePointsAlongLines Distance 50m from selected GUA in GEOSTAT21_689_finalGQA.shp to GEOSTAT21_689_GUA_pt_50m
# nb generated points : 7514
# SelectLayerByLocation points in GEOSTAT21_689_GUA_pt_50m WITHIN_A_DISTANCE of 25 meters from nw to GEOSTAT21_689_GUA_pt_50m_nw_25m
# Nb of GQA near network 473
# Total nb of GQA 550
# Centroids and FIDs computed and appended successfully.
# nb points in GEOSTAT21_689_GUA_pt_50m_nw_25m : 3640
# GEOSTAT21_689GUA_points_layer
# end: 15:51:55
# GEOSTAT21_694
# Logroño
# GEOSTAT21_580
# Saint-Etienne
# GEOSTAT21_588
# Rijeka
# GEOSTAT21_595
# Bordeaux
# start: 15:51:55
# Extent set to match uc: 3472000 2464000 3493000 2482000 NaN NaN NaN NaN
# nb record(s) in GEOSTAT21_595_finalGQA.shp subset selection [code_2018] IN (14100,30000,31000) : 492
# Create points from GUA borders used to create SA
# GeneratePointsAlongLines Distance 50m from selected GUA in GEOSTAT21_595_finalGQA.shp to GEOSTAT21_595_GUA_pt_50m
# nb generated points : 7424
# SelectLayerByLocation points in GEOSTAT21_595_GUA_pt_50m WITHIN_A_DISTANCE of 25 meters from nw to GEOSTAT21_595_GUA_pt_50m_nw_25m
# Nb of GQA near network 397
# Total nb of GQA 492
# Centroids and FIDs computed and appended successfully.
# nb points in GEOSTAT21_595_GUA_pt_50m_nw_25m : 3471
# GEOSTAT21_595GUA_points_layer
# end: 15:53:11
# GEOSTAT21_597
# Grenoble
# start: 15:53:11
# Extent set to match uc: 3981000 2455000 3991000 2467000 NaN NaN NaN NaN
# nb record(s) in GEOSTAT21_597_finalGQA.shp subset selection [code_2018] IN (14100,30000,31000) : 230
# Create points from GUA borders used to create SA
# GeneratePointsAlongLines Distance 50m from selected GUA in GEOSTAT21_597_finalGQA.shp to GEOSTAT21_597_GUA_pt_50m
# nb generated points : 2742
# SelectLayerByLocation points in GEOSTAT21_597_GUA_pt_50m WITHIN_A_DISTANCE of 25 meters from nw to GEOSTAT21_597_GUA_pt_50m_nw_25m
# Nb of GQA near network 172
# Total nb of GQA 230
# Centroids and FIDs computed and appended successfully.
# nb points in GEOSTAT21_597_GUA_pt_50m_nw_25m : 1325
# GEOSTAT21_597GUA_points_layer
# end: 15:54:02
# GEOSTAT21_620
# Gijón
# GEOSTAT21_521
# Zürich
# GEOSTAT21_514
# St. Gallen
# GEOSTAT21_519
# Besançon
# GEOSTAT21_520
# Innsbruck
# GEOSTAT21_522
# Graz
# GEOSTAT21_943
# Cham / Zug
# GEOSTAT21_523
# Biel/Bienne
# GEOSTAT21_528
# Bern
# GEOSTAT21_531
# Fribourg
# GEOSTAT21_800
# Castellón de la Plana/Castelló de la Plana
# GEOSTAT21_809
# Valencia
# GEOSTAT21_843
# Lefkosia
# GEOSTAT21_773
# Madrid
# GEOSTAT21_768
# Torrejón de Ardoz
# GEOSTAT21_774
# Fuenlabrada
# GEOSTAT21_706
# Porto
# GEOSTAT21_712
# Valladolid
# GEOSTAT21_856
# Lemesos
# GEOSTAT21_867
# Valletta

# %%
import glob

# %%
GQA_ls = glob.glob(os.path.join(step2_f, '*_finalGQA.shp'))

# %%
len(GQA_ls)
# Out:
# 236

# %%
import glob
SA_ls = glob.glob(os.path.join(step3_f, 'Dissolved', '*.shp'))

# %%
SA_ls[:10]
# Out:
# ['P:\\Environment and Health\\Noise\\ServiceContract\\2024_ServiceContract\\QuietAreas\\OutputData\\step3_SA\\Dissolved\\GEOSTAT21_299_SAd.shp',
#  'P:\\Environment and Health\\Noise\\ServiceContract\\2024_ServiceContract\\QuietAreas\\OutputData\\step3_SA\\Dissolved\\GEOSTAT21_297_SAd.shp',
#  'P:\\Environment and Health\\Noise\\ServiceContract\\2024_ServiceContract\\QuietAreas\\OutputData\\step3_SA\\Dissolved\\GEOSTAT21_919_SAd.shp',
#  'P:\\Environment and Health\\Noise\\ServiceContract\\2024_ServiceContract\\QuietAreas\\OutputData\\step3_SA\\Dissolved\\GEOSTAT21_242_SAd.shp',
#  'P:\\Environment and Health\\Noise\\ServiceContract\\2024_ServiceContract\\QuietAreas\\OutputData\\step3_SA\\Dissolved\\GEOSTAT21_121_SAd.shp',
#  'P:\\Environment and Health\\Noise\\ServiceContract\\2024_ServiceContract\\QuietAreas\\OutputData\\step3_SA\\Dissolved\\GEOSTAT21_141_SAd.shp',
#  'P:\\Environment and Health\\Noise\\ServiceContract\\2024_ServiceContract\\QuietAreas\\OutputData\\step3_SA\\Dissolved\\GEOSTAT21_140_SAd.shp',
#  'P:\\Environment and Health\\Noise\\ServiceContract\\2024_ServiceContract\\QuietAreas\\OutputData\\step3_SA\\Dissolved\\GEOSTAT21_201_SAd.shp',
#  'P:\\Environment and Health\\Noise\\ServiceContract\\2024_ServiceContract\\QuietAreas\\OutputData\\step3_SA\\Dissolved\\GEOSTAT21_225_SAd.shp',
#  'P:\\Environment and Health\\Noise\\ServiceContract\\2024_ServiceContract\\QuietAreas\\OutputData\\step3_SA\\Dissolved\\GEOSTAT21_243_SAd.shp']

# %%
sorted(SA_ls)[:10]
# Out:
# ['P:\\Environment and Health\\Noise\\ServiceContract\\2024_ServiceContract\\QuietAreas\\OutputData\\step3_SA\\Dissolved\\GEOSTAT21_002_SAd.shp',
#  'P:\\Environment and Health\\Noise\\ServiceContract\\2024_ServiceContract\\QuietAreas\\OutputData\\step3_SA\\Dissolved\\GEOSTAT21_003_SAd.shp',
#  'P:\\Environment and Health\\Noise\\ServiceContract\\2024_ServiceContract\\QuietAreas\\OutputData\\step3_SA\\Dissolved\\GEOSTAT21_004_SAd.shp',
#  'P:\\Environment and Health\\Noise\\ServiceContract\\2024_ServiceContract\\QuietAreas\\OutputData\\step3_SA\\Dissolved\\GEOSTAT21_005_SAd.shp',
#  'P:\\Environment and Health\\Noise\\ServiceContract\\2024_ServiceContract\\QuietAreas\\OutputData\\step3_SA\\Dissolved\\GEOSTAT21_006_SAd.shp',
#  'P:\\Environment and Health\\Noise\\ServiceContract\\2024_ServiceContract\\QuietAreas\\OutputData\\step3_SA\\Dissolved\\GEOSTAT21_007_SAd.shp',
#  'P:\\Environment and Health\\Noise\\ServiceContract\\2024_ServiceContract\\QuietAreas\\OutputData\\step3_SA\\Dissolved\\GEOSTAT21_011_SAd.shp',
#  'P:\\Environment and Health\\Noise\\ServiceContract\\2024_ServiceContract\\QuietAreas\\OutputData\\step3_SA\\Dissolved\\GEOSTAT21_012_SAd.shp',
#  'P:\\Environment and Health\\Noise\\ServiceContract\\2024_ServiceContract\\QuietAreas\\OutputData\\step3_SA\\Dissolved\\GEOSTAT21_013_SAd.shp',
#  'P:\\Environment and Health\\Noise\\ServiceContract\\2024_ServiceContract\\QuietAreas\\OutputData\\step3_SA\\Dissolved\\GEOSTAT21_016_SAd.shp']
