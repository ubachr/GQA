# %% [markdown]
# # New version

# %%
#----------------------------------------------------------------------------------
#Author: Veerle Martens
#Date: may 2012
#Adapted by: Raquel Ubach (UAB) - Dec 2023/Jul 2024
#
#Purpose: Create service areas around each building block and find out the area of
#         green urban area that can be reached.
#---------------------------------------------------------------------------------

#create error handler
class CustomError(Exception):
    def __init__(self,value):
        self.value = value
    def __str__(self):
        return repr(self.value)

import sys, arcpy, time, traceback, os.path

def unique_values(table , field):
    with arcpy.da.SearchCursor(table, [field]) as cursor:
        return sorted({row[0] for row in cursor})

def convert(list):
    return tuple(list)

def create_service_area_layer(input_layer, output_layer, network_path, group_id, nb_meters):
    print ("Creating network layer for batch {}".format(group_id))
    salyr = arcpy.MakeServiceAreaLayer_na(network_path, "{}_SA_400m".format(group_id), "Meters", "TRAVEL_FROM", nb_meters, "DETAILED_POLYS", "NO_MERGE", "DISKS", "NO_LINES", "", "", "", "", "ALLOW_UTURNS", "", "NO_TRIM_POLYS", "", "")
    arcpy.AddLocations_na(salyr, "Facilities", input_layer, "Name {} #".format(UATL_ID_Fld), "500 Meters", "", "", "MATCH_TO_CLOSEST", "APPEND", "NO_SNAP", "", "EXCLUDE", "")
    print("Solving network analysis")
    arcpy.Solve_na(salyr, "SKIP")
    return salyr

# %%
# Path to data folders
indata_f = r'P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas'
networks_f = os.path.join(indata_f, 'Network data Regio')
step1_f = os.path.join(indata_f, 'OutputData', 'batch1_allprocessed', 'step1')
temp_f = os.path.join(indata_f, 'Processing', 'step2_CleaningGQA')
step2_f = os.path.join(indata_f, 'OutputData', 'batch1_allprocessed', 'step2')
if not os.path.exists(step2_f):
    os.makedirs(step2_f)

# %%
# Create list of urban centres
uc_file_path = os.path.join(indata_f, 'UrbanCentres', 'HDC2021_RG_InputUpdateB2.shp')

# Specify the columns you need to extract and apply conditions on
columns = ["Batch", "CNTR_CODE", "HDENS_CLST"]

# Initialize an empty list to store the values
values_list = []

# Use an arcpy.da.SearchCursor to iterate over the rows in the shapefile
with arcpy.da.SearchCursor(uc_file_path, columns) as cursor:
    for row in cursor:
        # Apply the selection criteria
        if row[0] == 1.0:
            values_list.append(row[2])

# %%
# input parameters
pedestrian_path = networks_f
outPath = step2_f 
CODE_Fld = "code_2018"
UATL_ID_Fld = "FID"
nbMeters = 400

# %%
# Define the path and name for the geodatabase
gdb_path = temp_f
gdb_name = "SA_output_batch1_v3107_v7.gdb"
outGDB = os.path.join(gdb_path, gdb_name)

# Check if the geodatabase exists
if not arcpy.Exists(outGDB):
    # Create the geodatabase if it does not exist
    arcpy.CreateFileGDB_management(gdb_path, gdb_name)

# %%
# Create a list of files in the directory that end with GQA.shp
GQA_ls = [
    os.path.join(temp_f, f) for f in os.listdir(temp_f)
    if f.endswith('finalGQA.shp')
]

# %%
len(GQA_ls)
# Out:
# 100

# %%
import pandas as pd
# TRANSLATOR TABLE
# Crosswalk table containing the different codes from input sources
codes_path = r'P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\Codes.csv'
codes = pd.read_csv(codes_path)

# %%
codes.head(20)
# Out:
#     FREQUENCY     HDENS_CLST            HDENS_NAME     HDENS_2011  \
# 0           1  GEOSTAT21_002       Oulu / Uleåborg  GEOSTAT11_002
# 1           1  GEOSTAT21_003                  Umeå  GEOSTAT11_003
# 2           1  GEOSTAT21_004             Trondheim  GEOSTAT11_004
# 3           1  GEOSTAT21_005             Jyväskylä  GEOSTAT11_005
# 4           1  GEOSTAT21_006  Tampere / Tammerfors  GEOSTAT11_006
# 5           1  GEOSTAT21_007           Turku / Åbo  GEOSTAT11_007
# 6           1  GEOSTAT21_011                Bergen  GEOSTAT11_011
# 7           1  GEOSTAT21_012               Tallinn  GEOSTAT11_012
# 8           1  GEOSTAT21_013               Uppsala  GEOSTAT11_013
# 9           1  GEOSTAT21_016              Västerås  GEOSTAT11_016
# 10          1  GEOSTAT21_018             Stockholm  GEOSTAT11_018
# 11          1  GEOSTAT21_018             Stockholm  GEOSTAT11_018
# 12          1  GEOSTAT21_018             Stockholm  GEOSTAT11_018
# 13          1  GEOSTAT21_019               Haninge  GEOSTAT11_019
# 14          1  GEOSTAT21_019               Haninge  GEOSTAT11_019
# 15          1  GEOSTAT21_019               Haninge  GEOSTAT11_019
# 16          1  GEOSTAT21_021                 Tartu  GEOSTAT11_021
# 17          1  GEOSTAT21_022                Örebro  GEOSTAT11_022
# 18          1  GEOSTAT21_023             Stavanger  GEOSTAT11_023
# 19          1  GEOSTAT21_024            Norrköping  GEOSTAT11_024
#
#    agglomerationId_identifier agglomerationName_nameEng  \
# 0                  AG_FI_00_6                      Oulu
# 1                 SE_a_ag2480                      Umea
# 2                  AG_NO_00_3                 Trondheim
# 3                  AG_FI_00_9                 Jyvaskyla
# 4                  AG_FI_00_3                   Tampere
# 5                  AG_FI_00_5                     Turku
# 6                  AG_NO_00_2                    Bergen
# 7                  AG_EE_00_1                   Tallinn
# 8                 SE_a_ag0380                   Uppsala
# 9                 SE_a_ag1980                  Vasteras
# 10                SE_a_ag0126                  Huddinge
# 11                SE_a_ag0180                 Stockholm
# 12                SE_a_ag0182                     Nacka
# 13                SE_a_ag0126                  Huddinge
# 14                SE_a_ag0180                 Stockholm
# 15                SE_a_ag0182                     Nacka
# 16                 AG_EE_00_2                Tartu city
# 17                SE_a_ag1880                    Orebro
# 18                 AG_NO_00_4         Stavanger/Sandnes
# 19                SE_a_ag0581                Norrkoping
#
#                                 UA2018
# 0             FI004L4_OULU_UA2018_v013
# 1             SE005L1_UMEA_UA2018_v013
# 2        NO003L1_TRONDHEIM_UA2018_v013
# 3        FI009L2_JYVASKYLA_UA2018_v013
# 4          FI002L3_TAMPERE_UA2018_v013
# 5            FI003L4_TURKU_UA2018_v013
# 6   NL028L3_BERGEN_OP_ZOOM_UA2018_v013
# 7          EE001L1_TALLINN_UA2018_v013
# 8          SE006L1_UPPSALA_UA2018_v013
# 9         SE501L1_VASTERAS_UA2018_v013
# 10       SE001L1_STOCKHOLM_UA2018_v013
# 11       SE001L1_STOCKHOLM_UA2018_v013
# 12       SE001L1_STOCKHOLM_UA2018_v013
# 13       SE001L1_STOCKHOLM_UA2018_v013
# 14       SE001L1_STOCKHOLM_UA2018_v013
# 15       SE001L1_STOCKHOLM_UA2018_v013
# 16           EE002L1_TARTU_UA2018_v013
# 17          SE008L1_OREBRO_UA2018_v013
# 18       NO004L1_STAVANGER_UA2018_v013
# 19      SE502L1_NORRKOPING_UA2018_v013

# %%
arcpy.CheckInExtension("Network")
if arcpy.CheckExtension("Network") == "Available":
    arcpy.CheckOutExtension("Network")
else:
    raise CustomError("The Network Analyst extension is not available.")

# %%
extension_status = arcpy.CheckExtension("Network")
print(extension_status)
# Out:
# Available

# %%
arcpy.CheckOutExtension("Network")
# Out:
# 'CheckedOut'

# %%
arcpy.CheckExtension("Network")
# Out:
# 'Available'

# %%
available_extensions = arcpy.ListExtensions()
print(available_extensions)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Q:\UserTemp\ubach\AppData\Local\Temp\30\ipykernel_817180\424246924.py in <cell line: 0>()
# ----> 1 available_extensions = arcpy.ListExtensions()
#       2 print(available_extensions)
#
# AttributeError: module 'arcpy' has no attribute 'ListExtensions'

# %%
#Environment settings
arcpy.env.overwriteOutput = 'true'
try:
    arcpy.CheckOutExtension("Network")
    print("Network Analyst extension has been checked out.")
except arcpy.ExecuteError:
    print("Failed to check out the Network Analyst extension.")
    
uc_file_path = os.path.join(indata_f, 'UrbanCentres', 'HDC2021_RG_InputUpdateB2.shp')
sql_query = "Batch = 1"
with arcpy.da.SearchCursor(uc_file_path, ["SHAPE@", "HDENS_CLST", "CNTR_CODE"], where_clause=sql_query) as uc_cursor:
    for uc_row in uc_cursor:
        geom = uc_row[0]  # Geometry object
        ctr_cd = uc_row[2]
        uc_code = uc_row[1]
        print(uc_code)
        print(codes.query(f'HDENS_CLST == "{uc_code}"').HDENS_NAME.values.astype(str)[0].strip())
        
        inGQA = os.path.join(temp_f, '{}_finalGQA.shp'.format(uc_code))
        if os.path.exists(inGQA) and ctr_cd!="NO":
            print(inGQA)
            pedestrianNWpath = pedestrian_path + r"\NW_" + ctr_cd + ".gdb\\" + ctr_cd + r"\Network_ND"
            if not arcpy.Exists(pedestrianNWpath):
                raise CustomError("Featureclass " + pedestrianNWpath + " NOT FOUND")

            arcpy.env.extent = geom.extent # Extent object of the geometry
            print("Extent set to match uc: {}".format(arcpy.env.extent))

            try:          

                if arcpy.Exists("{}_UATLlayer".format(uc_code)):
                    arcpy.Delete_management("{}_UATLlayer".format(uc_code))
                uatlLyr = arcpy.MakeFeatureLayer_management(inGQA, "{}_UATLlayer".format(uc_code))

                ## Count number of GUA Blocks
                cnt = arcpy.GetCount_management(uatlLyr)
                print ("nb record(s) in " + os.path.basename(inGQA) + " subset selection [" + CODE_Fld + "] IN (14100,30000,31000) : " +  cnt.getOutput(0))

                ## Create and Select points from GUA borders used to create SA
                print ("Create points from GUA borders used to create SA")

                #fc_GUA_pt_50m = outPath + "\\GUA_pt_50m.shp" ## modified to output folder
                fc_GUA_pt_50m = outGDB +"\\{}_GUA_pt_50m".format(uc_code)

                if arcpy.Exists(fc_GUA_pt_50m):
                    arcpy.Delete_management(fc_GUA_pt_50m)
                print ("GeneratePointsAlongLines Distance 50m from selected GUA in " + os.path.basename(inGQA) + " to " + os.path.basename(fc_GUA_pt_50m))
                arcpy.GeneratePointsAlongLines_management(uatlLyr, fc_GUA_pt_50m, 'DISTANCE', Distance='50 meters', Include_End_Points='END_POINTS')

                cnt = arcpy.GetCount_management(fc_GUA_pt_50m)
                nbrec = cnt.getOutput(0)
                print ("nb generated points : " + nbrec)

                if arcpy.Exists('{}_GUA_PT_50m_lyr'.format(uc_code)):
                    arcpy.Delete_management('{}_GUA_PT_50m_lyr'.format(uc_code))
                arcpy.MakeFeatureLayer_management(fc_GUA_pt_50m, '{}_GUA_PT_50m_lyr'.format(uc_code)) 

                fc_GUA_pt_50m_nw_25m = outGDB +"\\{}_GUA_pt_50m_nw_25m".format(uc_code)    
                if arcpy.Exists(fc_GUA_pt_50m_nw_25m):
                    arcpy.Delete_management(fc_GUA_pt_50m_nw_25m)
                nw_Path = pedestrian_path + r"\NW_" + ctr_cd + ".gdb" + "\\" + ctr_cd + "\\nw"
                print ("SelectLayerByLocation points in " + os.path.basename(fc_GUA_pt_50m) + " WITHIN_A_DISTANCE of 25 meters from " + os.path.basename(nw_Path)+ " to " + os.path.basename(fc_GUA_pt_50m_nw_25m))
                Selection = arcpy.SelectLayerByLocation_management('{}_GUA_PT_50m_lyr'.format(uc_code), 'WITHIN_A_DISTANCE', nw_Path, "25 meters", "NEW_SELECTION")
                # save selection in a diferent feature class
                arcpy.CopyFeatures_management(Selection, fc_GUA_pt_50m_nw_25m) 
                # Adding FID field to the point feature class if it doesn't already exist
                if 'FID' not in [f.name for f in arcpy.ListFields(fc_GUA_pt_50m_nw_25m)]:
                    arcpy.AddField_management(fc_GUA_pt_50m_nw_25m, 'FID', 'LONG')

                UATL_Ids_GUAs_nw_25m = unique_values(fc_GUA_pt_50m_nw_25m, "ORIG_FID")
                print("Nb of GQA near network " + str(len(UATL_Ids_GUAs_nw_25m)))
                ids_ls_GQA = unique_values(uatlLyr, "FID")
                print("Total nb of GQA " +str(len(ids_ls_GQA)))

                # GQA without access to network (less than 25m)
                ids_noaccess = [item for item in ids_ls_GQA if item not in UATL_Ids_GUAs_nw_25m]
                
                # List to hold centroid points and their corresponding FIDs
                centroid_points = []
                fields_ls = ["FID", "SHAPE@", "Area"] # List of fields to include
                # Create a search cursor to iterate through the polygon shapefile GQA
                with arcpy.da.SearchCursor(uatlLyr, fields_ls) as cursor:
                    for row in cursor:
                        if row[0] in ids_noaccess:
                            # Get the FID and the geometry of the polygon
                            fid = row[0]
                            polygon = row[1]
                            area = row[2]
                            # Compute the centroid of the polygon
                            centroid = polygon.centroid
                            # Append the FID and centroid to the list
                            centroid_points.append((fid, centroid, area))

                # Start an edit session for the geodatabase
                with arcpy.da.Editor(outGDB) as edit:
                    # Create an insert cursor for the point feature class
                    with arcpy.da.InsertCursor(fc_GUA_pt_50m_nw_25m, fields_ls) as cursor:
                        for fid, point, area in centroid_points:
                            # Insert the centroid point and the FID
                            cursor.insertRow([fid, point, area])
                print("Centroids and FIDs computed and appended successfully.")

                # Add FID value to all records
                field_to_check = 'FID'
                alternative_field = 'ORIG_FID'
                #expression = f"!{field_to_check}! if !{field_to_check}! is not None else !{alternative_field}!"
                expression ="!FID! if !FID! is not None else !ORIG_FID!"
                # Execute CalculateField
                arcpy.CalculateField_management(fc_GUA_pt_50m_nw_25m, field_to_check, expression, "PYTHON3")

                cnt = arcpy.GetCount_management(fc_GUA_pt_50m_nw_25m)
                nbrec = cnt.getOutput(0)
                print ("nb points in " + os.path.basename(fc_GUA_pt_50m_nw_25m) + " : " + nbrec)

                
                #Loop through to prevent memory errors
                # Batch processing to prevent memory issues
                batch_size = 20000 
                print(f'batch size {batch_size}')

                # Function to create service area layer
                for i in range(0, int(nbrec), batch_size):
                    j = min(i + batch_size, int(nbrec))
                    print ("this is i {} and this is j {}".format(i,j))
                    expr = "\"OBJECTID\" >= {} AND \"OBJECTID\" < {}".format(i,j)

                    if arcpy.Exists("GUA_points_layer"):
                        arcpy.Delete_management("GUA_points_layer")
                    GUA_pt_lyr = arcpy.MakeFeatureLayer_management(fc_GUA_pt_50m_nw_25m, "{}GUA_points_layer".format(uc_code), expr)
                    print('GUA_pt_lyr')

                    # Create service area layer
                    salyr = create_service_area_layer(GUA_pt_lyr, "{}_SA_400m_batch_{}_{}".format(uc_code,i,j), pedestrianNWpath, uc_code, nbMeters)

                    if i == 0:
                        fc_SA = os.path.join(gdb_path, gdb_name, "{}_SA".format(uc_code))
                        if arcpy.Exists(fc_SA):
                            arcpy.Delete_management(fc_SA)
                        #saFC = arcpy.CopyFeatures_management(salyr + "\\Polygons", fc_SA)
                        saFC = arcpy.CopyFeatures_management("{}_SA_400m\Polygons".format(uc_code), fc_SA)
                        
                    else:
                        tmpFC = arcpy.CopyFeatures_management("{}_SA_400m\Polygons".format(uc_code), os.path.join(gdb_path, gdb_name, "{}_sa_batch_{}_{}").format(uc_code,i,j))
                        arcpy.Append_management(tmpFC, saFC, "NO_TEST")
                        arcpy.Delete_management(tmpFC)

                    arcpy.Delete_management(salyr) 

              

                print ("end: " + time.strftime("%H:%M:%S", time.localtime()))
                
            except CustomError as ce:
                arcpy.AddError(ce.value)
                print (ce.value)
            except arcpy.ExecuteError:
                msgs = arcpy.GetMessages(2)
                arcpy.AddError(msgs)
                print (msgs)
            except:
                tb = sys.exc_info()[2]
                tbinfo = traceback.format_tb(tb)[0]
                pymsg = "PYTHON ERRORS:\nTraceback info:\n" + tbinfo + "\nError Info:\n" + str(sys.exc_info()[1])
                msgs = "ArcPy ERRORS:\n" + arcpy.GetMessages(2) + "\n"
                arcpy.AddError(pymsg)
                print (msgs)
                arcpy.AddError(msgs)
                print (pymsg)
            finally:
                arcpy.CheckInExtension("Network")
# Out:
# Network Analyst extension has been checked out.
# GEOSTAT21_018
# Stockholm
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_018_finalGQA.shp
# Extent set to match uc: 4763000 4038000 4791000 4065000 NaN NaN NaN NaN
# nb record(s) in GEOSTAT21_018_finalGQA.shp subset selection [code_2018] IN (14100,30000,31000) : 1609
# Create points from GUA borders used to create SA
# GeneratePointsAlongLines Distance 50m from selected GUA in GEOSTAT21_018_finalGQA.shp to GEOSTAT21_018_GUA_pt_50m
# nb generated points : 20406
# SelectLayerByLocation points in GEOSTAT21_018_GUA_pt_50m WITHIN_A_DISTANCE of 25 meters from nw to GEOSTAT21_018_GUA_pt_50m_nw_25m
# Nb of GQA near network 1364
# Total nb of GQA 1609
# Centroids and FIDs computed and appended successfully.
# nb points in GEOSTAT21_018_GUA_pt_50m_nw_25m : 12852
# batch size 20000
# this is i 0 and this is j 12852
# GUA_pt_lyr
# Creating network layer for batch GEOSTAT21_018
# Solving network analysis
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
arcpy.env.addOutputsToMap = False

# %% [markdown]
# ## All in one cell

# %%
#----------------------------------------------------------------------------------
#Author: Veerle Martens
#Date: may 2012
#Adapted by: Raquel Ubach (UAB) - Dec 2023/Jul 2024
#
#Purpose: Create service areas around each building block and find out the area of
#         green urban area that can be reached.
#---------------------------------------------------------------------------------

#create error handler
class CustomError(Exception):
    def __init__(self,value):
        self.value = value
    def __str__(self):
        return repr(self.value)

import sys, arcpy, time, traceback, os.path
import pandas as pd

def unique_values(table , field):
    with arcpy.da.SearchCursor(table, [field]) as cursor:
        return sorted({row[0] for row in cursor})

def convert(list):
    return tuple(list)

def create_service_area_layer(input_layer, output_layer, network_path, group_id, nb_meters):
    print ("Creating network layer for batch {}".format(group_id))
    salyr = arcpy.MakeServiceAreaLayer_na(network_path, "{}_SA_400m".format(group_id), "Meters", "TRAVEL_FROM", nb_meters, "DETAILED_POLYS", "NO_MERGE", "DISKS", "NO_LINES", "", "", "", "", "ALLOW_UTURNS", "", "NO_TRIM_POLYS", "", "")
    arcpy.AddLocations_na(salyr, "Facilities", input_layer, "Name {} #".format(UATL_ID_Fld), "500 Meters", "", "", "MATCH_TO_CLOSEST", "APPEND", "NO_SNAP", "", "EXCLUDE", "")
    print("Solving network analysis")
    arcpy.Solve_na(salyr, "SKIP")
    return salyr

# Path to data folders
indata_f = r'P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas'
networks_f = os.path.join(indata_f, 'Network data Regio')
step1_f = os.path.join(indata_f, 'OutputData', 'batch1_allprocessed', 'step1')
temp_f = os.path.join(indata_f, 'Processing', 'step2_CleaningGQA')
step2_f = os.path.join(indata_f, 'OutputData', 'batch1_allprocessed', 'step2')
if not os.path.exists(step2_f):
    os.makedirs(step2_f)
uc_file_path = os.path.join(indata_f, 'UrbanCentres', 'HDC2021_RG_InputUpdateB2.shp')

# input parameters
pedestrian_path = networks_f
outPath = step2_f 
CODE_Fld = "code_2018"
UATL_ID_Fld = "FID"
nbMeters = 400

# Define the path and name for the geodatabase
gdb_path = temp_f
gdb_name = "SA_output_batch1_v3107_v7.gdb"
outGDB = os.path.join(gdb_path, gdb_name)

# Check if the geodatabase exists
if not arcpy.Exists(outGDB):
    # Create the geodatabase if it does not exist
    arcpy.CreateFileGDB_management(gdb_path, gdb_name)

    
# TRANSLATOR TABLE
# Crosswalk table containing the different codes from input sources
codes_path = r'P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\Codes.csv'
codes = pd.read_csv(codes_path)

#Environment settings
arcpy.env.overwriteOutput = True
arcpy.env.addOutputsToMap = False

try:
    arcpy.CheckOutExtension("Network")
    print("Network Analyst extension has been checked out.")
except arcpy.ExecuteError:
    print("Failed to check out the Network Analyst extension.")
    
# Run process for Batch N
sql_query = "Batch = 1"
with arcpy.da.SearchCursor(uc_file_path, ["SHAPE@", "HDENS_CLST", "CNTR_CODE"], where_clause=sql_query) as uc_cursor:
    for uc_row in uc_cursor:
        geom = uc_row[0]  # Geometry object
        ctr_cd = uc_row[2]
        uc_code = uc_row[1]
        print(uc_code)
        print(codes.query(f'HDENS_CLST == "{uc_code}"').HDENS_NAME.values.astype(str)[0].strip())
        
        inGQA = os.path.join(temp_f, '{}_finalGQA.shp'.format(uc_code))
        fc_SA = os.path.join(gdb_path, gdb_name, "{}_SA".format(uc_code))

        if os.path.exists(inGQA) and not arcpy.Exists(fc_SA) and ctr_cd!="NO":
            print ("start: " + time.strftime("%H:%M:%S", time.localtime()))
            pedestrianNWpath = pedestrian_path + r"\NW_" + ctr_cd + ".gdb\\" + ctr_cd + r"\Network_ND"
            if not arcpy.Exists(pedestrianNWpath):
                raise CustomError("Featureclass " + pedestrianNWpath + " NOT FOUND")

            arcpy.env.extent = geom.extent # Extent object of the geometry
            print("Extent set to match uc: {}".format(arcpy.env.extent))

            try:          

                if arcpy.Exists("{}_UATLlayer".format(uc_code)):
                    arcpy.Delete_management("{}_UATLlayer".format(uc_code))
                uatlLyr = arcpy.MakeFeatureLayer_management(inGQA, "{}_UATLlayer".format(uc_code))

                ## Count number of GUA Blocks
                cnt = arcpy.GetCount_management(uatlLyr)
                print ("nb record(s) in " + os.path.basename(inGQA) + " subset selection [" + CODE_Fld + "] IN (14100,30000,31000) : " +  cnt.getOutput(0))

                ## Create and Select points from GUA borders used to create SA
                print ("Create points from GUA borders used to create SA")

                #fc_GUA_pt_50m = outPath + "\\GUA_pt_50m.shp" ## modified to output folder
                fc_GUA_pt_50m = outGDB +"\\{}_GUA_pt_50m".format(uc_code)

                if arcpy.Exists(fc_GUA_pt_50m):
                    arcpy.Delete_management(fc_GUA_pt_50m)
                print ("GeneratePointsAlongLines Distance 50m from selected GUA in " + os.path.basename(inGQA) + " to " + os.path.basename(fc_GUA_pt_50m))
                arcpy.GeneratePointsAlongLines_management(uatlLyr, fc_GUA_pt_50m, 'DISTANCE', Distance='50 meters', Include_End_Points='END_POINTS')

                cnt = arcpy.GetCount_management(fc_GUA_pt_50m)
                nbrec = cnt.getOutput(0)
                print ("nb generated points : " + nbrec)

                if arcpy.Exists('{}_GUA_PT_50m_lyr'.format(uc_code)):
                    arcpy.Delete_management('{}_GUA_PT_50m_lyr'.format(uc_code))
                arcpy.MakeFeatureLayer_management(fc_GUA_pt_50m, '{}_GUA_PT_50m_lyr'.format(uc_code)) 

                fc_GUA_pt_50m_nw_25m = outGDB +"\\{}_GUA_pt_50m_nw_25m".format(uc_code)    
                if arcpy.Exists(fc_GUA_pt_50m_nw_25m):
                    arcpy.Delete_management(fc_GUA_pt_50m_nw_25m)
                nw_Path = pedestrian_path + r"\NW_" + ctr_cd + ".gdb" + "\\" + ctr_cd + "\\nw"
                print ("SelectLayerByLocation points in " + os.path.basename(fc_GUA_pt_50m) + " WITHIN_A_DISTANCE of 25 meters from " + os.path.basename(nw_Path)+ " to " + os.path.basename(fc_GUA_pt_50m_nw_25m))
                Selection = arcpy.SelectLayerByLocation_management('{}_GUA_PT_50m_lyr'.format(uc_code), 'WITHIN_A_DISTANCE', nw_Path, "25 meters", "NEW_SELECTION")
                # save selection in a diferent feature class
                arcpy.CopyFeatures_management(Selection, fc_GUA_pt_50m_nw_25m) 
                # Adding FID field to the point feature class if it doesn't already exist
                if 'FID' not in [f.name for f in arcpy.ListFields(fc_GUA_pt_50m_nw_25m)]:
                    arcpy.AddField_management(fc_GUA_pt_50m_nw_25m, 'FID', 'LONG')

                UATL_Ids_GUAs_nw_25m = unique_values(fc_GUA_pt_50m_nw_25m, "ORIG_FID")
                print("Nb of GQA near network " + str(len(UATL_Ids_GUAs_nw_25m)))
                ids_ls_GQA = unique_values(uatlLyr, "FID")
                print("Total nb of GQA " +str(len(ids_ls_GQA)))

                # GQA without access to network (less than 25m)
                ids_noaccess = [item for item in ids_ls_GQA if item not in UATL_Ids_GUAs_nw_25m]
                
                # List to hold centroid points and their corresponding FIDs
                centroid_points = []
                fields_ls = ["FID", "SHAPE@", "Area"] # List of fields to include
                # Create a search cursor to iterate through the polygon shapefile GQA
                with arcpy.da.SearchCursor(uatlLyr, fields_ls) as cursor:
                    for row in cursor:
                        if row[0] in ids_noaccess:
                            # Get the FID and the geometry of the polygon
                            fid = row[0]
                            polygon = row[1]
                            area = row[2]
                            # Compute the centroid of the polygon
                            centroid = polygon.centroid
                            # Append the FID and centroid to the list
                            centroid_points.append((fid, centroid, area))

                # Start an edit session for the geodatabase
                with arcpy.da.Editor(outGDB) as edit:
                    # Create an insert cursor for the point feature class
                    with arcpy.da.InsertCursor(fc_GUA_pt_50m_nw_25m, fields_ls) as cursor:
                        for fid, point, area in centroid_points:
                            # Insert the centroid point and the FID
                            cursor.insertRow([fid, point, area])
                print("Centroids and FIDs computed and appended successfully.")

                # Add FID value to all records
                field_to_check = 'FID'
                alternative_field = 'ORIG_FID'
                #expression = f"!{field_to_check}! if !{field_to_check}! is not None else !{alternative_field}!"
                expression ="!FID! if !FID! != None else !ORIG_FID!"
                # Execute CalculateField
                arcpy.CalculateField_management(fc_GUA_pt_50m_nw_25m, field_to_check, expression, "PYTHON3")

                cnt = arcpy.GetCount_management(fc_GUA_pt_50m_nw_25m)
                nbrec = cnt.getOutput(0)
                print ("nb points in " + os.path.basename(fc_GUA_pt_50m_nw_25m) + " : " + nbrec)

                
                #Loop through to prevent memory errors
                # Batch processing to prevent memory issues
                batch_size = 5000 
                print(f'batch size {batch_size}')

                # Function to create service area layer
                for i in range(0, int(nbrec), batch_size):
                    j = min(i + batch_size, int(nbrec))
                    print ("this is i {} and this is j {}".format(i,j))
                    expr = "\"OBJECTID\" >= {} AND \"OBJECTID\" < {}".format(i,j)

                    if arcpy.Exists("GUA_points_layer"):
                        arcpy.Delete_management("GUA_points_layer")
                    GUA_pt_lyr = arcpy.MakeFeatureLayer_management(fc_GUA_pt_50m_nw_25m, "{}GUA_points_layer".format(uc_code), expr)
                    print('GUA_pt_lyr')

                    # Create service area layer
                    salyr = create_service_area_layer(GUA_pt_lyr, "{}_SA_400m_batch_{}_{}".format(uc_code,i,j), pedestrianNWpath, uc_code, nbMeters)

                    if i == 0:
                        fc_SA = os.path.join(gdb_path, gdb_name, "{}_SA".format(uc_code))
                        if arcpy.Exists(fc_SA):
                            arcpy.Delete_management(fc_SA)
                        #saFC = arcpy.CopyFeatures_management(salyr + "\\Polygons", fc_SA)
                        saFC = arcpy.CopyFeatures_management("{}_SA_400m\Polygons".format(uc_code), fc_SA)
                        
                    else:
                        tmpFC = arcpy.CopyFeatures_management("{}_SA_400m\Polygons".format(uc_code), os.path.join(gdb_path, gdb_name, "{}_sa_batch_{}_{}").format(uc_code,i,j))
                        arcpy.Append_management(tmpFC, saFC, "NO_TEST")
                        arcpy.Delete_management(tmpFC)

                    arcpy.Delete_management(salyr) 

                print ("end: " + time.strftime("%H:%M:%S", time.localtime()))
                
            except CustomError as ce:
                arcpy.AddError(ce.value)
                print (ce.value)
            except arcpy.ExecuteError:
                msgs = arcpy.GetMessages(2)
                arcpy.AddError(msgs)
                print (msgs)
            except:
                tb = sys.exc_info()[2]
                tbinfo = traceback.format_tb(tb)[0]
                pymsg = "PYTHON ERRORS:\nTraceback info:\n" + tbinfo + "\nError Info:\n" + str(sys.exc_info()[1])
                msgs = "ArcPy ERRORS:\n" + arcpy.GetMessages(2) + "\n"
                arcpy.AddError(pymsg)
                print (msgs)
                arcpy.AddError(msgs)
                print (pymsg)
            finally:
                arcpy.CheckInExtension("Network")

# %%
#         green urban area that can be reached.
#---------------------------------------------------------------------------------

#create error handler
class CustomError(Exception):
    def __init__(self,value):
        self.value = value
    def __str__(self):
        return repr(self.value)

import sys, arcpy, time, traceback, os.path
import pandas as pd

def unique_values(table , field):
    with arcpy.da.SearchCursor(table, [field]) as cursor:
        return sorted({row[0] for row in cursor})

def convert(list):
    return tuple(list)

def create_service_area_layer(input_layer, output_layer, network_path, group_id, nb_meters):
    print ("Creating network layer for batch {}".format(group_id))
    salyr = arcpy.MakeServiceAreaLayer_na(network_path, "{}_SA_400m".format(group_id), "Meters", "TRAVEL_FROM", nb_meters, "DETAILED_POLYS", "NO_MERGE", "DISKS", "NO_LINES", "", "", "", "", "ALLOW_UTURNS", "", "NO_TRIM_POLYS", "", "")
    arcpy.AddLocations_na(salyr, "Facilities", input_layer, "Name {} #".format(UATL_ID_Fld), "500 Meters", "", "", "MATCH_TO_CLOSEST", "APPEND", "NO_SNAP", "", "EXCLUDE", "")
    print("Solving network analysis")
    arcpy.Solve_na(salyr, "SKIP")
    return salyr

# Path to data folders
indata_f = r'P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas'
networks_f = os.path.join(indata_f, 'Network data Regio')
step1_f = os.path.join(indata_f, 'OutputData', 'batch1_allprocessed', 'step1')
temp_f = os.path.join(indata_f, 'Processing', 'step2_CleaningGQA')
step2_f = os.path.join(indata_f, 'OutputData', 'batch1_allprocessed', 'step2')
if not os.path.exists(step2_f):
    os.makedirs(step2_f)
uc_file_path = os.path.join(indata_f, 'UrbanCentres', 'HDC2021_RG_InputUpdateB2.shp')

# input parameters
pedestrian_path = networks_f
outPath = step2_f 
CODE_Fld = "code_2018"
UATL_ID_Fld = "FID"
nbMeters = 400

# Define the path and name for the geodatabase
gdb_path = temp_f
gdb_name = "SA_output_batch1_v3107_v7.gdb"
outGDB = os.path.join(gdb_path, gdb_name)

# Check if the geodatabase exists
if not arcpy.Exists(outGDB):
    # Create the geodatabase if it does not exist
    arcpy.CreateFileGDB_management(gdb_path, gdb_name)

    
# TRANSLATOR TABLE
# Crosswalk table containing the different codes from input sources
codes_path = r'P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\Codes.csv'
codes = pd.read_csv(codes_path)

#Environment settings
arcpy.env.overwriteOutput = True
arcpy.env.addOutputsToMap = False

try:
    arcpy.CheckOutExtension("Network")
    print("Network Analyst extension has been checked out.")
except arcpy.ExecuteError:
    print("Failed to check out the Network Analyst extension.")
    
# Run process for Batch N
sql_query = "Batch = 1"
with arcpy.da.SearchCursor(uc_file_path, ["SHAPE@", "HDENS_CLST", "CNTR_CODE"], where_clause=sql_query) as uc_cursor:
    for uc_row in uc_cursor:
        geom = uc_row[0]  # Geometry object
        ctr_cd = uc_row[2]
        uc_code = uc_row[1]
        print(uc_code)
        print(codes.query(f'HDENS_CLST == "{uc_code}"').HDENS_NAME.values.astype(str)[0].strip())
        
        inGQA = os.path.join(temp_f, '{}_finalGQA.shp'.format(uc_code))
        fc_SA = os.path.join(gdb_path, gdb_name, "{}_SA".format(uc_code))

        if os.path.exists(inGQA) and not arcpy.Exists(fc_SA) and ctr_cd!="NO":
            print ("start: " + time.strftime("%H:%M:%S", time.localtime()))
            print (inGQA)
            print (fc_SA)
            print (ctr_cd)
# Out:
# Network Analyst extension has been checked out.
# GEOSTAT21_018
# Stockholm
# GEOSTAT21_021
# Tartu
# GEOSTAT21_023
# Stavanger
# GEOSTAT21_024
# Norrköping
# GEOSTAT21_025
# Linköping
# GEOSTAT21_029
# Göteborg
# start: 10:57:57
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_029_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_029_SA
# SE
# GEOSTAT21_028
# Rīga
# start: 10:57:57
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_028_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_028_SA
# LV
# GEOSTAT21_031
# Aalborg
# start: 10:57:57
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_031_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_031_SA
# DK
# GEOSTAT21_047
# Århus
# start: 10:57:58
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_047_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_047_SA
# DK
# GEOSTAT21_048
# Helsingborg
# start: 10:57:58
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_048_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_048_SA
# SE
# GEOSTAT21_903
# København
# start: 10:57:58
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_903_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_903_SA
# DK
# GEOSTAT21_049
# Lund
# start: 10:57:58
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_049_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_049_SA
# SE
# GEOSTAT21_051
# Kaunas
# start: 10:57:58
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_051_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_051_SA
# LT
# GEOSTAT21_054
# Malmö
# start: 10:57:58
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_054_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_054_SA
# SE
# GEOSTAT21_060
# Odense
# start: 10:57:58
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_060_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_060_SA
# DK
# GEOSTAT21_068
# Gdańsk
# start: 10:57:58
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_068_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_068_SA
# PL
# GEOSTAT21_904
# Dublin
# start: 10:57:58
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_904_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_904_SA
# IE
# GEOSTAT21_095
# Limerick
# start: 10:57:58
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_095_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_095_SA
# IE
# GEOSTAT21_119
# Hamburg
# start: 10:57:58
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_119_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_119_SA
# DE
# GEOSTAT21_132
# Cork
# start: 10:57:58
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_132_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_132_SA
# IE
# GEOSTAT21_137
# Groningen
# start: 10:57:58
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_137_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_137_SA
# NL
# GEOSTAT21_145
# Bremen
# start: 10:57:58
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_145_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_145_SA
# DE
# GEOSTAT21_150
# Włocławek
# start: 10:57:58
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_150_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_150_SA
# PL
# GEOSTAT21_171
# Warszawa
# start: 10:57:58
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_171_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_171_SA
# PL
# GEOSTAT21_002
# Oulu / Uleåborg
# start: 10:57:58
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_002_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_002_SA
# FI
# GEOSTAT21_004
# Trondheim
# GEOSTAT21_006
# Tampere / Tammerfors
# start: 10:57:58
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_006_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_006_SA
# FI
# GEOSTAT21_901
# Helsinki
# start: 10:57:58
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_901_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_901_SA
# FI
# GEOSTAT21_007
# Turku / Åbo
# start: 10:57:58
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_007_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_007_SA
# FI
# GEOSTAT21_011
# Bergen
# GEOSTAT21_012
# Tallinn
# start: 10:57:58
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_012_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_012_SA
# EE
# GEOSTAT21_013
# Uppsala
# start: 10:57:58
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_013_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_013_SA
# SE
# GEOSTAT21_902
# Oslo
# GEOSTAT21_912
# Drammen
# GEOSTAT21_905
# Utrecht
# start: 10:57:58
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_905_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_905_SA
# NL
# GEOSTAT21_240
# Rotterdam
# start: 10:57:58
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_240_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_240_SA
# NL
# GEOSTAT21_233
# Zielona Góra
# start: 10:57:59
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_233_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_233_SA
# PL
# GEOSTAT21_332
# Gent
# start: 10:57:59
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_332_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_332_SA
# BE
# GEOSTAT21_346
# Köln
# start: 10:57:59
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_346_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_346_SA
# DE
# GEOSTAT21_349
# Bruxelles / Brussel
# start: 10:57:59
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_349_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_349_SA
# BE
# GEOSTAT21_344
# Leuven
# start: 10:57:59
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_344_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_344_SA
# BE
# GEOSTAT21_358
# Liberec
# start: 10:57:59
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_358_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_358_SA
# CZ
# GEOSTAT21_363
# Bonn
# start: 10:57:59
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_363_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_363_SA
# DE
# GEOSTAT21_364
# Liège
# start: 10:57:59
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_364_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_364_SA
# BE
# GEOSTAT21_362
# Ústí nad Labem
# start: 10:57:59
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_362_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_362_SA
# CZ
# GEOSTAT21_376
# Górnośląski Związek Metropolitalny
# start: 10:57:59
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_376_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_376_SA
# PL
# GEOSTAT21_379
# Charleroi
# start: 10:57:59
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_379_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_379_SA
# BE
# GEOSTAT21_299
# Ruhrgebiet
# start: 10:57:59
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_299_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_299_SA
# DE
# GEOSTAT21_292
# Eindhoven
# start: 10:57:59
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_292_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_292_SA
# NL
# GEOSTAT21_317
# Antwerpen
# start: 10:57:59
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_317_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_317_SA
# BE
# GEOSTAT21_318
# Wrocław
# start: 10:57:59
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_318_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_318_SA
# PL
# GEOSTAT21_922
# Scharwoude / Heerhugowaard
# start: 10:57:59
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_922_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_922_SA
# NL
# GEOSTAT21_186
# Berlin
# start: 10:57:59
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_186_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_186_SA
# DE
# GEOSTAT21_190
# Amsterdam
# start: 10:57:59
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_190_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_190_SA
# NL
# GEOSTAT21_177
# Zwolle
# start: 10:57:59
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_177_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_177_SA
# NL
# GEOSTAT21_413
# Darmstadt
# start: 10:57:59
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_413_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_413_SA
# DE
# GEOSTAT21_414
# Olomouc
# start: 10:57:59
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_414_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_414_SA
# CZ
# GEOSTAT21_416
# Plzeň
# start: 10:57:59
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_416_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_416_SA
# CZ
# GEOSTAT21_419
# Luxembourg
# start: 10:57:59
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_419_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_419_SA
# LU
# GEOSTAT21_420
# Caen
# start: 10:57:59
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_420_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_420_SA
# FR
# GEOSTAT21_457
# Vaihingen / Möhringen
# start: 10:57:59
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_457_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_457_SA
# DE
# GEOSTAT21_473
# Reutlingen
# start: 10:58:00
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_473_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_473_SA
# DE
# GEOSTAT21_481
# Wien
# start: 10:58:00
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_481_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_481_SA
# AT
# GEOSTAT21_476
# Ulm/Neu-Ulm
# start: 10:58:00
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_476_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_476_SA
# DE
# GEOSTAT21_479
# Linz
# start: 10:58:00
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_479_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_479_SA
# AT
# GEOSTAT21_495
# Salzburg
# start: 10:58:00
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_495_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_495_SA
# AT
# GEOSTAT21_510
# Basel
# start: 10:58:00
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_510_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_510_SA
# CH-DE
# GEOSTAT21_427
# Reims
# start: 10:58:00
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_427_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_427_SA
# FR
# GEOSTAT21_430
# Brno
# start: 10:58:00
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_430_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_430_SA
# CZ
# GEOSTAT21_431
# Brest
# start: 10:58:00
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_431_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_431_SA
# FR
# GEOSTAT21_455
# Ingolstadt
# start: 10:58:00
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_455_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_455_SA
# DE
# GEOSTAT21_385
# Kraków
# start: 10:58:00
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_385_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_385_SA
# PL
# GEOSTAT21_382
# Arras
# start: 10:58:00
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_382_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_382_SA
# FR
# GEOSTAT21_402
# Praha
# start: 10:58:00
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_402_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_402_SA
# CZ
# GEOSTAT21_397
# Ostrava
# start: 10:58:00
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_397_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_397_SA
# CZ
# GEOSTAT21_400
# Hanau
# start: 10:58:00
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_400_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_400_SA
# DE
# GEOSTAT21_542
# Lausanne
# start: 10:58:00
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_542_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_542_SA
# CH
# GEOSTAT21_549
# Genève
# start: 10:58:00
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_549_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_549_SA
# CH-FR
# GEOSTAT21_558
# Clermont-Ferrand
# start: 10:58:00
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_558_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_558_SA
# FR
# GEOSTAT21_561
# Zagreb
# start: 10:58:00
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_561_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_561_SA
# HR
# GEOSTAT21_569
# Lyon
# start: 10:58:00
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_569_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_569_SA
# FR
# GEOSTAT21_650
# Bilbao
# start: 10:58:00
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_650_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_650_SA
# ES
# GEOSTAT21_657
# Vigo
# start: 10:58:00
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_657_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_657_SA
# ES
# GEOSTAT21_665
# León
# start: 10:58:00
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_665_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_665_SA
# ES
# GEOSTAT21_672
# Nice
# start: 10:58:00
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_672_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_672_SA
# FR
# GEOSTAT21_669
# Split
# start: 10:58:00
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_669_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_669_SA
# HR
# GEOSTAT21_674
# Vitoria/Gasteiz
# start: 10:58:00
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_674_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_674_SA
# ES
# GEOSTAT21_689
# Marseille
# start: 10:58:00
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_689_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_689_SA
# FR
# GEOSTAT21_588
# Rijeka
# start: 10:58:00
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_588_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_588_SA
# HR
# GEOSTAT21_595
# Bordeaux
# start: 10:58:01
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_595_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_595_SA
# FR
# GEOSTAT21_521
# Zürich
# start: 10:58:01
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_521_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_521_SA
# CH
# GEOSTAT21_520
# Innsbruck
# start: 10:58:01
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_520_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_520_SA
# AT
# GEOSTAT21_522
# Graz
# start: 10:58:01
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_522_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_522_SA
# AT
# GEOSTAT21_528
# Bern
# start: 10:58:01
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_528_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_528_SA
# CH
# GEOSTAT21_809
# Valencia
# start: 10:58:01
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_809_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_809_SA
# ES
# GEOSTAT21_843
# Lefkosia
# start: 10:58:01
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_843_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_843_SA
# CY
# GEOSTAT21_773
# Madrid
# start: 10:58:01
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_773_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_773_SA
# ES
# GEOSTAT21_706
# Porto
# start: 10:58:01
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_706_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_706_SA
# PT
# GEOSTAT21_856
# Lemesos
# start: 10:58:01
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_856_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_856_SA
# CY
# GEOSTAT21_867
# Valletta
# start: 10:58:01
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\GEOSTAT21_867_finalGQA.shp
# P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\step2_CleaningGQA\SA_output_batch1_v3107_v7.gdb\GEOSTAT21_867_SA
# MT

# %%
uc_code = 'GEOSTAT21_018'
fc_GUA_pt_50m_nw_25m = outGDB +"\\{}_GUA_pt_50m_nw_25m".format(uc_code)

# %%
fc_GUA_pt_50m_nw_25m
# Create the expression with a conditional check
field_to_check = 'FID'
alternative_field = 'ORIG_FID'
expression = f"!{field_to_check}! if !{field_to_check}! is not None else !{alternative_field}!"
# Execute CalculateField
arcpy.CalculateField_management(fc_GUA_pt_50m_nw_25m, field_to_check, expression, "PYTHON3")
# Out:
# <Result 'P:\\Environment and Health\\Noise\\ServiceContract\\2024_ServiceContract\\QuietAreas\\Processing\\step2_CleaningGQA\\SA_output_batch1_v3107_v3.gdb\\GEOSTAT21_018_GUA_pt_50m_nw_25m'>

# %%
arcpy.GeneratePointsAlongLines_management(uatlLyr, fc_GUA_pt_50m, 'DISTANCE', Distance='50 meters', Include_End_Points='END_POINTS')

# %%
import arcpy

# Define the path to the shapefile
shapefile_path = r"C:\path\to\your\shapefile.shp"

# Initialize variables to store the combined extent
xmin, ymin, xmax, ymax = None, None, None, None

# Check if the shapefile exists
if arcpy.Exists(shapefile_path):
    # Open a search cursor to iterate through the features
    with arcpy.da.SearchCursor(shapefile_path, ["SHAPE@"]) as cursor:
        for row in cursor:
            geom = row[0]  # Geometry object
            extent = geom.extent  # Extent object of the geometry
            
            # Update the combined extent
            if xmin is None or extent.XMin < xmin:
                xmin = extent.XMin
            if ymin is None or extent.YMin < ymin:
                ymin = extent.YMin
            if xmax is None or extent.XMax > xmax:
                xmax = extent.XMax
            if ymax is None or extent.YMax > ymax:
                ymax = extent.YMax
    
    # Set the environment extent using the combined extent
    if xmin is not None and ymin is not None and xmax is not None and ymax is not None:
        arcpy.env.extent = arcpy.Extent(xmin, ymin, xmax, ymax)
        print(f"Environment extent set to: {arcpy.env.extent}")
    else:
        print("No valid features found in the shapefile to set extent.")
else:
    print(f"Shapefile does not exist at {shapefile_path}")

# %%
# 1 COMMON SOURCES FOR ALL DATA
# URBAN CENTRES
# Read shapefile
uc_file_path = os.path.join(indata_f, 'UrbanCentres', 'HDC2021_RG_InputUpdateB1B2.shp')
# Read the GeoPackage file
uc = gpd.read_file(uc_file_path)
uc['CNTR_CODE'].fillna('AA', inplace=True)

# Select cities for processing in this batch
uc_sel = uc.query('Batch==1.0')
uc_sel = uc_sel.sort_values(by='CNTR_CODE')

# Read table to list the cities to process using urban centre code
cities_ls = uc_sel.HDENS_CLST.tolist()

# NOISE DATA
# Load agglomerations delineations
agls_file_path = os.path.join(indata_f, 'NoiseData', 'DF1_5_Agglomerations_20240429.gpkg')

# Read the GeoPackage file
agls = gpd.read_file(agls_file_path, layer = 'dbo.DF15_AgglomerationSource_Valid_LatestDelivery', 
                     **engines['pyogrio+arrow'],columns=['agglomerationId_identifier', 'agglomerationName_nameEng', 'geometry'])

# URBAN ATLAS
# Read table with HDENS Urban centres information and Agglomerations link
HDENS_AGGL_tbl = pd.read_csv(r'P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\UrbanCentres_Agglomerations_csv.csv')
# Join uc code field to this table
HDENS_AGGL_tbl = HDENS_AGGL_tbl.merge(uc[['POPL_2021', 'HDENS_CLST']], on='POPL_2021')
# UA data folder
ua_data_f = r'A:\Copernicus\UrbanAtlas\UrbanAtlas\UA2018'
# TRANSLATOR TABLE
# Crosswalk table containing the different codes from input sources
codes_path = r'P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\Codes.csv'
codes = pd.read_csv(codes_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Q:\UserTemp\ubach\AppData\Local\Temp\4\ipykernel_433440\2204637657.py in <cell line: 0>()
#       4 uc_file_path = os.path.join(indata_f, 'UrbanCentres', 'HDC2021_RG_InputUpdateB1B2.shp')
#       5 # Read the GeoPackage file
# ----> 6 uc = gpd.read_file(uc_file_path)
#       7 uc['CNTR_CODE'].fillna('AA', inplace=True)
#       8
#
# NameError: name 'gpd' is not defined

# %%
for i in GQA_ls:
    uc_code = os.path.basename(GQA_ls[0])[:-13]
    print(uc_code)
    codes.query(f"HDENS_CLST=='{uc_code}'")

# %%
GEOSTAT21_002_finalGQA.shp

# %%
outCentroids = os.path.join(temp_f, f'{uc_code}_pts_GQA.shp')

# %%
arcpy.CheckInExtension("Network")
if arcpy.CheckExtension("Network") == "Available":
    arcpy.CheckOutExtension("Network")
else:
    raise CustomError("The Network Analyst extension is not available.")

#Environment settings
arcpy.env.overwriteOutput = 'true'
uc_file_path = os.path.join(indata_f, 'UrbanCentres', 'HDC2021_RG_InputUpdateB2.shp')
sql_query = "Batch = 1"
with arcpy.da.SearchCursor(uc_file_path, ["SHAPE@", "HDENS_CLST", "CNTR_CODE"], where_clause=sql_query) as uc_cursor:
    for uc_row in uc_cursor:
        geom = uc_row[0]  # Geometry object
        ctr_cd = uc_row[2]
        uc_code = uc_row[1]
        print(uc_code)
        
        inGQA = os.path.join(temp_f, '{}_finalGQA.shp'.format(uc_code))
        if os.path.exists(inGQA):
            print(inGQA)
            inGQA = inGQA
            ctr_cd = ctr_cd

            pedestrianNWpath = pedestrian_path + r"\NW_" + ctr_cd + ".gdb\\" + ctr_cd + r"\Network_ND"
            if not arcpy.Exists(pedestrianNWpath):
                raise CustomError("Featureclass " + pedestrianNWpath + " NOT FOUND")

            arcpy.env.extent = geom.extent # Extent object of the geometry
            print("Extent set to match uc: {}".format(arcpy.env.extent))

            try:          

                if arcpy.Exists("{}_UATLlayer".format(uc_code)):
                    arcpy.Delete_management("{}_UATLlayer".format(uc_code))
                uatlLyr = arcpy.MakeFeatureLayer_management(inGQA, "{}_UATLlayer".format(uc_code))

                ## Count number of GUA Blocks
                cnt = arcpy.GetCount_management(uatlLyr)
                print ("nb record(s) in " + os.path.basename(inGQA) + " subset selection [" + CODE_Fld + "] IN (14100,30000,31000) : " +  cnt.getOutput(0))

                ## Create and Select points from GUA borders used to create SA
                print ("Create points from GUA borders used to create SA")

                #fc_GUA_pt_50m = outPath + "\\GUA_pt_50m.shp" ## modified to output folder
                fc_GUA_pt_50m = outGDB +"\\{}_GUA_pt_50m".format(uc_code)

                if arcpy.Exists(fc_GUA_pt_50m):
                    arcpy.Delete_management(fc_GUA_pt_50m)
                print ("GeneratePointsAlongLines Distance 50m from selected GUA in " + os.path.basename(inGQA) + " to " + os.path.basename(fc_GUA_pt_50m))
                arcpy.GeneratePointsAlongLines_management(uatlLyr, fc_GUA_pt_50m, 'DISTANCE', Distance='50 meters', Include_End_Points='END_POINTS')
                print ("Points generated - hurray!!")

                cnt = arcpy.GetCount_management(fc_GUA_pt_50m)
                nbrec = cnt.getOutput(0)
                print ("nb generated points : " + nbrec)

                if arcpy.Exists('{}_GUA_PT_50m_lyr'.format(uc_code)):
                    arcpy.Delete_management('{}_GUA_PT_50m_lyr'.format(uc_code))
                arcpy.MakeFeatureLayer_management(fc_GUA_pt_50m, '{}_GUA_PT_50m_lyr'.format(uc_code)) 

                fc_GUA_pt_50m_nw_25m = outGDB +"\\{}_GUA_pt_50m_nw_25m".format(uc_code)    
                if arcpy.Exists(fc_GUA_pt_50m_nw_25m):
                    arcpy.Delete_management(fc_GUA_pt_50m_nw_25m)
                nw_Path = pedestrian_path + r"\NW_" + ctr_cd + ".gdb" + "\\" + ctr_cd + "\\nw"
                print ("SelectLayerByLocation points in " + os.path.basename(fc_GUA_pt_50m) + " WITHIN_A_DISTANCE of 25 meters from " + os.path.basename(nw_Path)+ " to " + os.path.basename(fc_GUA_pt_50m_nw_25m))
                Selection = arcpy.SelectLayerByLocation_management('{}_GUA_PT_50m_lyr'.format(uc_code), 'WITHIN_A_DISTANCE', nw_Path, "25 meters", "NEW_SELECTION")
                arcpy.CopyFeatures_management(Selection, fc_GUA_pt_50m_nw_25m) 
                UATL_Ids_GUAs_nw_25m = unique_values(fc_GUA_pt_50m_nw_25m, "ORIG_FID")
                print("Nb of GQA near network " +len(UATL_Ids_GUAs_nw_25m))
                ids_ls_GQA = unique_values(uatlLyr, "FID")
                print("Total nb of GQA " +len(ids_ls_GQA))

                # GQA without access to network
                ids_noaccess = [item for item in ids_ls_GQA if item not in UATL_Ids_GUAs_nw_25m]
                

                

                desc = arcpy.Describe(uatlLyr)
                SR = desc.spatialReference
                flds = arcpy.ListFields(uatlLyr)
                ###UATL_FieldName_List = [fld.name for fld in flds if fld.name != desc.OIDFieldName and fld.type != 'Geometry' and fld.name != desc.areaFieldName and fld.name != desc.lengthFieldName]
                UATL_FieldName_List = [fld.name for fld in flds if fld.type != 'Geometry']
                # rename FID to OBJECTID
                UATL_FieldName_List = ['OBJECTID' if field == 'FID' else field for field in UATL_FieldName_List]


                ##fc_GUA_centroids_no_pt = outPath + "\\GUA_centroids_no_pt.shp"
                fc_GUA_centroids_no_pt = os.path.join(outGDB, '{}GUA_centroids_no_pt'.format(uc_code))    
            ##    fc_GUA_centroids_no_pt = r"in_memory\GUA_centroids_no_pt"
                if arcpy.Exists(fc_GUA_centroids_no_pt):
                    arcpy.Delete_management(fc_GUA_centroids_no_pt)
                print ("CreateFeatureclass " + os.path.basename(fc_GUA_centroids_no_pt))
                ##arcpy.CreateFeatureclass_management("in_memory", "GUA_centroids_no_pt", "POINT", "", "DISABLED", "DISABLED", SR, "", "0", "0", "0")
                arcpy.CreateFeatureclass_management(outGDB, "{}GUA_centroids_no_pt".format(uc_code), "POINT", "", "DISABLED", "DISABLED", SR, "", "0", "0", "0")
                
                idxfld = 0
                for fldnam in UATL_FieldName_List:
                    for fldidx in range(0,len(flds)):
                        if fldnam == flds[fldidx].name:
                            typeF = flds[fldidx].type
                            if typeF == 'String':
                                length_fld = flds[fldidx].length
                            break
                    if typeF in ['Integer']:
                        arcpy.AddField_management(fc_GUA_centroids_no_pt,fldnam,field_type='LONG')
                    elif typeF == 'SmallInteger':
                        arcpy.AddField_management(fc_GUA_centroids_no_pt,fldnam,field_type='SHORT')
                    elif typeF == 'String':
                        arcpy.AddField_management(fc_GUA_centroids_no_pt,fldnam,field_type='TEXT',field_length=length_fld)
                    elif typeF == 'Double':
                        arcpy.AddField_management(fc_GUA_centroids_no_pt,fldnam,field_type='DOUBLE')
                    elif typeF == 'Single':
                        arcpy.AddField_management(fc_GUA_centroids_no_pt,fldnam,field_type='FLOAT')
                    elif typeF == 'Date':
                        arcpy.AddField_management(fc_GUA_centroids_no_pt,fldnam,field_type='DATE')
                    idxfld += 1

                fields = []
                fields.append("SHAPE@")
                for fldnam in UATL_FieldName_List:
                    fields.append(fldnam)
                print ("Insert centroids where no point in " + os.path.basename('{}fc_GUA_pt_50m_nw_25m').format(uc_code))
                cursor = arcpy.da.InsertCursor(fc_GUA_centroids_no_pt, fields)  
                for row in arcpy.da.SearchCursor(uatlLyr, fields):
                    if row[1] not in UATL_Ids_GUAs_nw_25m:
                        list_row = list(row)
                        list_row[0] = row[0].centroid
                        cursor.insertRow(convert(list_row))  
                del row,cursor

                print("centroids inserted")

                ##fc_GUA_mem_pt_all = "in_memory\GUA_pt_ALL"
                fc_GUA_mem_pt_all = outGDB +"\\{}_GUA_pt_ALL".format(uc_code)
                ###fc_GUA_mem_pt_all = outPath + "\\\GUA_pt_ALL.shp"

                if arcpy.Exists(fc_GUA_mem_pt_all):
                    arcpy.Delete_management(fc_GUA_mem_pt_all)
                print ("CopyFeatures from " + os.path.basename(fc_GUA_pt_50m_nw_25m) + " in "  + fc_GUA_mem_pt_all)
                arcpy.CopyFeatures_management(fc_GUA_pt_50m_nw_25m, fc_GUA_mem_pt_all) 
                print ("append " + os.path.basename(fc_GUA_centroids_no_pt) + " in " + os.path.basename(fc_GUA_mem_pt_all))
                arcpy.Append_management(fc_GUA_centroids_no_pt, fc_GUA_mem_pt_all, "NO_TEST")

                cnt = arcpy.GetCount_management(fc_GUA_mem_pt_all)
                nbrec = cnt.getOutput(0)
                print ("nb points in " + os.path.basename(fc_GUA_mem_pt_all) + " : " + nbrec)

                
                #Loop through to prevent memory errors
                # Batch processing to prevent memory issues
                batch_size = 1000 
                print('batch size 1000')

                # Function to create service area layer
                for i in range(0, int(nbrec), batch_size):
                    j = min(i + batch_size, int(nbrec))
                    print ("this is i {} and this is j {}".format(i,j))
                    expr = "\"OBJECTID\" >= {} AND \"OBJECTID\" < {}".format(i,j)

                    if arcpy.Exists("GUA_points_layer"):
                        arcpy.Delete_management("GUA_points_layer")
                    GUA_pt_lyr = arcpy.MakeFeatureLayer_management(fc_GUA_mem_pt_all, "{}GUA_points_layer".format(uc_code), expr)
                    print('GUA_pt_lyr')

                    # Create service area layer
                    salyr = create_service_area_layer(GUA_pt_lyr, "{}_SA_400m_batch_{}_{}".format(uc_code,i,j), pedestrianNWpath, uc_code, nbMeters)

                    if i == 0:
                        fc_SA = os.path.join(gdb_path, gdb_name, "{}_sa".format(uc_code))
                        if arcpy.Exists(fc_SA):
                            arcpy.Delete_management(fc_SA)
                        #saFC = arcpy.CopyFeatures_management(salyr + "\\Polygons", fc_SA)
                        saFC = arcpy.CopyFeatures_management("{}_SA_400m\Polygons".format(uc_code), fc_SA)
                        
                    else:
                        tmpFC = arcpy.CopyFeatures_management("{}_SA_400m\Polygons".format(uc_code), os.path.join(gdb_path, gdb_name, "{}_sa_batch_{}_{}").format(ctr_cd,i,j))
                        arcpy.Append_management(tmpFC, saFC, "NO_TEST")
                        arcpy.Delete_management(tmpFC)

                    arcpy.Delete_management(salyr) 

                fc_GUA_pt_all = os.path.join(gdb_path, gdb_name, "GUA_{}_pt_ALL".format(uc_code))
                if arcpy.Exists(fc_GUA_pt_all):
                    arcpy.Delete_management(fc_GUA_pt_all)
                print ("CopyFeatures from " + os.path.basename(fc_GUA_mem_pt_all) + " in "  + fc_GUA_pt_all)
                arcpy.CopyFeatures_management(fc_GUA_mem_pt_all, fc_GUA_pt_all)
                

                print ("end: " + time.strftime("%H:%M:%S", time.localtime()))
                
            except CustomError as ce:
                arcpy.AddError(ce.value)
                print (ce.value)
            except arcpy.ExecuteError:
                msgs = arcpy.GetMessages(2)
                arcpy.AddError(msgs)
                print (msgs)
            except:
                tb = sys.exc_info()[2]
                tbinfo = traceback.format_tb(tb)[0]
                pymsg = "PYTHON ERRORS:\nTraceback info:\n" + tbinfo + "\nError Info:\n" + str(sys.exc_info()[1])
                msgs = "ArcPy ERRORS:\n" + arcpy.GetMessages(2) + "\n"
                arcpy.AddError(pymsg)
                print (msgs)
                arcpy.AddError(msgs)
                print (pymsg)
            finally:
                arcpy.CheckInExtension("Network")
