# %%
#----------------------------------------------------------------------------------
#Author: Veerle Martens
#Date: may 2012
#Adapted by: Raquel Ubach (UAB) - Dec 2023/Jul 2024
#
#Purpose: Create service areas around each building block and find out the area of
#         green urban area that can be reached.
#---------------------------------------------------------------------------------

#create error handler
class CustomError(Exception):
    def __init__(self,value):
        self.value = value
    def __str__(self):
        return repr(self.value)

import sys, arcpy, time, traceback, os.path
import pandas as pd

def unique_values(table , field):
    with arcpy.da.SearchCursor(table, [field]) as cursor:
        return sorted({row[0] for row in cursor})

def convert(list):
    return tuple(list)

def create_service_area_layer(group_id, network_dataset, locations, fc_SA):
    print ("Creating network layer for batch {}".format(group_id))
    salyr = arcpy.na.MakeServiceAreaAnalysisLayer(
        network_data_source= network_dataset,
        layer_name="{}_SA_400m".format(group_id),
        travel_mode="Walk",
        travel_direction="FROM_FACILITIES",
        cutoffs=[400],
        time_of_day=None,
        time_zone="LOCAL_TIME_AT_LOCATIONS",
        output_type="POLYGONS",
        polygon_detail="HIGH",
        geometry_at_overlaps="OVERLAP",
        geometry_at_cutoffs="DISKS",
        polygon_trim_distance="10 Meters",
        exclude_sources_from_polygon_generation=None,
        accumulate_attributes=None,
        ignore_invalid_locations="SKIP"
    )
    arcpy.na.AddLocations(
        in_network_analysis_layer=salyr,
        sub_layer="Facilities",        
        in_table=locations,
        field_mappings="Name # #;CurbApproach # 0;Attr_Minutes # 0;Attr_Meters # 0;Attr_pedestrian_minutes # 0;Breaks_Minutes # #;Breaks_Meters # #;Breaks_pedestrian_minutes # #",
        search_tolerance="5000 Meters",
        sort_field=None,
        search_criteria="nw SHAPE;Network_ND_Junctions NONE",
        match_type="MATCH_TO_CLOSEST",
        append="APPEND",
        snap_to_position_along_network="NO_SNAP",
        snap_offset="5 Meters",
        exclude_restricted_elements="EXCLUDE",
        search_query=None,
        allow_auto_relocate="ALLOW"
    )
    print("Solving network analysis")
    arcpy.na.Solve(
        in_network_analysis_layer=salyr,
        ignore_invalids="SKIP",
        terminate_on_solve_error="CONTINUE",
        simplification_tolerance=None,
        overrides=""
    )
    arcpy.CopyFeatures_management("{}_SA_400m\Polygons".format(uc_code), fc_SA)
    arcpy.Delete_management(salyr) 

# Path to data folders
indata_f = r'P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas'
networks_f = os.path.join(indata_f, 'Network data Regio')
step1_f = os.path.join(indata_f, 'OutputData', 'step1_GQA')
step2_f = os.path.join(indata_f, 'OutputData', 'step2_GQA_Final')
step3_f = os.path.join(indata_f, 'OutputData', 'step3_SA')
if not os.path.exists(step3_f):
    os.makedirs(step3_f)
uc_file_path = os.path.join(indata_f, 'UrbanCentres', 'HDC2021_RG_InputUpdateB2B3B4Copy.shp')

# input parameters
pedestrian_path = networks_f
outPath = step3_f 
CODE_Fld = "code_2018"
UATL_ID_Fld = "FID"

    
# TRANSLATOR TABLE
# Crosswalk table containing the different codes from input sources
codes_path = r'P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\Codes.csv'
codes = pd.read_csv(codes_path)

#Environment settings
arcpy.env.overwriteOutput = True
arcpy.env.addOutputsToMap = False

try:
    arcpy.CheckOutExtension("Network")
    print("Network Analyst extension has been checked out.")
except arcpy.ExecuteError:
    print("Failed to check out the Network Analyst extension.")
    
# Run process for ctry
ctry = 'CZ'
sql_query = "Batch >0"

# Define the path and name for the geodatabase
gdb_path = os.path.join(indata_f, 'Processing')

gdb_name = f"SA_output_2510_{ctry}.gdb"
outGDB = os.path.join(gdb_path, gdb_name)
# Check if the geodatabase exists
if not arcpy.Exists(outGDB):
    # Create the geodatabase if it does not exist
    arcpy.CreateFileGDB_management(gdb_path, gdb_name)

with arcpy.da.SearchCursor(uc_file_path, ["SHAPE@", "HDENS_CLST", "CNTR_CODE"], where_clause=sql_query) as uc_cursor:
    for uc_row in uc_cursor:
        geom = uc_row[0]  # Geometry object
        ctr_cd = uc_row[2]
        uc_code = uc_row[1]
        print(uc_code)
        print(codes.query(f'HDENS_CLST == "{uc_code}"').HDENS_NAME.values.astype(str)[0].strip())
        inGQA = os.path.join(step2_f, '{}_finalGQA.shp'.format(uc_code))
        fc_SA = os.path.join(outPath, "{}_SA.shp".format(uc_code))
        ####fc_SA = os.path.join(gdb_path, gdb_name, "{}_SA".format(uc_code))
        if ctr_cd.startswith("CH-"):
            ctr_cd = "CH"
        
        outDiss = os.path.join(outPath, 'Dissolved', "{}_SAd.shp".format(uc_code))
        fc_GUA_pt_50m_nw_25m = outGDB +"\\{}_GUA_pt_50m_nw_25m".format(uc_code)
        ##if os.path.exists(inGQA) and not arcpy.Exists(fc_SA) and ctr_cd!="NO" and ctr_cd!="CH":
        if os.path.exists(inGQA) and not arcpy.Exists(outDiss) and ctr_cd==ctry:

            #join GQA FID
            arcpy.management.JoinField(
                in_data=fc_SA,
                in_field="FacilityID",
                join_table=fc_GUA_pt_50m_nw_25m,
                join_field="OBJECTID",
                fields="FID",
                fm_option="NOT_USE_FM",
                field_mapping=None,
                index_join_fields="NO_INDEXES"
            )
            # Dissolve by QGA id
            outDiss = os.path.join(outPath, 'Dissolved', "{}_SAd.shp".format(uc_code))
            if not os.path.exists(outDiss):
                arcpy.analysis.PairwiseDissolve(
                    in_features=fc_SA,
                    out_feature_class=outDiss,
                    dissolve_field="FID_1",
                    statistics_fields=None,
                    multi_part="MULTI_PART",
                    concatenation_separator=""
                )


                print ("end: " + time.strftime("%H:%M:%S", time.localtime()))
# Out:
# Network Analyst extension has been checked out.
# GEOSTAT21_018
# Stockholm
# GEOSTAT21_021
# Tartu
# GEOSTAT21_022
# Örebro
# GEOSTAT21_023
# Stavanger
# GEOSTAT21_024
# Norrköping
# GEOSTAT21_025
# Linköping
# GEOSTAT21_914
# Jönköping / Huskvarna
# GEOSTAT21_029
# Göteborg
# GEOSTAT21_026
# Borås
# GEOSTAT21_028
# Rīga
# GEOSTAT21_031
# Aalborg
# GEOSTAT21_047
# Århus
# GEOSTAT21_048
# Helsingborg
# GEOSTAT21_903
# København
# GEOSTAT21_049
# Lund
# GEOSTAT21_051
# Kaunas
# GEOSTAT21_054
# Malmö
# GEOSTAT21_060
# Odense
# GEOSTAT21_065
# Gdynia
# GEOSTAT21_068
# Gdańsk
# GEOSTAT21_904
# Dublin
# GEOSTAT21_070
# Elbląg
# GEOSTAT21_086
# Kiel
# GEOSTAT21_090
# Olsztyn
# GEOSTAT21_093
# Lütten Klein
# GEOSTAT21_094
# Rostock
# GEOSTAT21_095
# Limerick
# GEOSTAT21_108
# Lübeck
# GEOSTAT21_109
# Białystok
# GEOSTAT21_119
# Hamburg
# GEOSTAT21_118
# Bremerhaven
# GEOSTAT21_120
# Szczecin
# GEOSTAT21_919
# Neu Wulmstorf / Neugraben-Fischbek / Hausbruch
# GEOSTAT21_121
# Harburg
# GEOSTAT21_122
# Kasztelanka
# GEOSTAT21_128
# Bydgoszcz
# GEOSTAT21_132
# Cork
# GEOSTAT21_131
# Toruń
# GEOSTAT21_137
# Groningen
# GEOSTAT21_141
# Oldenburg (Oldenburg)
# GEOSTAT21_140
# Gröpelingen / Vegesack
# GEOSTAT21_145
# Bremen
# GEOSTAT21_150
# Włocławek
# GEOSTAT21_154
# Płock
# GEOSTAT21_161
# Gorzów Wielkopolski
# GEOSTAT21_171
# Warszawa
# GEOSTAT21_002
# Oulu / Uleåborg
# GEOSTAT21_003
# Umeå
# GEOSTAT21_004
# Trondheim
# GEOSTAT21_005
# Jyväskylä
# GEOSTAT21_006
# Tampere / Tammerfors
# GEOSTAT21_911
# Lahti
# GEOSTAT21_901
# Helsinki
# GEOSTAT21_007
# Turku / Åbo
# GEOSTAT21_011
# Bergen
# GEOSTAT21_012
# Tallinn
# GEOSTAT21_013
# Uppsala
# GEOSTAT21_902
# Oslo
# GEOSTAT21_016
# Västerås
# GEOSTAT21_912
# Drammen
# GEOSTAT21_200
# Hannover
# GEOSTAT21_205
# Leiden
# GEOSTAT21_196
# Hilversum
# GEOSTAT21_199
# Hengelo
# GEOSTAT21_201
# Osnabrück
# GEOSTAT21_203
# Apeldoorn
# GEOSTAT21_211
# Braunschweig
# GEOSTAT21_208
# Enschede
# GEOSTAT21_206
# Alphen aan den Rijn
# GEOSTAT21_221
# Den Haag
# GEOSTAT21_905
# Utrecht
# GEOSTAT21_216
# Zoetermeer
# GEOSTAT21_229
# Łódź
# GEOSTAT21_225
# Magdeburg
# GEOSTAT21_220
# Gouda
# GEOSTAT21_223
# Hildesheim
# GEOSTAT21_224
# Nieuwegein / IJsselstein
# GEOSTAT21_240
# Rotterdam
# GEOSTAT21_233
# Zielona Góra
# GEOSTAT21_239
# Arnhem
# GEOSTAT21_237
# Bielefeld
# GEOSTAT21_243
# Münster
# GEOSTAT21_242
# Spijkenisse
# GEOSTAT21_248
# Dordrecht
# GEOSTAT21_249
# Radom
# GEOSTAT21_256
# Nijmegen
# GEOSTAT21_255
# Lublin
# GEOSTAT21_327
# Düsseldorf
# GEOSTAT21_925
# Wuppertal
# GEOSTAT21_316
# Dunkerque
# GEOSTAT21_331
# Mönchengladbach
# GEOSTAT21_332
# Gent
# GEOSTAT21_334
# Solingen
# GEOSTAT21_328
# Remscheid
# GEOSTAT21_335
# Częstochowa
# GEOSTAT21_339
# Dresden
# GEOSTAT21_346
# Köln
# GEOSTAT21_349
# Bruxelles / Brussel
# GEOSTAT21_344
# Leuven
# GEOSTAT21_347
# Heerlen
# GEOSTAT21_348
# Opole
# GEOSTAT21_354
# Porz
# GEOSTAT21_359
# Chemnitz
# GEOSTAT21_358
# Liberec
# GEOSTAT21_360
# Aachen
# GEOSTAT21_363
# Bonn
# GEOSTAT21_364
# Liège
# GEOSTAT21_362
# Ústí nad Labem
# GEOSTAT21_376
# Górnośląski Związek Metropolitalny
# GEOSTAT21_366
# Rzeszów
# GEOSTAT21_367
# Lens
# GEOSTAT21_379
# Charleroi
# GEOSTAT21_265
# s-Hertogenbosch
# GEOSTAT21_274
# Breda
# GEOSTAT21_299
# Ruhrgebiet
# GEOSTAT21_289
# Göttingen
# GEOSTAT21_292
# Eindhoven
# GEOSTAT21_288
# Helmond
# GEOSTAT21_295
# Halle an der Saale
# GEOSTAT21_297
# Moers / Rheinhausen
# GEOSTAT21_302
# Duisburg
# GEOSTAT21_305
# Hagen
# GEOSTAT21_304
# Brugge
# GEOSTAT21_312
# Leipzig
# GEOSTAT21_307
# Krefeld
# GEOSTAT21_317
# Antwerpen
# GEOSTAT21_308
# Kielce
# GEOSTAT21_318
# Wrocław
# GEOSTAT21_320
# Kassel
# GEOSTAT21_922
# Scharwoude / Heerhugowaard
# GEOSTAT21_168
# Alkmaar
# GEOSTAT21_178
# Poznań
# GEOSTAT21_186
# Berlin
# GEOSTAT21_173
# Beverwijk/Heemskerk
# GEOSTAT21_190
# Amsterdam
# GEOSTAT21_177
# Zwolle
# GEOSTAT21_181
# Haarlem
# GEOSTAT21_184
# Almere
# GEOSTAT21_188
# Potsdam
# GEOSTAT21_405
# Wiesbaden
# GEOSTAT21_403
# Havířov
# end: 18:30:25
# GEOSTAT21_404
# Hrabuvka
# end: 18:30:26
# GEOSTAT21_408
# Mainz
# GEOSTAT21_413
# Darmstadt
# GEOSTAT21_418
# Rouen
# GEOSTAT21_414
# Olomouc
# GEOSTAT21_417
# Würzburg
# GEOSTAT21_416
# Plzeň
# GEOSTAT21_419
# Luxembourg
# GEOSTAT21_420
# Caen
# GEOSTAT21_421
# Erlangen
# GEOSTAT21_457
# Vaihingen / Möhringen
# GEOSTAT21_473
# Reutlingen
# GEOSTAT21_481
# Wien
# GEOSTAT21_476
# Ulm/Neu-Ulm
# GEOSTAT21_479
# Linz
# GEOSTAT21_907
# Augsburg
# GEOSTAT21_487
# München
# GEOSTAT21_488
# Freiburg im Breisgau
# GEOSTAT21_489
# Angers
# GEOSTAT21_496
# Nantes
# GEOSTAT21_495
# Salzburg
# GEOSTAT21_499
# Tours
# GEOSTAT21_510
# Basel
# GEOSTAT21_941
# Gebenstorf / Turgi / Obersiggenthal / Baden / Wettingen
# GEOSTAT21_425
# Mannheim/Ludwigshafen
# GEOSTAT21_429
# Fürth
# GEOSTAT21_427
# Reims
# GEOSTAT21_428
# Heidelberg
# GEOSTAT21_430
# Brno
# GEOSTAT21_431
# Brest
# GEOSTAT21_906
# Paris
# GEOSTAT21_432
# Mantes en Yvelines
# GEOSTAT21_435
# Saarbrücken
# GEOSTAT21_437
# Poissy
# GEOSTAT21_441
# Heilbronn
# GEOSTAT21_440
# Les Clayes-sous-Bois
# GEOSTAT21_443
# Maurepas / Montigny-le-Bretonneux
# GEOSTAT21_445
# Regensburg
# GEOSTAT21_447
# Karlsruhe
# GEOSTAT21_448
# Pforzheim
# GEOSTAT21_454
# Stuttgart
# GEOSTAT21_455
# Ingolstadt
# GEOSTAT21_459
# Rennes
# GEOSTAT21_377
# Tarnów
# GEOSTAT21_385
# Kraków
# GEOSTAT21_382
# Arras
# GEOSTAT21_384
# Tychy
# GEOSTAT21_387
# Koblenz
# GEOSTAT21_402
# Praha
# end: 18:30:28
# GEOSTAT21_401
# Frankfurt am Main
# GEOSTAT21_394
# Bielsko-Biała
# GEOSTAT21_397
# Ostrava
# GEOSTAT21_400
# Hanau
# GEOSTAT21_398
# Poruba
# end: 18:30:30
# GEOSTAT21_542
# Lausanne
# GEOSTAT21_549
# Genève
# GEOSTAT21_550
# Limoges
# GEOSTAT21_558
# Clermont-Ferrand
# GEOSTAT21_557
# Lugano
# GEOSTAT21_561
# Zagreb
# GEOSTAT21_569
# Lyon
# GEOSTAT21_945
# Saint-Priest / Mions
# GEOSTAT21_624
# Oviedo
# GEOSTAT21_650
# Bilbao
# GEOSTAT21_652
# San Sebastián/Donostia
# GEOSTAT21_657
# Vigo
# GEOSTAT21_665
# León
# GEOSTAT21_672
# Nice
# GEOSTAT21_669
# Split
# GEOSTAT21_674
# Vitoria/Gasteiz
# GEOSTAT21_676
# Aix-en-Provence
# GEOSTAT21_682
# Martigues / Port-de-Bouc
# GEOSTAT21_687
# Pamplona/Iruña
# GEOSTAT21_689
# Marseille
# GEOSTAT21_694
# Logroño
# GEOSTAT21_580
# Saint-Etienne
# GEOSTAT21_588
# Rijeka
# GEOSTAT21_595
# Bordeaux
# GEOSTAT21_597
# Grenoble
# GEOSTAT21_620
# Gijón
# GEOSTAT21_521
# Zürich
# GEOSTAT21_514
# St. Gallen
# GEOSTAT21_519
# Besançon
# GEOSTAT21_520
# Innsbruck
# GEOSTAT21_522
# Graz
# GEOSTAT21_943
# Cham / Zug
# GEOSTAT21_523
# Biel/Bienne
# GEOSTAT21_528
# Bern
# GEOSTAT21_531
# Fribourg
# GEOSTAT21_800
# Castellón de la Plana/Castelló de la Plana
# GEOSTAT21_809
# Valencia
# GEOSTAT21_843
# Lefkosia
# GEOSTAT21_773
# Madrid
# GEOSTAT21_768
# Torrejón de Ardoz
# GEOSTAT21_774
# Fuenlabrada
# GEOSTAT21_706
# Porto
# GEOSTAT21_712
# Valladolid
# GEOSTAT21_856
# Lemesos
# GEOSTAT21_867
# Valletta

# %%
#----------------------------------------------------------------------------------
#Author: Veerle Martens
#Date: may 2012
#Adapted by: Raquel Ubach (UAB) - Dec 2023/Jul 2024
#
#Purpose: Create service areas around each building block and find out the area of
#         green urban area that can be reached.
#---------------------------------------------------------------------------------

#create error handler
class CustomError(Exception):
    def __init__(self,value):
        self.value = value
    def __str__(self):
        return repr(self.value)

import sys, arcpy, time, traceback, os.path
import pandas as pd

def unique_values(table , field):
    with arcpy.da.SearchCursor(table, [field]) as cursor:
        return sorted({row[0] for row in cursor})

def convert(list):
    return tuple(list)

def create_service_area_layer(group_id, network_dataset, locations, fc_SA):
    print ("Creating network layer for batch {}".format(group_id))
    salyr = arcpy.na.MakeServiceAreaAnalysisLayer(
        network_data_source= network_dataset,
        layer_name="{}_SA_400m".format(group_id),
        travel_mode="Walk",
        travel_direction="FROM_FACILITIES",
        cutoffs=[400],
        time_of_day=None,
        time_zone="LOCAL_TIME_AT_LOCATIONS",
        output_type="POLYGONS",
        polygon_detail="HIGH",
        geometry_at_overlaps="OVERLAP",
        geometry_at_cutoffs="DISKS",
        polygon_trim_distance="10 Meters",
        exclude_sources_from_polygon_generation=None,
        accumulate_attributes=None,
        ignore_invalid_locations="SKIP"
    )
    arcpy.na.AddLocations(
        in_network_analysis_layer=salyr,
        sub_layer="Facilities",        
        in_table=locations,
        field_mappings="Name # #;CurbApproach # 0;Attr_Minutes # 0;Attr_Meters # 0;Attr_pedestrian_minutes # 0;Breaks_Minutes # #;Breaks_Meters # #;Breaks_pedestrian_minutes # #",
        search_tolerance="5000 Meters",
        sort_field=None,
        search_criteria="nw SHAPE;Network_ND_Junctions NONE",
        match_type="MATCH_TO_CLOSEST",
        append="APPEND",
        snap_to_position_along_network="NO_SNAP",
        snap_offset="5 Meters",
        exclude_restricted_elements="EXCLUDE",
        search_query=None,
        allow_auto_relocate="ALLOW"
    )
    print("Solving network analysis")
    arcpy.na.Solve(
        in_network_analysis_layer=salyr,
        ignore_invalids="SKIP",
        terminate_on_solve_error="CONTINUE",
        simplification_tolerance=None,
        overrides=""
    )
    arcpy.CopyFeatures_management("{}_SA_400m\Polygons".format(uc_code), fc_SA)
    arcpy.Delete_management(salyr) 

# Path to data folders
indata_f = r'P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas'
networks_f = os.path.join(indata_f, 'Network data Regio')
step1_f = os.path.join(indata_f, 'OutputData', 'step1_GQA')
step2_f = os.path.join(indata_f, 'OutputData', 'step2_GQA_Final')
step3_f = os.path.join(indata_f, 'OutputData', 'step3_SA')
if not os.path.exists(step3_f):
    os.makedirs(step3_f)
uc_file_path = os.path.join(indata_f, 'UrbanCentres', 'HDC2021_RG_InputUpdateB2B3B4Copy.shp')

# input parameters
pedestrian_path = networks_f
outPath = step3_f 
CODE_Fld = "code_2018"
UATL_ID_Fld = "FID"

    
# TRANSLATOR TABLE
# Crosswalk table containing the different codes from input sources
codes_path = r'P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\Codes.csv'
codes = pd.read_csv(codes_path)

#Environment settings
arcpy.env.overwriteOutput = True
arcpy.env.addOutputsToMap = False

try:
    arcpy.CheckOutExtension("Network")
    print("Network Analyst extension has been checked out.")
except arcpy.ExecuteError:
    print("Failed to check out the Network Analyst extension.")
    
# Run process for ctry
ctry = 'DE'
sql_query = "Batch >0"


# Define the path and name for the geodatabase
gdb_path = os.path.join(indata_f, 'Processing')

gdb_name = f"SA_output_2810_diss.gdb"
outGDB = os.path.join(gdb_path, gdb_name)
# Check if the geodatabase exists
if not arcpy.Exists(outGDB):
    # Create the geodatabase if it does not exist
    arcpy.CreateFileGDB_management(gdb_path, gdb_name)

with arcpy.da.SearchCursor(uc_file_path, ["SHAPE@", "HDENS_CLST", "CNTR_CODE"], where_clause=sql_query) as uc_cursor:
    for uc_row in uc_cursor:
        geom = uc_row[0]  # Geometry object
        ctr_cd = uc_row[2]
        uc_code = uc_row[1]
        print(uc_code)
        print(codes.query(f'HDENS_CLST == "{uc_code}"').HDENS_NAME.values.astype(str)[0].strip())
        inGQA = os.path.join(step2_f, '{}_finalGQA.shp'.format(uc_code))
        fc_SA = os.path.join(outPath, "{}_SA.shp".format(uc_code))
        ####fc_SA = os.path.join(gdb_path, gdb_name, "{}_SA".format(uc_code))
        if ctr_cd.startswith("CH-"):
            ctr_cd = "CH"
        
        outDiss = os.path.join(outPath, 'Dissolved', "{}_SAd.shp".format(uc_code))
        ##if os.path.exists(inGQA) and not arcpy.Exists(fc_SA) and ctr_cd!="NO" and ctr_cd!="CH":
        if os.path.exists(inGQA) and not arcpy.Exists(outDiss) and ctr_cd==ctry:
            print ("start: " + time.strftime("%H:%M:%S", time.localtime()))
            pedestrianNWpath = pedestrian_path + r"\NW_" + ctr_cd + ".gdb\\" + ctr_cd + r"\Network_ND"
            if not arcpy.Exists(pedestrianNWpath):
                raise CustomError("Featureclass " + pedestrianNWpath + " NOT FOUND")

            arcpy.env.extent = geom.extent # Extent object of the geometry
            print("Extent set to match uc: {}".format(arcpy.env.extent))
            
            try:          

                if arcpy.Exists("{}_UATLlayer".format(uc_code)):
                    arcpy.Delete_management("{}_UATLlayer".format(uc_code))
                uatlLyr = arcpy.MakeFeatureLayer_management(inGQA, "{}_UATLlayer".format(uc_code))

                ## Count number of GUA Blocks
                cnt = arcpy.GetCount_management(uatlLyr)
                print ("nb record(s) in " + os.path.basename(inGQA) + " subset selection [" + CODE_Fld + "] IN (14100,30000,31000) : " +  cnt.getOutput(0))

                ## Create and Select points from GUA borders used to create SA
                print ("Create points from GUA borders used to create SA")

                #fc_GUA_pt_50m = outPath + "\\GUA_pt_50m.shp" ## modified to output folder
                fc_GUA_pt_50m = outGDB +"\\{}_GUA_pt_50m".format(uc_code)

                if arcpy.Exists(fc_GUA_pt_50m):
                    arcpy.Delete_management(fc_GUA_pt_50m)
                print ("GeneratePointsAlongLines Distance 50m from selected GUA in " + os.path.basename(inGQA) + " to " + os.path.basename(fc_GUA_pt_50m))
                arcpy.GeneratePointsAlongLines_management(uatlLyr, fc_GUA_pt_50m, 'DISTANCE', Distance='50 meters', Include_End_Points='END_POINTS')

                cnt = arcpy.GetCount_management(fc_GUA_pt_50m)
                nbrec = cnt.getOutput(0)
                print ("nb generated points : " + nbrec)

                if arcpy.Exists('{}_GUA_PT_50m_lyr'.format(uc_code)):
                    arcpy.Delete_management('{}_GUA_PT_50m_lyr'.format(uc_code))
                arcpy.MakeFeatureLayer_management(fc_GUA_pt_50m, '{}_GUA_PT_50m_lyr'.format(uc_code)) 

                fc_GUA_pt_50m_nw_25m = outGDB +"\\{}_GUA_pt_50m_nw_25m".format(uc_code)    
                if arcpy.Exists(fc_GUA_pt_50m_nw_25m):
                    arcpy.Delete_management(fc_GUA_pt_50m_nw_25m)
                nw_Path = pedestrian_path + r"\NW_" + ctr_cd + ".gdb" + "\\" + ctr_cd + "\\nw"
                print ("SelectLayerByLocation points in " + os.path.basename(fc_GUA_pt_50m) + " WITHIN_A_DISTANCE of 25 meters from " + os.path.basename(nw_Path)+ " to " + os.path.basename(fc_GUA_pt_50m_nw_25m))
                Selection = arcpy.SelectLayerByLocation_management('{}_GUA_PT_50m_lyr'.format(uc_code), 'WITHIN_A_DISTANCE', nw_Path, "25 meters", "NEW_SELECTION")
                # save selection in a diferent feature class
                arcpy.CopyFeatures_management(Selection, fc_GUA_pt_50m_nw_25m) 
                # Adding FID field to the point feature class if it doesn't already exist
                if 'FID' not in [f.name for f in arcpy.ListFields(fc_GUA_pt_50m_nw_25m)]:
                    arcpy.AddField_management(fc_GUA_pt_50m_nw_25m, 'FID', 'LONG')

                UATL_Ids_GUAs_nw_25m = unique_values(fc_GUA_pt_50m_nw_25m, "ORIG_FID")
                print("Nb of GQA near network " + str(len(UATL_Ids_GUAs_nw_25m)))
                ids_ls_GQA = unique_values(uatlLyr, "FID")
                print("Total nb of GQA " +str(len(ids_ls_GQA)))

                # GQA without access to network (less than 25m)
                ids_noaccess = [item for item in ids_ls_GQA if item not in UATL_Ids_GUAs_nw_25m]
                
                # List to hold centroid points and their corresponding FIDs
                centroid_points = []
                fields_ls = ["FID", "SHAPE@", "Area"] # List of fields to include
                # Create a search cursor to iterate through the polygon shapefile GQA
                with arcpy.da.SearchCursor(uatlLyr, fields_ls) as cursor:
                    for row in cursor:
                        if row[0] in ids_noaccess:
                            # Get the FID and the geometry of the polygon
                            fid = row[0]
                            polygon = row[1]
                            area = row[2]
                            # Compute the centroid of the polygon
                            centroid = polygon.centroid
                            # Append the FID and centroid to the list
                            centroid_points.append((fid, centroid, area))

                # Start an edit session for the geodatabase
                with arcpy.da.Editor(outGDB) as edit:
                    # Create an insert cursor for the point feature class
                    with arcpy.da.InsertCursor(fc_GUA_pt_50m_nw_25m, fields_ls) as cursor:
                        for fid, point, area in centroid_points:
                            # Insert the centroid point and the FID
                            cursor.insertRow([fid, point, area])
                print("Centroids and FIDs computed and appended successfully.")

                # Add FID value to all records
                field_to_check = 'FID'
                alternative_field = 'ORIG_FID'
                #expression = f"!{field_to_check}! if !{field_to_check}! is not None else !{alternative_field}!"
                expression ="!FID! if !FID! is not None else !ORIG_FID!"
                # Execute CalculateField
                arcpy.CalculateField_management(fc_GUA_pt_50m_nw_25m, field_to_check, expression, "PYTHON3")

                cnt = arcpy.GetCount_management(fc_GUA_pt_50m_nw_25m)
                nbrec = cnt.getOutput(0)
                print ("nb points in " + os.path.basename(fc_GUA_pt_50m_nw_25m) + " : " + nbrec)
        
                if arcpy.Exists("{}GUA_points_layer".format(uc_code)):
                    arcpy.Delete_management("{}GUA_points_layer".format(uc_code))
                GUA_pt_lyr = arcpy.MakeFeatureLayer_management(fc_GUA_pt_50m_nw_25m, "{}GUA_points_layer".format(uc_code))
                print("{}GUA_points_layer".format(uc_code))
                

                # Create service area layer
                ###create_service_area_layer(GUA_pt_lyr, "{}_SA_400m".format(uc_code), pedestrianNWpath, uc_code, nbMeters)
                group_id = uc_code
                network_dataset = pedestrianNWpath
                locations = GUA_pt_lyr
                if not os.path.exists(fc_SA):
                    create_service_area_layer(group_id, network_dataset, locations, fc_SA)

                #join GQA FID
                arcpy.management.JoinField(
                    in_data=fc_SA,
                    in_field="FacilityID",
                    join_table=fc_GUA_pt_50m_nw_25m,
                    join_field="OBJECTID",
                    fields="FID",
                    fm_option="NOT_USE_FM",
                    field_mapping=None,
                    index_join_fields="NO_INDEXES"
                )
                # Dissolve by QGA id
                outDiss = os.path.join(outPath, 'Dissolved', "{}_SAd.shp".format(uc_code))
                if not os.path.exists(outDiss):
                    arcpy.analysis.PairwiseDissolve(
                        in_features=fc_SA,
                        out_feature_class=outDiss,
                        dissolve_field="FID_1",
                        statistics_fields=None,
                        multi_part="MULTI_PART",
                        concatenation_separator=""
                    )


                print ("end: " + time.strftime("%H:%M:%S", time.localtime()))
                
            except CustomError as ce:
                arcpy.AddError(ce.value)
                print (ce.value)
            except arcpy.ExecuteError:
                msgs = arcpy.GetMessages(2)
                arcpy.AddError(msgs)
                print (msgs)
            except:
                tb = sys.exc_info()[2]
                tbinfo = traceback.format_tb(tb)[0]
                pymsg = "PYTHON ERRORS:\nTraceback info:\n" + tbinfo + "\nError Info:\n" + str(sys.exc_info()[1])
                msgs = "ArcPy ERRORS:\n" + arcpy.GetMessages(2) + "\n"
                arcpy.AddError(pymsg)
                print (msgs)
                arcpy.AddError(msgs)
                print (pymsg)
# Out:
# Network Analyst extension has been checked out.
# GEOSTAT21_018
# Stockholm
# GEOSTAT21_021
# Tartu
# GEOSTAT21_022
# Örebro
# GEOSTAT21_023
# Stavanger
# GEOSTAT21_024
# Norrköping
# GEOSTAT21_025
# Linköping
# GEOSTAT21_914
# Jönköping / Huskvarna
# GEOSTAT21_029
# Göteborg
# GEOSTAT21_026
# Borås
# GEOSTAT21_028
# Rīga
# GEOSTAT21_031
# Aalborg
# GEOSTAT21_047
# Århus
# GEOSTAT21_048
# Helsingborg
# GEOSTAT21_903
# København
# GEOSTAT21_049
# Lund
# GEOSTAT21_051
# Kaunas
# GEOSTAT21_054
# Malmö
# GEOSTAT21_060
# Odense
# GEOSTAT21_065
# Gdynia
# GEOSTAT21_068
# Gdańsk
# GEOSTAT21_904
# Dublin
# GEOSTAT21_070
# Elbląg
# GEOSTAT21_086
# Kiel
# GEOSTAT21_090
# Olsztyn
# GEOSTAT21_093
# Lütten Klein
# GEOSTAT21_094
# Rostock
# GEOSTAT21_095
# Limerick
# GEOSTAT21_108
# Lübeck
# GEOSTAT21_109
# Białystok
# GEOSTAT21_119
# Hamburg
# GEOSTAT21_118
# Bremerhaven
# GEOSTAT21_120
# Szczecin
# GEOSTAT21_919
# Neu Wulmstorf / Neugraben-Fischbek / Hausbruch
# GEOSTAT21_121
# Harburg
# GEOSTAT21_122
# Kasztelanka
# GEOSTAT21_128
# Bydgoszcz
# GEOSTAT21_132
# Cork
# GEOSTAT21_131
# Toruń
# GEOSTAT21_137
# Groningen
# GEOSTAT21_141
# Oldenburg (Oldenburg)
# GEOSTAT21_140
# Gröpelingen / Vegesack
# GEOSTAT21_145
# Bremen
# GEOSTAT21_150
# Włocławek
# GEOSTAT21_154
# Płock
# GEOSTAT21_161
# Gorzów Wielkopolski
# GEOSTAT21_171
# Warszawa
# GEOSTAT21_002
# Oulu / Uleåborg
# GEOSTAT21_003
# Umeå
# GEOSTAT21_004
# Trondheim
# GEOSTAT21_005
# Jyväskylä
# GEOSTAT21_006
# Tampere / Tammerfors
# GEOSTAT21_911
# Lahti
# GEOSTAT21_901
# Helsinki
# GEOSTAT21_007
# Turku / Åbo
# GEOSTAT21_011
# Bergen
# GEOSTAT21_012
# Tallinn
# GEOSTAT21_013
# Uppsala
# GEOSTAT21_902
# Oslo
# GEOSTAT21_016
# Västerås
# GEOSTAT21_912
# Drammen
# GEOSTAT21_200
# Hannover
# GEOSTAT21_205
# Leiden
# GEOSTAT21_196
# Hilversum
# GEOSTAT21_199
# Hengelo
# GEOSTAT21_201
# Osnabrück
# GEOSTAT21_203
# Apeldoorn
# GEOSTAT21_211
# Braunschweig
# GEOSTAT21_208
# Enschede
# GEOSTAT21_206
# Alphen aan den Rijn
# GEOSTAT21_221
# Den Haag
# GEOSTAT21_905
# Utrecht
# GEOSTAT21_216
# Zoetermeer
# GEOSTAT21_229
# Łódź
# GEOSTAT21_225
# Magdeburg
# GEOSTAT21_220
# Gouda
# GEOSTAT21_223
# Hildesheim
# GEOSTAT21_224
# Nieuwegein / IJsselstein
# GEOSTAT21_240
# Rotterdam
# GEOSTAT21_233
# Zielona Góra
# GEOSTAT21_239
# Arnhem
# GEOSTAT21_237
# Bielefeld
# GEOSTAT21_243
# Münster
# GEOSTAT21_242
# Spijkenisse
# GEOSTAT21_248
# Dordrecht
# GEOSTAT21_249
# Radom
# GEOSTAT21_256
# Nijmegen
# GEOSTAT21_255
# Lublin
# GEOSTAT21_327
# Düsseldorf
# GEOSTAT21_925
# Wuppertal
# GEOSTAT21_316
# Dunkerque
# GEOSTAT21_331
# Mönchengladbach
# GEOSTAT21_332
# Gent
# GEOSTAT21_334
# Solingen
# GEOSTAT21_328
# Remscheid
# GEOSTAT21_335
# Częstochowa
# GEOSTAT21_339
# Dresden
# GEOSTAT21_346
# Köln
# GEOSTAT21_349
# Bruxelles / Brussel
# GEOSTAT21_344
# Leuven
# GEOSTAT21_347
# Heerlen
# GEOSTAT21_348
# Opole
# GEOSTAT21_354
# Porz
# GEOSTAT21_359
# Chemnitz
# GEOSTAT21_358
# Liberec
# GEOSTAT21_360
# Aachen
# GEOSTAT21_363
# Bonn
# GEOSTAT21_364
# Liège
# GEOSTAT21_362
# Ústí nad Labem
# GEOSTAT21_376
# Górnośląski Związek Metropolitalny
# GEOSTAT21_366
# Rzeszów
# GEOSTAT21_367
# Lens
# GEOSTAT21_379
# Charleroi
# GEOSTAT21_265
# s-Hertogenbosch
# GEOSTAT21_274
# Breda
# GEOSTAT21_299
# Ruhrgebiet
# GEOSTAT21_289
# Göttingen
# GEOSTAT21_292
# Eindhoven
# GEOSTAT21_288
# Helmond
# GEOSTAT21_295
# Halle an der Saale
# GEOSTAT21_297
# Moers / Rheinhausen
# GEOSTAT21_302
# Duisburg
# GEOSTAT21_305
# Hagen
# GEOSTAT21_304
# Brugge
# GEOSTAT21_312
# Leipzig
# GEOSTAT21_307
# Krefeld
# GEOSTAT21_317
# Antwerpen
# GEOSTAT21_308
# Kielce
# GEOSTAT21_318
# Wrocław
# GEOSTAT21_320
# Kassel
# GEOSTAT21_922
# Scharwoude / Heerhugowaard
# GEOSTAT21_168
# Alkmaar
# GEOSTAT21_178
# Poznań
# GEOSTAT21_186
# Berlin
# GEOSTAT21_173
# Beverwijk/Heemskerk
# GEOSTAT21_190
# Amsterdam
# GEOSTAT21_177
# Zwolle
# GEOSTAT21_181
# Haarlem
# GEOSTAT21_184
# Almere
# GEOSTAT21_188
# Potsdam
# GEOSTAT21_405
# Wiesbaden
# GEOSTAT21_403
# Havířov
# GEOSTAT21_404
# Hrabuvka
# GEOSTAT21_408
# Mainz
# GEOSTAT21_413
# Darmstadt
# GEOSTAT21_418
# Rouen
# GEOSTAT21_414
# Olomouc
# GEOSTAT21_417
# Würzburg
# GEOSTAT21_416
# Plzeň
# GEOSTAT21_419
# Luxembourg
# GEOSTAT21_420
# Caen
# GEOSTAT21_421
# Erlangen
# GEOSTAT21_457
# Vaihingen / Möhringen
# GEOSTAT21_473
# Reutlingen
# GEOSTAT21_481
# Wien
# GEOSTAT21_476
# Ulm/Neu-Ulm
# start: 15:25:09
# Extent set to match uc: 4314000 2805000 4325000 2814000 NaN NaN NaN NaN
# nb record(s) in GEOSTAT21_476_finalGQA.shp subset selection [code_2018] IN (14100,30000,31000) : 91
# Create points from GUA borders used to create SA
# GeneratePointsAlongLines Distance 50m from selected GUA in GEOSTAT21_476_finalGQA.shp to GEOSTAT21_476_GUA_pt_50m
# nb generated points : 1253
# SelectLayerByLocation points in GEOSTAT21_476_GUA_pt_50m WITHIN_A_DISTANCE of 25 meters from nw to GEOSTAT21_476_GUA_pt_50m_nw_25m
# Nb of GQA near network 74
# Total nb of GQA 91
# Centroids and FIDs computed and appended successfully.
# nb points in GEOSTAT21_476_GUA_pt_50m_nw_25m : 750
# GEOSTAT21_476GUA_points_layer
# end: 15:25:55
# GEOSTAT21_479
# Linz
# GEOSTAT21_907
# Augsburg
# start: 15:25:56
# Extent set to match uc: 4381000 2793000 4392000 2811000 NaN NaN NaN NaN
# nb record(s) in GEOSTAT21_907_finalGQA.shp subset selection [code_2018] IN (14100,30000,31000) : 158
# Create points from GUA borders used to create SA
# GeneratePointsAlongLines Distance 50m from selected GUA in GEOSTAT21_907_finalGQA.shp to GEOSTAT21_907_GUA_pt_50m
# nb generated points : 2429
# SelectLayerByLocation points in GEOSTAT21_907_GUA_pt_50m WITHIN_A_DISTANCE of 25 meters from nw to GEOSTAT21_907_GUA_pt_50m_nw_25m
# Nb of GQA near network 135
# Total nb of GQA 158
# Centroids and FIDs computed and appended successfully.
# nb points in GEOSTAT21_907_GUA_pt_50m_nw_25m : 1099
# GEOSTAT21_907GUA_points_layer
# end: 15:26:38
# GEOSTAT21_487
# München
# start: 15:26:38
# Extent set to match uc: 4425000 2771000 4451000 2793000 NaN NaN NaN NaN
# nb record(s) in GEOSTAT21_487_finalGQA.shp subset selection [code_2018] IN (14100,30000,31000) : 695
# Create points from GUA borders used to create SA
# GeneratePointsAlongLines Distance 50m from selected GUA in GEOSTAT21_487_finalGQA.shp to GEOSTAT21_487_GUA_pt_50m
# nb generated points : 9244
# SelectLayerByLocation points in GEOSTAT21_487_GUA_pt_50m WITHIN_A_DISTANCE of 25 meters from nw to GEOSTAT21_487_GUA_pt_50m_nw_25m
# Nb of GQA near network 638
# Total nb of GQA 695
# Centroids and FIDs computed and appended successfully.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <expression> in <module>
#
# KeyboardInterrupt:
# nb points in GEOSTAT21_487_GUA_pt_50m_nw_25m : 6753
# GEOSTAT21_487GUA_points_layer

# %%
#----------------------------------------------------------------------------------
#Author: Veerle Martens
#Date: may 2012
#Adapted by: Raquel Ubach (UAB) - Dec 2023/Jul 2024
#
#Purpose: Create service areas around each building block and find out the area of
#         green urban area that can be reached.
#---------------------------------------------------------------------------------

#create error handler
class CustomError(Exception):
    def __init__(self,value):
        self.value = value
    def __str__(self):
        return repr(self.value)

import sys, arcpy, time, traceback, os.path
import pandas as pd

def unique_values(table , field):
    with arcpy.da.SearchCursor(table, [field]) as cursor:
        return sorted({row[0] for row in cursor})

def convert(list):
    return tuple(list)

def create_service_area_layer(group_id, network_dataset, locations, fc_SA):
    print ("Creating network layer for batch {}".format(group_id))
    salyr = arcpy.na.MakeServiceAreaAnalysisLayer(
        network_data_source= network_dataset,
        layer_name="{}_SA_400m".format(group_id),
        travel_mode="Walk",
        travel_direction="FROM_FACILITIES",
        cutoffs=[400],
        time_of_day=None,
        time_zone="LOCAL_TIME_AT_LOCATIONS",
        output_type="POLYGONS",
        polygon_detail="HIGH",
        geometry_at_overlaps="OVERLAP",
        geometry_at_cutoffs="DISKS",
        polygon_trim_distance="10 Meters",
        exclude_sources_from_polygon_generation=None,
        accumulate_attributes=None,
        ignore_invalid_locations="SKIP"
    )
    arcpy.na.AddLocations(
        in_network_analysis_layer=salyr,
        sub_layer="Facilities",        
        in_table=locations,
        field_mappings="Name # #;CurbApproach # 0;Attr_Minutes # 0;Attr_Meters # 0;Attr_pedestrian_minutes # 0;Breaks_Minutes # #;Breaks_Meters # #;Breaks_pedestrian_minutes # #",
        search_tolerance="5000 Meters",
        sort_field=None,
        search_criteria="nw SHAPE;Network_ND_Junctions NONE",
        match_type="MATCH_TO_CLOSEST",
        append="APPEND",
        snap_to_position_along_network="NO_SNAP",
        snap_offset="5 Meters",
        exclude_restricted_elements="EXCLUDE",
        search_query=None,
        allow_auto_relocate="ALLOW"
    )
    print("Solving network analysis")
    arcpy.na.Solve(
        in_network_analysis_layer=salyr,
        ignore_invalids="SKIP",
        terminate_on_solve_error="CONTINUE",
        simplification_tolerance=None,
        overrides=""
    )
    arcpy.CopyFeatures_management("{}_SA_400m\Polygons".format(uc_code), fc_SA)
    arcpy.Delete_management(salyr) 

# Path to data folders
indata_f = r'P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas'
networks_f = os.path.join(indata_f, 'Network data Regio')
step1_f = os.path.join(indata_f, 'OutputData', 'step1_GQA')
step2_f = os.path.join(indata_f, 'OutputData', 'step2_GQA_Final')
step3_f = os.path.join(indata_f, 'OutputData', 'step3_SA')
if not os.path.exists(step3_f):
    os.makedirs(step3_f)
uc_file_path = os.path.join(indata_f, 'UrbanCentres', 'HDC2021_RG_InputUpdateB2B3B4Copy.shp')

# input parameters
pedestrian_path = networks_f
outPath = step3_f 
CODE_Fld = "code_2018"
UATL_ID_Fld = "FID"

    
# TRANSLATOR TABLE
# Crosswalk table containing the different codes from input sources
codes_path = r'P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\Codes.csv'
codes = pd.read_csv(codes_path)

#Environment settings
arcpy.env.overwriteOutput = True
arcpy.env.addOutputsToMap = False

try:
    arcpy.CheckOutExtension("Network")
    print("Network Analyst extension has been checked out.")
except arcpy.ExecuteError:
    print("Failed to check out the Network Analyst extension.")
    
# Run process for ctry
ctry = 'FR'
sql_query = "Batch >0"

# Define the path and name for the geodatabase
gdb_path = os.path.join(indata_f, 'Processing')
#gdb_path = os.path.join(indata_f, 'OutputData', 'oct_run', 'step2_SA_final_AT')

#gdb_name = f"SA_output_2510_{ctry}.gdb"
gdb_name = f"SA_diss_2910.gdb"
outGDB = os.path.join(gdb_path, gdb_name)
# Check if the geodatabase exists
if not arcpy.Exists(outGDB):
    # Create the geodatabase if it does not exist
    arcpy.CreateFileGDB_management(gdb_path, gdb_name)

with arcpy.da.SearchCursor(uc_file_path, ["SHAPE@", "HDENS_CLST", "CNTR_CODE"], where_clause=sql_query) as uc_cursor:
    for uc_row in uc_cursor:
        geom = uc_row[0]  # Geometry object
        ctr_cd = uc_row[2]
        uc_code = uc_row[1]
        print(uc_code)
        print(codes.query(f'HDENS_CLST == "{uc_code}"').HDENS_NAME.values.astype(str)[0].strip())
        inGQA = os.path.join(step2_f, '{}_finalGQA.shp'.format(uc_code))
        fc_SA = os.path.join(outPath, "{}_SA.shp".format(uc_code))
        ####fc_SA = os.path.join(gdb_path, gdb_name, "{}_SA".format(uc_code))
        if ctr_cd.startswith("CH-"):
            ctr_cd = "CH"
        
        outDiss = os.path.join(outPath, 'Dissolved', "{}_SAd.shp".format(uc_code))
        ##if os.path.exists(inGQA) and not arcpy.Exists(fc_SA) and ctr_cd!="NO" and ctr_cd!="CH":
        if os.path.exists(inGQA) and not arcpy.Exists(outDiss) and ctr_cd != ctry:
            print ("start: " + time.strftime("%H:%M:%S", time.localtime()))
            pedestrianNWpath = pedestrian_path + r"\NW_" + ctr_cd + ".gdb\\" + ctr_cd + r"\Network_ND"
            if not arcpy.Exists(pedestrianNWpath):
                raise CustomError("Featureclass " + pedestrianNWpath + " NOT FOUND")

            arcpy.env.extent = geom.extent # Extent object of the geometry
            print("Extent set to match uc: {}".format(arcpy.env.extent))
            
            try:          

                if arcpy.Exists("{}_UATLlayer".format(uc_code)):
                    arcpy.Delete_management("{}_UATLlayer".format(uc_code))
                uatlLyr = arcpy.MakeFeatureLayer_management(inGQA, "{}_UATLlayer".format(uc_code))

                ## Count number of GUA Blocks
                cnt = arcpy.GetCount_management(uatlLyr)
                print ("nb record(s) in " + os.path.basename(inGQA) + " subset selection [" + CODE_Fld + "] IN (14100,30000,31000) : " +  cnt.getOutput(0))

                ## Create and Select points from GUA borders used to create SA
                print ("Create points from GUA borders used to create SA")

                #fc_GUA_pt_50m = outPath + "\\GUA_pt_50m.shp" ## modified to output folder
                fc_GUA_pt_50m = outGDB +"\\{}_GUA_pt_50m".format(uc_code)

                if arcpy.Exists(fc_GUA_pt_50m):
                    arcpy.Delete_management(fc_GUA_pt_50m)
                print ("GeneratePointsAlongLines Distance 50m from selected GUA in " + os.path.basename(inGQA) + " to " + os.path.basename(fc_GUA_pt_50m))
                arcpy.GeneratePointsAlongLines_management(uatlLyr, fc_GUA_pt_50m, 'DISTANCE', Distance='50 meters', Include_End_Points='END_POINTS')

                cnt = arcpy.GetCount_management(fc_GUA_pt_50m)
                nbrec = cnt.getOutput(0)
                print ("nb generated points : " + nbrec)

                if arcpy.Exists('{}_GUA_PT_50m_lyr'.format(uc_code)):
                    arcpy.Delete_management('{}_GUA_PT_50m_lyr'.format(uc_code))
                arcpy.MakeFeatureLayer_management(fc_GUA_pt_50m, '{}_GUA_PT_50m_lyr'.format(uc_code)) 

                fc_GUA_pt_50m_nw_25m = outGDB +"\\{}_GUA_pt_50m_nw_25m".format(uc_code)    
                if arcpy.Exists(fc_GUA_pt_50m_nw_25m):
                    arcpy.Delete_management(fc_GUA_pt_50m_nw_25m)
                nw_Path = pedestrian_path + r"\NW_" + ctr_cd + ".gdb" + "\\" + ctr_cd + "\\nw"
                print ("SelectLayerByLocation points in " + os.path.basename(fc_GUA_pt_50m) + " WITHIN_A_DISTANCE of 25 meters from " + os.path.basename(nw_Path)+ " to " + os.path.basename(fc_GUA_pt_50m_nw_25m))
                Selection = arcpy.SelectLayerByLocation_management('{}_GUA_PT_50m_lyr'.format(uc_code), 'WITHIN_A_DISTANCE', nw_Path, "25 meters", "NEW_SELECTION")
                # save selection in a diferent feature class
                arcpy.CopyFeatures_management(Selection, fc_GUA_pt_50m_nw_25m) 
                # Adding FID field to the point feature class if it doesn't already exist
                if 'FID' not in [f.name for f in arcpy.ListFields(fc_GUA_pt_50m_nw_25m)]:
                    arcpy.AddField_management(fc_GUA_pt_50m_nw_25m, 'FID', 'LONG')

                UATL_Ids_GUAs_nw_25m = unique_values(fc_GUA_pt_50m_nw_25m, "ORIG_FID")
                print("Nb of GQA near network " + str(len(UATL_Ids_GUAs_nw_25m)))
                ids_ls_GQA = unique_values(uatlLyr, "FID")
                print("Total nb of GQA " +str(len(ids_ls_GQA)))

                # GQA without access to network (less than 25m)
                ids_noaccess = [item for item in ids_ls_GQA if item not in UATL_Ids_GUAs_nw_25m]
                
                # List to hold centroid points and their corresponding FIDs
                centroid_points = []
                fields_ls = ["FID", "SHAPE@", "Area"] # List of fields to include
                # Create a search cursor to iterate through the polygon shapefile GQA
                with arcpy.da.SearchCursor(uatlLyr, fields_ls) as cursor:
                    for row in cursor:
                        if row[0] in ids_noaccess:
                            # Get the FID and the geometry of the polygon
                            fid = row[0]
                            polygon = row[1]
                            area = row[2]
                            # Compute the centroid of the polygon
                            centroid = polygon.centroid
                            # Append the FID and centroid to the list
                            centroid_points.append((fid, centroid, area))

                # Start an edit session for the geodatabase
                with arcpy.da.Editor(outGDB) as edit:
                    # Create an insert cursor for the point feature class
                    with arcpy.da.InsertCursor(fc_GUA_pt_50m_nw_25m, fields_ls) as cursor:
                        for fid, point, area in centroid_points:
                            # Insert the centroid point and the FID
                            cursor.insertRow([fid, point, area])
                print("Centroids and FIDs computed and appended successfully.")

                # Add FID value to all records
                field_to_check = 'FID'
                alternative_field = 'ORIG_FID'
                #expression = f"!{field_to_check}! if !{field_to_check}! is not None else !{alternative_field}!"
                expression ="!FID! if !FID! is not None else !ORIG_FID!"
                # Execute CalculateField
                arcpy.CalculateField_management(fc_GUA_pt_50m_nw_25m, field_to_check, expression, "PYTHON3")

                cnt = arcpy.GetCount_management(fc_GUA_pt_50m_nw_25m)
                nbrec = cnt.getOutput(0)
                print ("nb points in " + os.path.basename(fc_GUA_pt_50m_nw_25m) + " : " + nbrec)
        
                if arcpy.Exists("{}GUA_points_layer".format(uc_code)):
                    arcpy.Delete_management("{}GUA_points_layer".format(uc_code))
                GUA_pt_lyr = arcpy.MakeFeatureLayer_management(fc_GUA_pt_50m_nw_25m, "{}GUA_points_layer".format(uc_code))
                print("{}GUA_points_layer".format(uc_code))
                

                # Create service area layer
                ###create_service_area_layer(GUA_pt_lyr, "{}_SA_400m".format(uc_code), pedestrianNWpath, uc_code, nbMeters)
                group_id = uc_code
                network_dataset = pedestrianNWpath
                locations = GUA_pt_lyr
                if os.path.exists(fc_SA):
                        #create_service_area_layer(group_id, network_dataset, locations, fc_SA)

                    #join GQA FID
                    arcpy.management.JoinField(
                        in_data=fc_SA,
                        in_field="FacilityID",
                        join_table=fc_GUA_pt_50m_nw_25m,
                        join_field="OBJECTID",
                        fields="FID",
                        fm_option="NOT_USE_FM",
                        field_mapping=None,
                        index_join_fields="NO_INDEXES"
                    )
                    # Dissolve by QGA id
                    outDiss = os.path.join(outPath, 'Dissolved', "{}_SAd.shp".format(uc_code))
                    if not os.path.exists(outDiss):
                        arcpy.analysis.PairwiseDissolve(
                            in_features=fc_SA,
                            out_feature_class=outDiss,
                            dissolve_field="FID_1",
                            statistics_fields=None,
                            multi_part="MULTI_PART",
                            concatenation_separator=""
                        )


                print ("end: " + time.strftime("%H:%M:%S", time.localtime()))
                
            except CustomError as ce:
                arcpy.AddError(ce.value)
                print (ce.value)
            except arcpy.ExecuteError:
                msgs = arcpy.GetMessages(2)
                arcpy.AddError(msgs)
                print (msgs)
            except:
                tb = sys.exc_info()[2]
                tbinfo = traceback.format_tb(tb)[0]
                pymsg = "PYTHON ERRORS:\nTraceback info:\n" + tbinfo + "\nError Info:\n" + str(sys.exc_info()[1])
                msgs = "ArcPy ERRORS:\n" + arcpy.GetMessages(2) + "\n"
                arcpy.AddError(pymsg)
                print (msgs)
                arcpy.AddError(msgs)
                print (pymsg)
# Out:
# Network Analyst extension has been checked out.
# GEOSTAT21_018
# Stockholm
# GEOSTAT21_021
# Tartu
# GEOSTAT21_022
# Örebro
# GEOSTAT21_023
# Stavanger
# GEOSTAT21_024
# Norrköping
# GEOSTAT21_025
# Linköping
# GEOSTAT21_914
# Jönköping / Huskvarna
# GEOSTAT21_029
# Göteborg
# GEOSTAT21_026
# Borås
# GEOSTAT21_028
# Rīga
# GEOSTAT21_031
# Aalborg
# GEOSTAT21_047
# Århus
# GEOSTAT21_048
# Helsingborg
# GEOSTAT21_903
# København
# GEOSTAT21_049
# Lund
# GEOSTAT21_051
# Kaunas
# GEOSTAT21_054
# Malmö
# GEOSTAT21_060
# Odense
# GEOSTAT21_065
# Gdynia
# GEOSTAT21_068
# Gdańsk
# GEOSTAT21_904
# Dublin
# GEOSTAT21_070
# Elbląg
# GEOSTAT21_086
# Kiel
# GEOSTAT21_090
# Olsztyn
# GEOSTAT21_093
# Lütten Klein
# GEOSTAT21_094
# Rostock
# GEOSTAT21_095
# Limerick
# GEOSTAT21_108
# Lübeck
# GEOSTAT21_109
# Białystok
# GEOSTAT21_119
# Hamburg
# GEOSTAT21_118
# Bremerhaven
# GEOSTAT21_120
# Szczecin
# GEOSTAT21_919
# Neu Wulmstorf / Neugraben-Fischbek / Hausbruch
# GEOSTAT21_121
# Harburg
# GEOSTAT21_122
# Kasztelanka
# GEOSTAT21_128
# Bydgoszcz
# GEOSTAT21_132
# Cork
# GEOSTAT21_131
# Toruń
# GEOSTAT21_137
# Groningen
# GEOSTAT21_141
# Oldenburg (Oldenburg)
# GEOSTAT21_140
# Gröpelingen / Vegesack
# GEOSTAT21_145
# Bremen
# GEOSTAT21_150
# Włocławek
# GEOSTAT21_154
# Płock
# GEOSTAT21_161
# Gorzów Wielkopolski
# GEOSTAT21_171
# Warszawa
# GEOSTAT21_002
# Oulu / Uleåborg
# GEOSTAT21_003
# Umeå
# GEOSTAT21_004
# Trondheim
# GEOSTAT21_005
# Jyväskylä
# GEOSTAT21_006
# Tampere / Tammerfors
# GEOSTAT21_911
# Lahti
# GEOSTAT21_901
# Helsinki
# GEOSTAT21_007
# Turku / Åbo
# GEOSTAT21_011
# Bergen
# GEOSTAT21_012
# Tallinn
# GEOSTAT21_013
# Uppsala
# GEOSTAT21_902
# Oslo
# GEOSTAT21_016
# Västerås
# GEOSTAT21_912
# Drammen
# GEOSTAT21_200
# Hannover
# GEOSTAT21_205
# Leiden
# GEOSTAT21_196
# Hilversum
# GEOSTAT21_199
# Hengelo
# GEOSTAT21_201
# Osnabrück
# GEOSTAT21_203
# Apeldoorn
# GEOSTAT21_211
# Braunschweig
# GEOSTAT21_208
# Enschede
# GEOSTAT21_206
# Alphen aan den Rijn
# GEOSTAT21_221
# Den Haag
# GEOSTAT21_905
# Utrecht
# GEOSTAT21_216
# Zoetermeer
# GEOSTAT21_229
# Łódź
# GEOSTAT21_225
# Magdeburg
# GEOSTAT21_220
# Gouda
# GEOSTAT21_223
# Hildesheim
# GEOSTAT21_224
# Nieuwegein / IJsselstein
# GEOSTAT21_240
# Rotterdam
# GEOSTAT21_233
# Zielona Góra
# GEOSTAT21_239
# Arnhem
# GEOSTAT21_237
# Bielefeld
# GEOSTAT21_243
# Münster
# GEOSTAT21_242
# Spijkenisse
# GEOSTAT21_248
# Dordrecht
# start: 15:50:51
# Extent set to match uc: 3949000 3198000 3963000 3207000 NaN NaN NaN NaN
# nb record(s) in GEOSTAT21_248_finalGQA.shp subset selection [code_2018] IN (14100,30000,31000) : 192
# Create points from GUA borders used to create SA
# GeneratePointsAlongLines Distance 50m from selected GUA in GEOSTAT21_248_finalGQA.shp to GEOSTAT21_248_GUA_pt_50m
# nb generated points : 2963
# SelectLayerByLocation points in GEOSTAT21_248_GUA_pt_50m WITHIN_A_DISTANCE of 25 meters from nw to GEOSTAT21_248_GUA_pt_50m_nw_25m
# Nb of GQA near network 176
# Total nb of GQA 192
# Centroids and FIDs computed and appended successfully.
# nb points in GEOSTAT21_248_GUA_pt_50m_nw_25m : 1921
# GEOSTAT21_248GUA_points_layer
# end: 15:51:26
# GEOSTAT21_249
# Radom
# GEOSTAT21_256
# Nijmegen
# GEOSTAT21_255
# Lublin
# GEOSTAT21_327
# Düsseldorf
# GEOSTAT21_925
# Wuppertal
# GEOSTAT21_316
# Dunkerque
# GEOSTAT21_331
# Mönchengladbach
# GEOSTAT21_332
# Gent
# GEOSTAT21_334
# Solingen
# GEOSTAT21_328
# Remscheid
# GEOSTAT21_335
# Częstochowa
# GEOSTAT21_339
# Dresden
# GEOSTAT21_346
# Köln
# GEOSTAT21_349
# Bruxelles / Brussel
# GEOSTAT21_344
# Leuven
# GEOSTAT21_347
# Heerlen
# start: 15:51:28
# Extent set to match uc: 4034000 3090000 4044000 3102000 NaN NaN NaN NaN
# nb record(s) in GEOSTAT21_347_finalGQA.shp subset selection [code_2018] IN (14100,30000,31000) : 371
# Create points from GUA borders used to create SA
# GeneratePointsAlongLines Distance 50m from selected GUA in GEOSTAT21_347_finalGQA.shp to GEOSTAT21_347_GUA_pt_50m
# nb generated points : 5143
# SelectLayerByLocation points in GEOSTAT21_347_GUA_pt_50m WITHIN_A_DISTANCE of 25 meters from nw to GEOSTAT21_347_GUA_pt_50m_nw_25m
# Nb of GQA near network 340
# Total nb of GQA 371
# Centroids and FIDs computed and appended successfully.
# nb points in GEOSTAT21_347_GUA_pt_50m_nw_25m : 3381
# GEOSTAT21_347GUA_points_layer
# end: 15:52:02
# GEOSTAT21_348
# Opole
# GEOSTAT21_354
# Porz
# GEOSTAT21_359
# Chemnitz
# GEOSTAT21_358
# Liberec
# GEOSTAT21_360
# Aachen
# GEOSTAT21_363
# Bonn
# GEOSTAT21_364
# Liège
# GEOSTAT21_362
# Ústí nad Labem
# GEOSTAT21_376
# Górnośląski Związek Metropolitalny
# GEOSTAT21_366
# Rzeszów
# GEOSTAT21_367
# Lens
# GEOSTAT21_379
# Charleroi
# GEOSTAT21_265
# s-Hertogenbosch
# GEOSTAT21_274
# Breda
# GEOSTAT21_299
# Ruhrgebiet
# GEOSTAT21_289
# Göttingen
# GEOSTAT21_292
# Eindhoven
# GEOSTAT21_288
# Helmond
# GEOSTAT21_295
# Halle an der Saale
# GEOSTAT21_297
# Moers / Rheinhausen
# GEOSTAT21_302
# Duisburg
# GEOSTAT21_305
# Hagen
# GEOSTAT21_304
# Brugge
# GEOSTAT21_312
# Leipzig
# GEOSTAT21_307
# Krefeld
# GEOSTAT21_317
# Antwerpen
# GEOSTAT21_308
# Kielce
# GEOSTAT21_318
# Wrocław
# GEOSTAT21_320
# Kassel
# GEOSTAT21_922
# Scharwoude / Heerhugowaard
# GEOSTAT21_168
# Alkmaar
# GEOSTAT21_178
# Poznań
# GEOSTAT21_186
# Berlin
# GEOSTAT21_173
# Beverwijk/Heemskerk
# GEOSTAT21_190
# Amsterdam
# GEOSTAT21_177
# Zwolle
# GEOSTAT21_181
# Haarlem
# GEOSTAT21_184
# Almere
# GEOSTAT21_188
# Potsdam
# GEOSTAT21_405
# Wiesbaden
# GEOSTAT21_403
# Havířov
# GEOSTAT21_404
# Hrabuvka
# GEOSTAT21_408
# Mainz
# GEOSTAT21_413
# Darmstadt
# GEOSTAT21_418
# Rouen
# GEOSTAT21_414
# Olomouc
# GEOSTAT21_417
# Würzburg
# GEOSTAT21_416
# Plzeň
# GEOSTAT21_419
# Luxembourg
# GEOSTAT21_420
# Caen
# GEOSTAT21_421
# Erlangen
# GEOSTAT21_457
# Vaihingen / Möhringen
# GEOSTAT21_473
# Reutlingen
# GEOSTAT21_481
# Wien
# GEOSTAT21_476
# Ulm/Neu-Ulm
# GEOSTAT21_479
# Linz
# GEOSTAT21_907
# Augsburg
# GEOSTAT21_487
# München
# GEOSTAT21_488
# Freiburg im Breisgau
# GEOSTAT21_489
# Angers
# GEOSTAT21_496
# Nantes
# GEOSTAT21_495
# Salzburg
# start: 15:52:07
# Extent set to match uc: 4544000 2744000 4552000 2751000 NaN NaN NaN NaN
# nb record(s) in GEOSTAT21_495_finalGQA.shp subset selection [code_2018] IN (14100,30000,31000) : 157
# Create points from GUA borders used to create SA
# GeneratePointsAlongLines Distance 50m from selected GUA in GEOSTAT21_495_finalGQA.shp to GEOSTAT21_495_GUA_pt_50m
# nb generated points : 2020
# SelectLayerByLocation points in GEOSTAT21_495_GUA_pt_50m WITHIN_A_DISTANCE of 25 meters from nw to GEOSTAT21_495_GUA_pt_50m_nw_25m
# Nb of GQA near network 141
# Total nb of GQA 157
# Centroids and FIDs computed and appended successfully.
# nb points in GEOSTAT21_495_GUA_pt_50m_nw_25m : 1231
# GEOSTAT21_495GUA_points_layer
# end: 15:52:48
# GEOSTAT21_499
# Tours
# GEOSTAT21_510
# Basel
# start: 15:52:48
# Extent set to match uc: 4135000 2708000 4147000 2727000 NaN NaN NaN NaN
# nb record(s) in GEOSTAT21_510_finalGQA.shp subset selection [code_2018] IN (14100,30000,31000) : 165
# Create points from GUA borders used to create SA
# GeneratePointsAlongLines Distance 50m from selected GUA in GEOSTAT21_510_finalGQA.shp to GEOSTAT21_510_GUA_pt_50m
# nb generated points : 3104
# SelectLayerByLocation points in GEOSTAT21_510_GUA_pt_50m WITHIN_A_DISTANCE of 25 meters from nw to GEOSTAT21_510_GUA_pt_50m_nw_25m
# Nb of GQA near network 147
# Total nb of GQA 165
# Centroids and FIDs computed and appended successfully.
# nb points in GEOSTAT21_510_GUA_pt_50m_nw_25m : 1885
# GEOSTAT21_510GUA_points_layer
# end: 15:53:27
# GEOSTAT21_941
# Gebenstorf / Turgi / Obersiggenthal / Baden / Wettingen
# GEOSTAT21_425
# Mannheim/Ludwigshafen
# GEOSTAT21_429
# Fürth
# GEOSTAT21_427
# Reims
# GEOSTAT21_428
# Heidelberg
# GEOSTAT21_430
# Brno
# GEOSTAT21_431
# Brest
# GEOSTAT21_906
# Paris
# GEOSTAT21_432
# Mantes en Yvelines
# GEOSTAT21_435
# Saarbrücken
# GEOSTAT21_437
# Poissy
# GEOSTAT21_441
# Heilbronn
# GEOSTAT21_440
# Les Clayes-sous-Bois
# GEOSTAT21_443
# Maurepas / Montigny-le-Bretonneux
# GEOSTAT21_445
# Regensburg
# GEOSTAT21_447
# Karlsruhe
# GEOSTAT21_448
# Pforzheim
# GEOSTAT21_454
# Stuttgart
# GEOSTAT21_455
# Ingolstadt
# GEOSTAT21_459
# Rennes
# GEOSTAT21_377
# Tarnów
# start: 15:53:29
# Extent set to match uc: 5103000 3046000 5108000 3051000 NaN NaN NaN NaN
# nb record(s) in GEOSTAT21_377_finalGQA.shp subset selection [code_2018] IN (14100,30000,31000) : 30
# Create points from GUA borders used to create SA
# GeneratePointsAlongLines Distance 50m from selected GUA in GEOSTAT21_377_finalGQA.shp to GEOSTAT21_377_GUA_pt_50m
# nb generated points : 491
# SelectLayerByLocation points in GEOSTAT21_377_GUA_pt_50m WITHIN_A_DISTANCE of 25 meters from nw to GEOSTAT21_377_GUA_pt_50m_nw_25m
# Nb of GQA near network 20
# Total nb of GQA 30
# Centroids and FIDs computed and appended successfully.
# nb points in GEOSTAT21_377_GUA_pt_50m_nw_25m : 123
# GEOSTAT21_377GUA_points_layer
# end: 15:54:04
# GEOSTAT21_385
# Kraków
# start: 15:54:04
# Extent set to match uc: 5024000 3034000 5040000 3049000 NaN NaN NaN NaN
# nb record(s) in GEOSTAT21_385_finalGQA.shp subset selection [code_2018] IN (14100,30000,31000) : 380
# Create points from GUA borders used to create SA
# GeneratePointsAlongLines Distance 50m from selected GUA in GEOSTAT21_385_finalGQA.shp to GEOSTAT21_385_GUA_pt_50m
# nb generated points : 5942
# SelectLayerByLocation points in GEOSTAT21_385_GUA_pt_50m WITHIN_A_DISTANCE of 25 meters from nw to GEOSTAT21_385_GUA_pt_50m_nw_25m
# Nb of GQA near network 354
# Total nb of GQA 380
# Centroids and FIDs computed and appended successfully.
# nb points in GEOSTAT21_385_GUA_pt_50m_nw_25m : 3991
# GEOSTAT21_385GUA_points_layer
# end: 15:54:48
# GEOSTAT21_382
# Arras
# GEOSTAT21_384
# Tychy
# start: 15:54:48
# Extent set to match uc: 4960000 3036000 4964000 3043000 NaN NaN NaN NaN
# nb record(s) in GEOSTAT21_384_finalGQA.shp subset selection [code_2018] IN (14100,30000,31000) : 90
# Create points from GUA borders used to create SA
# GeneratePointsAlongLines Distance 50m from selected GUA in GEOSTAT21_384_finalGQA.shp to GEOSTAT21_384_GUA_pt_50m
# nb generated points : 1257
# SelectLayerByLocation points in GEOSTAT21_384_GUA_pt_50m WITHIN_A_DISTANCE of 25 meters from nw to GEOSTAT21_384_GUA_pt_50m_nw_25m
# Nb of GQA near network 74
# Total nb of GQA 90
# Centroids and FIDs computed and appended successfully.
# nb points in GEOSTAT21_384_GUA_pt_50m_nw_25m : 438
# GEOSTAT21_384GUA_points_layer
# end: 15:55:21
# GEOSTAT21_387
# Koblenz
# GEOSTAT21_402
# Praha
# GEOSTAT21_401
# Frankfurt am Main
# GEOSTAT21_394
# Bielsko-Biała
# GEOSTAT21_397
# Ostrava
# start: 15:55:22
# Extent set to match uc: 4913000 3001000 4918000 3006000 NaN NaN NaN NaN
# nb record(s) in GEOSTAT21_397_finalGQA.shp subset selection [code_2018] IN (14100,30000,31000) : 46
# Create points from GUA borders used to create SA
# GeneratePointsAlongLines Distance 50m from selected GUA in GEOSTAT21_397_finalGQA.shp to GEOSTAT21_397_GUA_pt_50m
# nb generated points : 437
# SelectLayerByLocation points in GEOSTAT21_397_GUA_pt_50m WITHIN_A_DISTANCE of 25 meters from nw to GEOSTAT21_397_GUA_pt_50m_nw_25m
# Nb of GQA near network 39
# Total nb of GQA 46
# Centroids and FIDs computed and appended successfully.
# nb points in GEOSTAT21_397_GUA_pt_50m_nw_25m : 219
# GEOSTAT21_397GUA_points_layer
# end: 15:55:54
# GEOSTAT21_400
# Hanau
# GEOSTAT21_398
# Poruba
# GEOSTAT21_542
# Lausanne
# start: 15:55:54
# Extent set to match uc: 4050000 2604000 4067000 2611000 NaN NaN NaN NaN
# nb record(s) in GEOSTAT21_542_finalGQA.shp subset selection [code_2018] IN (14100,30000,31000) : 198
# Create points from GUA borders used to create SA
# GeneratePointsAlongLines Distance 50m from selected GUA in GEOSTAT21_542_finalGQA.shp to GEOSTAT21_542_GUA_pt_50m
# nb generated points : 3030
# SelectLayerByLocation points in GEOSTAT21_542_GUA_pt_50m WITHIN_A_DISTANCE of 25 meters from nw to GEOSTAT21_542_GUA_pt_50m_nw_25m
# Nb of GQA near network 167
# Total nb of GQA 198
# Centroids and FIDs computed and appended successfully.
# nb points in GEOSTAT21_542_GUA_pt_50m_nw_25m : 1398
# GEOSTAT21_542GUA_points_layer
# end: 15:56:27
# GEOSTAT21_549
# Genève
# start: 15:56:27
# Extent set to match uc: 4017000 2568000 4032000 2577000 NaN NaN NaN NaN
# nb record(s) in GEOSTAT21_549_finalGQA.shp subset selection [code_2018] IN (14100,30000,31000) : 143
# Create points from GUA borders used to create SA
# GeneratePointsAlongLines Distance 50m from selected GUA in GEOSTAT21_549_finalGQA.shp to GEOSTAT21_549_GUA_pt_50m
# nb generated points : 2346
# SelectLayerByLocation points in GEOSTAT21_549_GUA_pt_50m WITHIN_A_DISTANCE of 25 meters from nw to GEOSTAT21_549_GUA_pt_50m_nw_25m
# Nb of GQA near network 129
# Total nb of GQA 143
# Centroids and FIDs computed and appended successfully.
# nb points in GEOSTAT21_549_GUA_pt_50m_nw_25m : 1260
# GEOSTAT21_549GUA_points_layer
# end: 15:57:00
# GEOSTAT21_550
# Limoges
# GEOSTAT21_558
# Clermont-Ferrand
# GEOSTAT21_557
# Lugano
# start: 15:57:00
# Extent set to match uc: 4238000 2542000 4243000 2548000 NaN NaN NaN NaN
# nb record(s) in GEOSTAT21_557_finalGQA.shp subset selection [code_2018] IN (14100,30000,31000) : 130
# Create points from GUA borders used to create SA
# GeneratePointsAlongLines Distance 50m from selected GUA in GEOSTAT21_557_finalGQA.shp to GEOSTAT21_557_GUA_pt_50m
# nb generated points : 1924
# SelectLayerByLocation points in GEOSTAT21_557_GUA_pt_50m WITHIN_A_DISTANCE of 25 meters from nw to GEOSTAT21_557_GUA_pt_50m_nw_25m
# Nb of GQA near network 109
# Total nb of GQA 130
# Centroids and FIDs computed and appended successfully.
# nb points in GEOSTAT21_557_GUA_pt_50m_nw_25m : 1050
# GEOSTAT21_557GUA_points_layer
# end: 15:57:33
# GEOSTAT21_561
# Zagreb
# start: 15:57:34
# Extent set to match uc: 4777000 2534000 4799000 2546000 NaN NaN NaN NaN
# nb record(s) in GEOSTAT21_561_finalGQA.shp subset selection [code_2018] IN (14100,30000,31000) : 214
# Create points from GUA borders used to create SA
# GeneratePointsAlongLines Distance 50m from selected GUA in GEOSTAT21_561_finalGQA.shp to GEOSTAT21_561_GUA_pt_50m
# nb generated points : 4371
# SelectLayerByLocation points in GEOSTAT21_561_GUA_pt_50m WITHIN_A_DISTANCE of 25 meters from nw to GEOSTAT21_561_GUA_pt_50m_nw_25m
# Nb of GQA near network 186
# Total nb of GQA 214
# Centroids and FIDs computed and appended successfully.
# nb points in GEOSTAT21_561_GUA_pt_50m_nw_25m : 2012
# GEOSTAT21_561GUA_points_layer
# end: 15:58:09
# GEOSTAT21_569
# Lyon
# GEOSTAT21_945
# Saint-Priest / Mions
# GEOSTAT21_624
# Oviedo
# GEOSTAT21_650
# Bilbao
# GEOSTAT21_652
# San Sebastián/Donostia
# GEOSTAT21_657
# Vigo
# GEOSTAT21_665
# León
# GEOSTAT21_672
# Nice
# GEOSTAT21_669
# Split
# start: 15:58:10
# Extent set to match uc: 4840000 2288000 4848000 2294000 NaN NaN NaN NaN
# nb record(s) in GEOSTAT21_669_finalGQA.shp subset selection [code_2018] IN (14100,30000,31000) : 34
# Create points from GUA borders used to create SA
# GeneratePointsAlongLines Distance 50m from selected GUA in GEOSTAT21_669_finalGQA.shp to GEOSTAT21_669_GUA_pt_50m
# nb generated points : 520
# SelectLayerByLocation points in GEOSTAT21_669_GUA_pt_50m WITHIN_A_DISTANCE of 25 meters from nw to GEOSTAT21_669_GUA_pt_50m_nw_25m
# Nb of GQA near network 26
# Total nb of GQA 34
# Centroids and FIDs computed and appended successfully.
# nb points in GEOSTAT21_669_GUA_pt_50m_nw_25m : 236
# GEOSTAT21_669GUA_points_layer
# end: 15:58:41
# GEOSTAT21_674
# Vitoria/Gasteiz
# GEOSTAT21_676
# Aix-en-Provence
# GEOSTAT21_682
# Martigues / Port-de-Bouc
# GEOSTAT21_687
# Pamplona/Iruña
# GEOSTAT21_689
# Marseille
# GEOSTAT21_694
# Logroño
# GEOSTAT21_580
# Saint-Etienne
# GEOSTAT21_588
# Rijeka
# start: 15:58:42
# Extent set to match uc: 4663000 2477000 4673000 2483000 NaN NaN NaN NaN
# nb record(s) in GEOSTAT21_588_finalGQA.shp subset selection [code_2018] IN (14100,30000,31000) : 201
# Create points from GUA borders used to create SA
# GeneratePointsAlongLines Distance 50m from selected GUA in GEOSTAT21_588_finalGQA.shp to GEOSTAT21_588_GUA_pt_50m
# nb generated points : 2350
# SelectLayerByLocation points in GEOSTAT21_588_GUA_pt_50m WITHIN_A_DISTANCE of 25 meters from nw to GEOSTAT21_588_GUA_pt_50m_nw_25m
# Nb of GQA near network 153
# Total nb of GQA 201
# Centroids and FIDs computed and appended successfully.
# nb points in GEOSTAT21_588_GUA_pt_50m_nw_25m : 1131
# GEOSTAT21_588GUA_points_layer
# end: 15:59:14
# GEOSTAT21_595
# Bordeaux
# GEOSTAT21_597
# Grenoble
# GEOSTAT21_620
# Gijón
# GEOSTAT21_521
# Zürich
# start: 15:59:14
# Extent set to match uc: 4199000 2682000 4219000 2707000 NaN NaN NaN NaN
# nb record(s) in GEOSTAT21_521_finalGQA.shp subset selection [code_2018] IN (14100,30000,31000) : 387
# Create points from GUA borders used to create SA
# GeneratePointsAlongLines Distance 50m from selected GUA in GEOSTAT21_521_finalGQA.shp to GEOSTAT21_521_GUA_pt_50m
# nb generated points : 8152
# SelectLayerByLocation points in GEOSTAT21_521_GUA_pt_50m WITHIN_A_DISTANCE of 25 meters from nw to GEOSTAT21_521_GUA_pt_50m_nw_25m
# Nb of GQA near network 355
# Total nb of GQA 387
# Centroids and FIDs computed and appended successfully.
# nb points in GEOSTAT21_521_GUA_pt_50m_nw_25m : 5115
# GEOSTAT21_521GUA_points_layer
# end: 15:59:58
# GEOSTAT21_514
# St. Gallen
# start: 15:59:58
# Extent set to match uc: 4269000 2699000 4277000 2706000 NaN NaN NaN NaN
# nb record(s) in GEOSTAT21_514_finalGQA.shp subset selection [code_2018] IN (14100,30000,31000) : 103
# Create points from GUA borders used to create SA
# GeneratePointsAlongLines Distance 50m from selected GUA in GEOSTAT21_514_finalGQA.shp to GEOSTAT21_514_GUA_pt_50m
# nb generated points : 1666
# SelectLayerByLocation points in GEOSTAT21_514_GUA_pt_50m WITHIN_A_DISTANCE of 25 meters from nw to GEOSTAT21_514_GUA_pt_50m_nw_25m
# Nb of GQA near network 79
# Total nb of GQA 103
# Centroids and FIDs computed and appended successfully.
# nb points in GEOSTAT21_514_GUA_pt_50m_nw_25m : 699
# GEOSTAT21_514GUA_points_layer
# end: 16:00:36
# GEOSTAT21_519
# Besançon
# GEOSTAT21_520
# Innsbruck
# start: 16:00:37
# Extent set to match uc: 4421000 2683000 4431000 2687000 NaN NaN NaN NaN
# nb record(s) in GEOSTAT21_520_finalGQA.shp subset selection [code_2018] IN (14100,30000,31000) : 110
# Create points from GUA borders used to create SA
# GeneratePointsAlongLines Distance 50m from selected GUA in GEOSTAT21_520_finalGQA.shp to GEOSTAT21_520_GUA_pt_50m
# nb generated points : 1240
# SelectLayerByLocation points in GEOSTAT21_520_GUA_pt_50m WITHIN_A_DISTANCE of 25 meters from nw to GEOSTAT21_520_GUA_pt_50m_nw_25m
# Nb of GQA near network 97
# Total nb of GQA 110
# Centroids and FIDs computed and appended successfully.
# nb points in GEOSTAT21_520_GUA_pt_50m_nw_25m : 729
# GEOSTAT21_520GUA_points_layer
# end: 16:01:15
# GEOSTAT21_522
# Graz
# start: 16:01:15
# Extent set to match uc: 4730000 2670000 4739000 2682000 NaN NaN NaN NaN
# nb record(s) in GEOSTAT21_522_finalGQA.shp subset selection [code_2018] IN (14100,30000,31000) : 217
# Create points from GUA borders used to create SA
# GeneratePointsAlongLines Distance 50m from selected GUA in GEOSTAT21_522_finalGQA.shp to GEOSTAT21_522_GUA_pt_50m
# nb generated points : 3192
# SelectLayerByLocation points in GEOSTAT21_522_GUA_pt_50m WITHIN_A_DISTANCE of 25 meters from nw to GEOSTAT21_522_GUA_pt_50m_nw_25m
# Nb of GQA near network 189
# Total nb of GQA 217
# Centroids and FIDs computed and appended successfully.
# nb points in GEOSTAT21_522_GUA_pt_50m_nw_25m : 1649
# GEOSTAT21_522GUA_points_layer
# end: 16:01:51
# GEOSTAT21_943
# Cham / Zug
# GEOSTAT21_523
# Biel/Bienne
# GEOSTAT21_528
# Bern
# start: 16:01:52
# Extent set to match uc: 4121000 2647000 4133000 2655000 NaN NaN NaN NaN
# nb record(s) in GEOSTAT21_528_finalGQA.shp subset selection [code_2018] IN (14100,30000,31000) : 153
# Create points from GUA borders used to create SA
# GeneratePointsAlongLines Distance 50m from selected GUA in GEOSTAT21_528_finalGQA.shp to GEOSTAT21_528_GUA_pt_50m
# nb generated points : 3328
# SelectLayerByLocation points in GEOSTAT21_528_GUA_pt_50m WITHIN_A_DISTANCE of 25 meters from nw to GEOSTAT21_528_GUA_pt_50m_nw_25m
# Nb of GQA near network 137
# Total nb of GQA 153
# Centroids and FIDs computed and appended successfully.
# nb points in GEOSTAT21_528_GUA_pt_50m_nw_25m : 1587
# GEOSTAT21_528GUA_points_layer
# end: 16:02:29
# GEOSTAT21_531
# Fribourg
# GEOSTAT21_800
# Castellón de la Plana/Castelló de la Plana
# GEOSTAT21_809
# Valencia
# GEOSTAT21_843
# Lefkosia
# start: 16:02:29
# Extent set to match uc: 6430000 1660000 6440000 1673000 NaN NaN NaN NaN
# nb record(s) in GEOSTAT21_843_finalGQA.shp subset selection [code_2018] IN (14100,30000,31000) : 51
# Create points from GUA borders used to create SA
# GeneratePointsAlongLines Distance 50m from selected GUA in GEOSTAT21_843_finalGQA.shp to GEOSTAT21_843_GUA_pt_50m
# nb generated points : 473
# SelectLayerByLocation points in GEOSTAT21_843_GUA_pt_50m WITHIN_A_DISTANCE of 25 meters from nw to GEOSTAT21_843_GUA_pt_50m_nw_25m
# Nb of GQA near network 35
# Total nb of GQA 51
# Centroids and FIDs computed and appended successfully.
# nb points in GEOSTAT21_843_GUA_pt_50m_nw_25m : 197
# GEOSTAT21_843GUA_points_layer
# end: 16:03:01
# GEOSTAT21_773
# Madrid
# GEOSTAT21_768
# Torrejón de Ardoz
# GEOSTAT21_774
# Fuenlabrada
# GEOSTAT21_706
# Porto
# GEOSTAT21_712
# Valladolid
# GEOSTAT21_856
# Lemesos
# start: 16:03:02
# Extent set to match uc: 6416000 1605000 6426000 1614000 NaN NaN NaN NaN
# nb record(s) in GEOSTAT21_856_finalGQA.shp subset selection [code_2018] IN (14100,30000,31000) : 24
# Create points from GUA borders used to create SA
# GeneratePointsAlongLines Distance 50m from selected GUA in GEOSTAT21_856_finalGQA.shp to GEOSTAT21_856_GUA_pt_50m
# nb generated points : 227
# SelectLayerByLocation points in GEOSTAT21_856_GUA_pt_50m WITHIN_A_DISTANCE of 25 meters from nw to GEOSTAT21_856_GUA_pt_50m_nw_25m
# Nb of GQA near network 16
# Total nb of GQA 24
# Centroids and FIDs computed and appended successfully.
# nb points in GEOSTAT21_856_GUA_pt_50m_nw_25m : 120
# GEOSTAT21_856GUA_points_layer
# end: 16:03:32
# GEOSTAT21_867
# Valletta
# start: 16:03:32
# Extent set to match uc: 4723000 1432000 4736000 1442000 NaN NaN NaN NaN
# nb record(s) in GEOSTAT21_867_finalGQA.shp subset selection [code_2018] IN (14100,30000,31000) : 67
# Create points from GUA borders used to create SA
# GeneratePointsAlongLines Distance 50m from selected GUA in GEOSTAT21_867_finalGQA.shp to GEOSTAT21_867_GUA_pt_50m
# nb generated points : 558
# SelectLayerByLocation points in GEOSTAT21_867_GUA_pt_50m WITHIN_A_DISTANCE of 25 meters from nw to GEOSTAT21_867_GUA_pt_50m_nw_25m
# Nb of GQA near network 56
# Total nb of GQA 67
# Centroids and FIDs computed and appended successfully.
# nb points in GEOSTAT21_867_GUA_pt_50m_nw_25m : 344
# GEOSTAT21_867GUA_points_layer
# end: 16:04:05

# %% [markdown]
# ### for last multiple ua

# %%
#----------------------------------------------------------------------------------
#Author: Veerle Martens
#Date: may 2012
#Adapted by: Raquel Ubach (UAB) - Dec 2023/Jul 2024
#
#Purpose: Create service areas around each building block and find out the area of
#         green urban area that can be reached.
#---------------------------------------------------------------------------------

#create error handler
class CustomError(Exception):
    def __init__(self,value):
        self.value = value
    def __str__(self):
        return repr(self.value)

import sys, arcpy, time, traceback, os.path
import pandas as pd

def unique_values(table , field):
    with arcpy.da.SearchCursor(table, [field]) as cursor:
        return sorted({row[0] for row in cursor})

def convert(list):
    return tuple(list)

def create_service_area_layer(group_id, network_dataset, locations, fc_SA):
    print ("Creating network layer for batch {}".format(group_id))
    salyr = arcpy.na.MakeServiceAreaAnalysisLayer(
        network_data_source= network_dataset,
        layer_name="{}_SA_400m".format(group_id),
        travel_mode="Walk",
        travel_direction="FROM_FACILITIES",
        cutoffs=[400],
        time_of_day=None,
        time_zone="LOCAL_TIME_AT_LOCATIONS",
        output_type="POLYGONS",
        polygon_detail="HIGH",
        geometry_at_overlaps="OVERLAP",
        geometry_at_cutoffs="DISKS",
        polygon_trim_distance="10 Meters",
        exclude_sources_from_polygon_generation=None,
        accumulate_attributes=None,
        ignore_invalid_locations="SKIP"
    )
    arcpy.na.AddLocations(
        in_network_analysis_layer=salyr,
        sub_layer="Facilities",        
        in_table=locations,
        field_mappings="Name # #;CurbApproach # 0;Attr_Minutes # 0;Attr_Meters # 0;Attr_pedestrian_minutes # 0;Breaks_Minutes # #;Breaks_Meters # #;Breaks_pedestrian_minutes # #",
        search_tolerance="5000 Meters",
        sort_field=None,
        search_criteria="nw SHAPE;Network_ND_Junctions NONE",
        match_type="MATCH_TO_CLOSEST",
        append="APPEND",
        snap_to_position_along_network="NO_SNAP",
        snap_offset="5 Meters",
        exclude_restricted_elements="EXCLUDE",
        search_query=None,
        allow_auto_relocate="ALLOW"
    )
    print("Solving network analysis")
    arcpy.na.Solve(
        in_network_analysis_layer=salyr,
        ignore_invalids="SKIP",
        terminate_on_solve_error="CONTINUE",
        simplification_tolerance=None,
        overrides=""
    )
    arcpy.CopyFeatures_management("{}_SA_400m\Polygons".format(uc_code), fc_SA)
    arcpy.Delete_management(salyr) 

# Path to data folders
indata_f = r'P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas'
networks_f = os.path.join(indata_f, 'Network data Regio')
step1_f = os.path.join(indata_f, 'OutputData', 'step1_GQA')
step2_f = os.path.join(indata_f, 'OutputData', 'step2_GQA_Final')
step3_f = os.path.join(indata_f, 'OutputData', 'step3_SA')
if not os.path.exists(step3_f):
    os.makedirs(step3_f)
uc_file_path = os.path.join(indata_f, 'UrbanCentres', 'HDC2021_RG_InputUpdateB2B3B4Copy.shp')

# input parameters
pedestrian_path = networks_f
outPath = step3_f 
CODE_Fld = "code_2018"
UATL_ID_Fld = "FID"

    
# TRANSLATOR TABLE
# Crosswalk table containing the different codes from input sources
codes_path = r'P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\Codes.csv'
codes = pd.read_csv(codes_path)

#Environment settings
arcpy.env.overwriteOutput = True
arcpy.env.addOutputsToMap = False

try:
    arcpy.CheckOutExtension("Network")
    print("Network Analyst extension has been checked out.")
except arcpy.ExecuteError:
    print("Failed to check out the Network Analyst extension.")
    
# Run process for ctry
ctry = 'DE'
#sql_query = "Batch >0"
sql_query = "HDENS_CLST = 'GEOSTAT21_297'"

# Define the path and name for the geodatabase
gdb_path = os.path.join(indata_f, 'Processing')
#gdb_path = os.path.join(indata_f, 'OutputData', 'oct_run', 'step2_SA_final_AT')

#gdb_name = f"SA_output_2510_{ctry}.gdb"
gdb_name = f"SA_diss_2611.gdb"
outGDB = os.path.join(gdb_path, gdb_name)
# Check if the geodatabase exists
if not arcpy.Exists(outGDB):
    # Create the geodatabase if it does not exist
    arcpy.CreateFileGDB_management(gdb_path, gdb_name)

with arcpy.da.SearchCursor(uc_file_path, ["SHAPE@", "HDENS_CLST", "CNTR_CODE"], where_clause=sql_query) as uc_cursor:
    for uc_row in uc_cursor:
        geom = uc_row[0]  # Geometry object
        ctr_cd = uc_row[2]
        uc_code = uc_row[1]
        print(uc_code)
        print(codes.query(f'HDENS_CLST == "{uc_code}"').HDENS_NAME.values.astype(str)[0].strip())
        inGQA = os.path.join(step2_f, '{}_finalGQA.shp'.format(uc_code))
        fc_SA = os.path.join(outPath, "{}_SA.shp".format(uc_code))
        ####fc_SA = os.path.join(gdb_path, gdb_name, "{}_SA".format(uc_code))
        if ctr_cd.startswith("CH-"):
            ctr_cd = "CH"
        
        outDiss = os.path.join(outPath, 'Dissolved', "{}_SAd.shp".format(uc_code))
        ##if os.path.exists(inGQA) and not arcpy.Exists(fc_SA) and ctr_cd!="NO" and ctr_cd!="CH":
        if os.path.exists(inGQA) and not arcpy.Exists(outDiss):
            print ("start: " + time.strftime("%H:%M:%S", time.localtime()))
            pedestrianNWpath = pedestrian_path + r"\NW_" + ctr_cd + ".gdb\\" + ctr_cd + r"\Network_ND"
            if not arcpy.Exists(pedestrianNWpath):
                raise CustomError("Featureclass " + pedestrianNWpath + " NOT FOUND")

            arcpy.env.extent = geom.extent # Extent object of the geometry
            print("Extent set to match uc: {}".format(arcpy.env.extent))
            
            try:          

                if arcpy.Exists("{}_UATLlayer".format(uc_code)):
                    arcpy.Delete_management("{}_UATLlayer".format(uc_code))
                uatlLyr = arcpy.MakeFeatureLayer_management(inGQA, "{}_UATLlayer".format(uc_code))

                ## Count number of GUA Blocks
                cnt = arcpy.GetCount_management(uatlLyr)
                print ("nb record(s) in " + os.path.basename(inGQA) + " subset selection [" + CODE_Fld + "] IN (14100,30000,31000) : " +  cnt.getOutput(0))

                ## Create and Select points from GUA borders used to create SA
                print ("Create points from GUA borders used to create SA")

                #fc_GUA_pt_50m = outPath + "\\GUA_pt_50m.shp" ## modified to output folder
                fc_GUA_pt_50m = outGDB +"\\{}_GUA_pt_50m".format(uc_code)

                if arcpy.Exists(fc_GUA_pt_50m):
                    arcpy.Delete_management(fc_GUA_pt_50m)
                print ("GeneratePointsAlongLines Distance 50m from selected GUA in " + os.path.basename(inGQA) + " to " + os.path.basename(fc_GUA_pt_50m))
                arcpy.GeneratePointsAlongLines_management(uatlLyr, fc_GUA_pt_50m, 'DISTANCE', Distance='50 meters', Include_End_Points='END_POINTS')

                cnt = arcpy.GetCount_management(fc_GUA_pt_50m)
                nbrec = cnt.getOutput(0)
                print ("nb generated points : " + nbrec)

                if arcpy.Exists('{}_GUA_PT_50m_lyr'.format(uc_code)):
                    arcpy.Delete_management('{}_GUA_PT_50m_lyr'.format(uc_code))
                arcpy.MakeFeatureLayer_management(fc_GUA_pt_50m, '{}_GUA_PT_50m_lyr'.format(uc_code)) 

                fc_GUA_pt_50m_nw_25m = outGDB +"\\{}_GUA_pt_50m_nw_25m".format(uc_code)    
                if arcpy.Exists(fc_GUA_pt_50m_nw_25m):
                    arcpy.Delete_management(fc_GUA_pt_50m_nw_25m)
                nw_Path = pedestrian_path + r"\NW_" + ctr_cd + ".gdb" + "\\" + ctr_cd + "\\nw"
                print ("SelectLayerByLocation points in " + os.path.basename(fc_GUA_pt_50m) + " WITHIN_A_DISTANCE of 25 meters from " + os.path.basename(nw_Path)+ " to " + os.path.basename(fc_GUA_pt_50m_nw_25m))
                Selection = arcpy.SelectLayerByLocation_management('{}_GUA_PT_50m_lyr'.format(uc_code), 'WITHIN_A_DISTANCE', nw_Path, "25 meters", "NEW_SELECTION")
                # save selection in a diferent feature class
                arcpy.CopyFeatures_management(Selection, fc_GUA_pt_50m_nw_25m) 
                # Adding FID field to the point feature class if it doesn't already exist
                if 'FID' not in [f.name for f in arcpy.ListFields(fc_GUA_pt_50m_nw_25m)]:
                    arcpy.AddField_management(fc_GUA_pt_50m_nw_25m, 'FID', 'LONG')

                UATL_Ids_GUAs_nw_25m = unique_values(fc_GUA_pt_50m_nw_25m, "ORIG_FID")
                print("Nb of GQA near network " + str(len(UATL_Ids_GUAs_nw_25m)))
                ids_ls_GQA = unique_values(uatlLyr, "FID")
                print("Total nb of GQA " +str(len(ids_ls_GQA)))

                # GQA without access to network (less than 25m)
                ids_noaccess = [item for item in ids_ls_GQA if item not in UATL_Ids_GUAs_nw_25m]
                
                # List to hold centroid points and their corresponding FIDs
                centroid_points = []
                #fields_ls = ["FID", "SHAPE@", "Area"] # List of fields to include
                fields_ls = ["FID", "SHAPE@", "area"]
                # Create a search cursor to iterate through the polygon shapefile GQA
                with arcpy.da.SearchCursor(uatlLyr, fields_ls) as cursor:
                    for row in cursor:
                        if row[0] in ids_noaccess:
                            # Get the FID and the geometry of the polygon
                            fid = row[0]
                            polygon = row[1]
                            area = row[2]
                            # Compute the centroid of the polygon
                            centroid = polygon.centroid
                            # Append the FID and centroid to the list
                            centroid_points.append((fid, centroid, area))

                # Start an edit session for the geodatabase
                with arcpy.da.Editor(outGDB) as edit:
                    # Create an insert cursor for the point feature class
                    with arcpy.da.InsertCursor(fc_GUA_pt_50m_nw_25m, fields_ls) as cursor:
                        for fid, point, area in centroid_points:
                            # Insert the centroid point and the FID
                            cursor.insertRow([fid, point, area])
                print("Centroids and FIDs computed and appended successfully.")

                # Add FID value to all records
                field_to_check = 'FID'
                alternative_field = 'ORIG_FID'
                #expression = f"!{field_to_check}! if !{field_to_check}! is not None else !{alternative_field}!"
                expression ="!FID! if !FID! is not None else !ORIG_FID!"
                # Execute CalculateField
                arcpy.CalculateField_management(fc_GUA_pt_50m_nw_25m, field_to_check, expression, "PYTHON3")

                cnt = arcpy.GetCount_management(fc_GUA_pt_50m_nw_25m)
                nbrec = cnt.getOutput(0)
                print ("nb points in " + os.path.basename(fc_GUA_pt_50m_nw_25m) + " : " + nbrec)
        
                if arcpy.Exists("{}GUA_points_layer".format(uc_code)):
                    arcpy.Delete_management("{}GUA_points_layer".format(uc_code))
                GUA_pt_lyr = arcpy.MakeFeatureLayer_management(fc_GUA_pt_50m_nw_25m, "{}GUA_points_layer".format(uc_code))
                print("{}GUA_points_layer".format(uc_code))
                

                # Create service area layer
                ###create_service_area_layer(GUA_pt_lyr, "{}_SA_400m".format(uc_code), pedestrianNWpath, uc_code, nbMeters)
                group_id = uc_code
                network_dataset = pedestrianNWpath
                locations = GUA_pt_lyr
                if os.path.exists(fc_SA):
                        #create_service_area_layer(group_id, network_dataset, locations, fc_SA)

                    #join GQA FID
                    arcpy.management.JoinField(
                        in_data=fc_SA,
                        in_field="FacilityID",
                        join_table=fc_GUA_pt_50m_nw_25m,
                        join_field="OBJECTID",
                        fields="FID",
                        fm_option="NOT_USE_FM",
                        field_mapping=None,
                        index_join_fields="NO_INDEXES"
                    )
                    # Dissolve by QGA id
                    outDiss = os.path.join(outPath, 'Dissolved', "{}_SAd.shp".format(uc_code))
                    if not os.path.exists(outDiss):
                        arcpy.analysis.PairwiseDissolve(
                            in_features=fc_SA,
                            out_feature_class=outDiss,
                            dissolve_field="FID_1",
                            statistics_fields=None,
                            multi_part="MULTI_PART",
                            concatenation_separator=""
                        )


                print ("end: " + time.strftime("%H:%M:%S", time.localtime()))
                
            except CustomError as ce:
                arcpy.AddError(ce.value)
                print (ce.value)
            except arcpy.ExecuteError:
                msgs = arcpy.GetMessages(2)
                arcpy.AddError(msgs)
                print (msgs)
            except:
                tb = sys.exc_info()[2]
                tbinfo = traceback.format_tb(tb)[0]
                pymsg = "PYTHON ERRORS:\nTraceback info:\n" + tbinfo + "\nError Info:\n" + str(sys.exc_info()[1])
                msgs = "ArcPy ERRORS:\n" + arcpy.GetMessages(2) + "\n"
                arcpy.AddError(pymsg)
                print (msgs)
                arcpy.AddError(msgs)
                print (pymsg)
# Out:
# Network Analyst extension has been checked out.
# GEOSTAT21_297
# Moers / Rheinhausen
# start: 16:23:18
# Extent set to match uc: 4085000 3146000 4095000 3157000 NaN NaN NaN NaN
# nb record(s) in GEOSTAT21_297_finalGQA.shp subset selection [code_2018] IN (14100,30000,31000) : 187
# Create points from GUA borders used to create SA
# GeneratePointsAlongLines Distance 50m from selected GUA in GEOSTAT21_297_finalGQA.shp to GEOSTAT21_297_GUA_pt_50m
# nb generated points : 3103
# SelectLayerByLocation points in GEOSTAT21_297_GUA_pt_50m WITHIN_A_DISTANCE of 25 meters from nw to GEOSTAT21_297_GUA_pt_50m_nw_25m
# Nb of GQA near network 161
# Total nb of GQA 187
# ArcPy ERRORS:
#
#
# PYTHON ERRORS:
# Traceback info:
#   File "Q:\UserTemp\ubach\AppData\Local\Temp\3\ipykernel_39676\3746442811.py", line 200, in <cell line: 0>
#     for row in cursor:
#
# Error Info:
# Cannot find field 'Area'

# %%
fields_ls = ["FID", "SHAPE@", "area"]
# Create a search cursor to iterate through the polygon shapefile GQA
with arcpy.da.SearchCursor(uatlLyr, fields_ls) as cursor:
    for row in cursor:
        if row[0] in ids_noaccess:
            # Get the FID and the geometry of the polygon
            fid = row[0]
            polygon = row[1]
            area = row[2]
            # Compute the centroid of the polygon
            centroid = polygon.centroid
            # Append the FID and centroid to the list
            centroid_points.append((fid, centroid, area))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Q:\UserTemp\ubach\AppData\Local\Temp\3\ipykernel_39676\3558312777.py in <cell line: 0>()
#       2 # Create a search cursor to iterate through the polygon shapefile GQA
#       3 with arcpy.da.SearchCursor(uatlLyr, fields_ls) as cursor:
# ----> 4     for row in cursor:
#       5         if row[0] in ids_noaccess:
#       6             # Get the FID and the geometry of the polygon
#
# RuntimeError: Cannot find field 'area'

# %%
#----------------------------------------------------------------------------------
#Author: Veerle Martens
#Date: may 2012
#Adapted by: Raquel Ubach (UAB) - Dec 2023/Jul 2024
#
#Purpose: Create service areas around each building block and find out the area of
#         green urban area that can be reached.
#---------------------------------------------------------------------------------

#create error handler
class CustomError(Exception):
    def __init__(self,value):
        self.value = value
    def __str__(self):
        return repr(self.value)

import sys, arcpy, time, traceback, os.path
import pandas as pd

def unique_values(table , field):
    with arcpy.da.SearchCursor(table, [field]) as cursor:
        return sorted({row[0] for row in cursor})

def convert(list):
    return tuple(list)

def create_service_area_layer(group_id, network_dataset, locations, fc_SA):
    print ("Creating network layer for batch {}".format(group_id))
    salyr = arcpy.na.MakeServiceAreaAnalysisLayer(
        network_data_source= network_dataset,
        layer_name="{}_SA_400m".format(group_id),
        travel_mode="Walk",
        travel_direction="FROM_FACILITIES",
        cutoffs=[400],
        time_of_day=None,
        time_zone="LOCAL_TIME_AT_LOCATIONS",
        output_type="POLYGONS",
        polygon_detail="HIGH",
        geometry_at_overlaps="OVERLAP",
        geometry_at_cutoffs="DISKS",
        polygon_trim_distance="10 Meters",
        exclude_sources_from_polygon_generation=None,
        accumulate_attributes=None,
        ignore_invalid_locations="SKIP"
    )
    arcpy.na.AddLocations(
        in_network_analysis_layer=salyr,
        sub_layer="Facilities",        
        in_table=locations,
        field_mappings="Name # #;CurbApproach # 0;Attr_Minutes # 0;Attr_Meters # 0;Attr_pedestrian_minutes # 0;Breaks_Minutes # #;Breaks_Meters # #;Breaks_pedestrian_minutes # #",
        search_tolerance="5000 Meters",
        sort_field=None,
        search_criteria="nw SHAPE;Network_ND_Junctions NONE",
        match_type="MATCH_TO_CLOSEST",
        append="APPEND",
        snap_to_position_along_network="NO_SNAP",
        snap_offset="5 Meters",
        exclude_restricted_elements="EXCLUDE",
        search_query=None,
        allow_auto_relocate="ALLOW"
    )
    print("Solving network analysis")
    arcpy.na.Solve(
        in_network_analysis_layer=salyr,
        ignore_invalids="SKIP",
        terminate_on_solve_error="CONTINUE",
        simplification_tolerance=None,
        overrides=""
    )
    arcpy.CopyFeatures_management("{}_SA_400m\Polygons".format(uc_code), fc_SA)
    arcpy.Delete_management(salyr) 

# Path to data folders
indata_f = r'P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas'
networks_f = os.path.join(indata_f, 'Network data Regio')
step1_f = os.path.join(indata_f, 'OutputData', 'step1_GQA')
step2_f = os.path.join(indata_f, 'OutputData', 'step2_GQA_Final')
step3_f = os.path.join(indata_f, 'OutputData', 'step3_SA')
if not os.path.exists(step3_f):
    os.makedirs(step3_f)
uc_file_path = os.path.join(indata_f, 'UrbanCentres', 'HDC2021_RG_InputUpdateB2B3B4Copy.shp')

# input parameters
pedestrian_path = networks_f
outPath = step3_f 
CODE_Fld = "code_2018"
UATL_ID_Fld = "FID"

    
# TRANSLATOR TABLE
# Crosswalk table containing the different codes from input sources
codes_path = r'P:\Environment and Health\Noise\ServiceContract\2024_ServiceContract\QuietAreas\Processing\Codes.csv'
codes = pd.read_csv(codes_path)

#Environment settings
arcpy.env.overwriteOutput = True
arcpy.env.addOutputsToMap = False

try:
    arcpy.CheckOutExtension("Network")
    print("Network Analyst extension has been checked out.")
except arcpy.ExecuteError:
    print("Failed to check out the Network Analyst extension.")
    
# Run process for ctry
ctry = 'DE'
#sql_query = "Batch >0"
sql_query = "HDENS_CLST = 'GEOSTAT21_297'"

# Define the path and name for the geodatabase
gdb_path = os.path.join(indata_f, 'Processing')
#gdb_path = os.path.join(indata_f, 'OutputData', 'oct_run', 'step2_SA_final_AT')

#gdb_name = f"SA_output_2510_{ctry}.gdb"
gdb_name = f"aa_SA_diss_2611.gdb"
outGDB = os.path.join(gdb_path, gdb_name)
# Check if the geodatabase exists
if not arcpy.Exists(outGDB):
    # Create the geodatabase if it does not exist
    arcpy.CreateFileGDB_management(gdb_path, gdb_name)

with arcpy.da.SearchCursor(uc_file_path, ["SHAPE@", "HDENS_CLST", "CNTR_CODE"], where_clause=sql_query) as uc_cursor:
    for uc_row in uc_cursor:
        geom = uc_row[0]  # Geometry object
        ctr_cd = uc_row[2]
        uc_code = uc_row[1]
        print(uc_code)
        print(codes.query(f'HDENS_CLST == "{uc_code}"').HDENS_NAME.values.astype(str)[0].strip())
        inGQA = os.path.join(step2_f, '{}_finalGQA.shp'.format(uc_code))
        fc_SA = os.path.join(outPath, "{}_SA.shp".format(uc_code))
        ####fc_SA = os.path.join(gdb_path, gdb_name, "{}_SA".format(uc_code))
        if ctr_cd.startswith("CH-"):
            ctr_cd = "CH"
        
        outDiss = os.path.join(outPath, 'Dissolved', "{}_SAd.shp".format(uc_code))
        ##if os.path.exists(inGQA) and not arcpy.Exists(fc_SA) and ctr_cd!="NO" and ctr_cd!="CH":
        if os.path.exists(inGQA) and not arcpy.Exists(outDiss):
            print ("start: " + time.strftime("%H:%M:%S", time.localtime()))
            pedestrianNWpath = pedestrian_path + r"\NW_" + ctr_cd + ".gdb\\" + ctr_cd + r"\Network_ND"
            if not arcpy.Exists(pedestrianNWpath):
                raise CustomError("Featureclass " + pedestrianNWpath + " NOT FOUND")

            arcpy.env.extent = geom.extent # Extent object of the geometry
            print("Extent set to match uc: {}".format(arcpy.env.extent))
            
            try:          

                if arcpy.Exists("{}_UATLlayer".format(uc_code)):
                    arcpy.Delete_management("{}_UATLlayer".format(uc_code))
                uatlLyr = arcpy.MakeFeatureLayer_management(inGQA, "{}_UATLlayer".format(uc_code))

                ## Count number of GUA Blocks
                cnt = arcpy.GetCount_management(uatlLyr)
                print ("nb record(s) in " + os.path.basename(inGQA) + " subset selection [" + CODE_Fld + "] IN (14100,30000,31000) : " +  cnt.getOutput(0))

                ## Create and Select points from GUA borders used to create SA
                print ("Create points from GUA borders used to create SA")

                #fc_GUA_pt_50m = outPath + "\\GUA_pt_50m.shp" ## modified to output folder
                fc_GUA_pt_50m = outGDB +"\\{}_GUA_pt_50m".format(uc_code)

                if arcpy.Exists(fc_GUA_pt_50m):
                    arcpy.Delete_management(fc_GUA_pt_50m)
                print ("GeneratePointsAlongLines Distance 50m from selected GUA in " + os.path.basename(inGQA) + " to " + os.path.basename(fc_GUA_pt_50m))
                arcpy.GeneratePointsAlongLines_management(uatlLyr, fc_GUA_pt_50m, 'DISTANCE', Distance='50 meters', Include_End_Points='END_POINTS')

                cnt = arcpy.GetCount_management(fc_GUA_pt_50m)
                nbrec = cnt.getOutput(0)
                print ("nb generated points : " + nbrec)

                if arcpy.Exists('{}_GUA_PT_50m_lyr'.format(uc_code)):
                    arcpy.Delete_management('{}_GUA_PT_50m_lyr'.format(uc_code))
                arcpy.MakeFeatureLayer_management(fc_GUA_pt_50m, '{}_GUA_PT_50m_lyr'.format(uc_code)) 

                fc_GUA_pt_50m_nw_25m = outGDB +"\\{}_GUA_pt_50m_nw_25m".format(uc_code)    
                if arcpy.Exists(fc_GUA_pt_50m_nw_25m):
                    arcpy.Delete_management(fc_GUA_pt_50m_nw_25m)
                nw_Path = pedestrian_path + r"\NW_" + ctr_cd + ".gdb" + "\\" + ctr_cd + "\\nw"
                print ("SelectLayerByLocation points in " + os.path.basename(fc_GUA_pt_50m) + " WITHIN_A_DISTANCE of 25 meters from " + os.path.basename(nw_Path)+ " to " + os.path.basename(fc_GUA_pt_50m_nw_25m))
                Selection = arcpy.SelectLayerByLocation_management('{}_GUA_PT_50m_lyr'.format(uc_code), 'WITHIN_A_DISTANCE', nw_Path, "25 meters", "NEW_SELECTION")
                # save selection in a diferent feature class
                arcpy.CopyFeatures_management(Selection, fc_GUA_pt_50m_nw_25m) 
                # Adding FID field to the point feature class if it doesn't already exist
                if 'FID' not in [f.name for f in arcpy.ListFields(fc_GUA_pt_50m_nw_25m)]:
                    arcpy.AddField_management(fc_GUA_pt_50m_nw_25m, 'FID', 'LONG')

                UATL_Ids_GUAs_nw_25m = unique_values(fc_GUA_pt_50m_nw_25m, "ORIG_FID")
                print("Nb of GQA near network " + str(len(UATL_Ids_GUAs_nw_25m)))
                ids_ls_GQA = unique_values(uatlLyr, "FID")
                print("Total nb of GQA " +str(len(ids_ls_GQA)))


                # Add FID value to all records
                field_to_check = 'FID'
                alternative_field = 'ORIG_FID'
                #expression = f"!{field_to_check}! if !{field_to_check}! is not None else !{alternative_field}!"
                expression ="!FID! if !FID! is not None else !ORIG_FID!"
                # Execute CalculateField
                arcpy.CalculateField_management(fc_GUA_pt_50m_nw_25m, field_to_check, expression, "PYTHON3")

                cnt = arcpy.GetCount_management(fc_GUA_pt_50m_nw_25m)
                nbrec = cnt.getOutput(0)
                print ("nb points in " + os.path.basename(fc_GUA_pt_50m_nw_25m) + " : " + nbrec)
        
                if arcpy.Exists("{}GUA_points_layer".format(uc_code)):
                    arcpy.Delete_management("{}GUA_points_layer".format(uc_code))
                GUA_pt_lyr = arcpy.MakeFeatureLayer_management(fc_GUA_pt_50m_nw_25m, "{}GUA_points_layer".format(uc_code))
                print("{}GUA_points_layer".format(uc_code))
                

                # Create service area layer
                ###create_service_area_layer(GUA_pt_lyr, "{}_SA_400m".format(uc_code), pedestrianNWpath, uc_code, nbMeters)
                group_id = uc_code
                network_dataset = pedestrianNWpath
                locations = GUA_pt_lyr
                if os.path.exists(fc_SA):
                    create_service_area_layer(group_id, network_dataset, locations, fc_SA)

                    #join GQA FID
                    arcpy.management.JoinField(
                        in_data=fc_SA,
                        in_field="FacilityID",
                        join_table=fc_GUA_pt_50m_nw_25m,
                        join_field="OBJECTID",
                        fields="FID",
                        fm_option="NOT_USE_FM",
                        field_mapping=None,
                        index_join_fields="NO_INDEXES"
                    )
                    # Dissolve by QGA id
                    outDiss = os.path.join(outPath, 'Dissolved', "{}_SAd.shp".format(uc_code))
                    if not os.path.exists(outDiss):
                        arcpy.analysis.PairwiseDissolve(
                            in_features=fc_SA,
                            out_feature_class=outDiss,
                            dissolve_field="FID_1",
                            statistics_fields=None,
                            multi_part="MULTI_PART",
                            concatenation_separator=""
                        )


                print ("end: " + time.strftime("%H:%M:%S", time.localtime()))
                
            except CustomError as ce:
                arcpy.AddError(ce.value)
                print (ce.value)
            except arcpy.ExecuteError:
                msgs = arcpy.GetMessages(2)
                arcpy.AddError(msgs)
                print (msgs)
            except:
                tb = sys.exc_info()[2]
                tbinfo = traceback.format_tb(tb)[0]
                pymsg = "PYTHON ERRORS:\nTraceback info:\n" + tbinfo + "\nError Info:\n" + str(sys.exc_info()[1])
                msgs = "ArcPy ERRORS:\n" + arcpy.GetMessages(2) + "\n"
                arcpy.AddError(pymsg)
                print (msgs)
                arcpy.AddError(msgs)
                print (pymsg)
# Out:
# Network Analyst extension has been checked out.
# GEOSTAT21_297
# Moers / Rheinhausen
# start: 16:40:49
# Extent set to match uc: 4085000 3146000 4095000 3157000 NaN NaN NaN NaN
# nb record(s) in GEOSTAT21_297_finalGQA.shp subset selection [code_2018] IN (14100,30000,31000) : 187
# Create points from GUA borders used to create SA
# GeneratePointsAlongLines Distance 50m from selected GUA in GEOSTAT21_297_finalGQA.shp to GEOSTAT21_297_GUA_pt_50m
# nb generated points : 3103
# SelectLayerByLocation points in GEOSTAT21_297_GUA_pt_50m WITHIN_A_DISTANCE of 25 meters from nw to GEOSTAT21_297_GUA_pt_50m_nw_25m
# Nb of GQA near network 161
# Total nb of GQA 187
# nb points in GEOSTAT21_297_GUA_pt_50m_nw_25m : 1805
# GEOSTAT21_297GUA_points_layer
# end: 16:41:32

# %%
group_id = uc_code
network_dataset = pedestrianNWpath
locations = GUA_pt_lyr
if not os.path.exists(fc_SA):
    create_service_area_layer(group_id, network_dataset, locations, fc_SA)

    #join GQA FID
    arcpy.management.JoinField(
        in_data=fc_SA,
        in_field="FacilityID",
        join_table=fc_GUA_pt_50m_nw_25m,
        join_field="OBJECTID",
        fields="FID",
        fm_option="NOT_USE_FM",
        field_mapping=None,
        index_join_fields="NO_INDEXES"
    )
    # Dissolve by QGA id
    outDiss = os.path.join(outPath, 'Dissolved', "{}_SAd.shp".format(uc_code))
    if not os.path.exists(outDiss):
        arcpy.analysis.PairwiseDissolve(
            in_features=fc_SA,
            out_feature_class=outDiss,
            dissolve_field="FID_1",
            statistics_fields=None,
            multi_part="MULTI_PART",
            concatenation_separator=""
        )
# Out:
# Creating network layer for batch GEOSTAT21_297
# Solving network analysis

# %%
inGQA
# Out:
# 'P:\\Environment and Health\\Noise\\ServiceContract\\2024_ServiceContract\\QuietAreas\\OutputData\\step2_GQA_Final\\GEOSTAT21_297_finalGQA.shp'

# %%
outDiss
# Out:
# 'P:\\Environment and Health\\Noise\\ServiceContract\\2024_ServiceContract\\QuietAreas\\OutputData\\step3_SA\\Dissolved\\GEOSTAT21_297_SAd.shp'

# %%
ctr_cd
# Out:
# 'DE'

# %%
ctry
# Out:
# 'DE'

# %%
ctr_cd != ctry
